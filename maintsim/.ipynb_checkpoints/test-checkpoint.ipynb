# %%
from System import System

# %%
sys = System(process_times=[3, 4, 5, 2, 3], degradation=[0]*5)
sys.simulate(warmup_time=0)
# Out:
# Writing M1 state at t=0, state=0
# Writing M1 state at t=1, state=0
# Writing M1 state at t=2, state=0
# Writing M1 state at t=3, state=0
# Writing M1 state at t=3, state=1
# Writing M1 state at t=4, state=1
# Writing M1 state at t=5, state=1
# Writing M1 state at t=6, state=1
# Writing M1 state at t=7, state=0
# Writing M1 state at t=7, state=0
# Writing M1 state at t=7, state=1
# Writing M1 state at t=8, state=1
# Writing M1 state at t=9, state=1
# Writing M1 state at t=10, state=1
# Writing M1 state at t=11, state=0
# Writing M1 state at t=11, state=0
# Writing M1 state at t=11, state=1
# Writing M1 state at t=12, state=1
# Writing M1 state at t=13, state=1
# Writing M1 state at t=14, state=1
# Writing M1 state at t=15, state=0
# Writing M1 state at t=15, state=0
# Writing M1 state at t=15, state=1
# Writing M1 state at t=16, state=1
# Writing M1 state at t=17, state=1
# Writing M1 state at t=18, state=1
# Writing M1 state at t=19, state=0
# Writing M1 state at t=19, state=0
# ...

# %%
sys.state_data
# Out:
#    time M0 has part b0 level M1 has part b1 level M2 has part b2 level  \
# 0   NaN           0        0           0        0           0        0
# 1   NaN           0        0           0        0           0        0
# 2   NaN           0        0           0        0           0        0
# 3   NaN           0        0           1        0           0        0
# 4   NaN           0        0           1        0           0        0
# 5   NaN           0        0           1        0           0        0
# 6   NaN           0        1           1        0           0        0
# 7   NaN           0        1           1        1           0        0
# 8   NaN           0        0           1        0           1        0
# 9   NaN           0        1           1        0           1        0
# 10  NaN           0        1           1        0           1        0
# 11  NaN           0        1           1        1           1        0
# ...

# %%
for m in range(5): print(m, sys.machines[m].parts_made)
# Out:
# 0 22
# 1 20
# 2 18
# 3 17
# 4 17

# %%
# single machine production validation
pt = 5
sys = System(process_times=[pt], degradation=[0])
sys.simulate()
print('Parts made: {}'.format(sys.machines[0].parts_made))
print('Parts expected: {}'.format(99 // pt))
# Out:
# 0 5
# 1 4
# 2 3
# 3 2
# 4 1
# 5 5
# 6 4
# 7 3
# 8 2
# 9 1
# 10 5
# 11 4
# 12 3
# 13 2
# 14 1
# 15 5
# 16 4
# 17 3
# 18 2
# 19 1
# 20 5
# 21 4
# 22 3
# 23 2
# 24 1
# 25 5
# 26 4
# 27 3
# 28 2
# 29 1
# 30 5
# 31 4
# 32 3
# 33 2
# 34 1
# 35 5
# 36 4
# 37 3
# 38 2
# 39 1
# 40 5
# 41 4
# 42 3
# 43 2
# 44 1
# 45 5
# 46 4
# 47 3
# 48 2
# 49 1
# 50 5
# 51 4
# 52 3
# 53 2
# 54 1
# 55 5
# 56 4
# 57 3
# 58 2
# 59 1
# 60 5
# 61 4
# 62 3
# 63 2
# 64 1
# 65 5
# 66 4
# 67 3
# 68 2
# 69 1
# 70 5
# 71 4
# 72 3
# 73 2
# 74 1
# 75 5
# 76 4
# 77 3
# 78 2
# 79 1
# 80 5
# 81 4
# 82 3
# 83 2
# 84 1
# 85 5
# 86 4
# 87 3
# 88 2
# 89 1
# 90 5
# 91 4
# 92 3
# 93 2
# 94 1
# 95 5
# 96 4
# 97 3
# 98 2
# 99 1
# Simulation complete in 0.24s
# Parts made: 19
# Parts expected: 19

# %%
sys.machines[0].remaining_process_time
# Out:
# 0

# %%
from random import random

# %%
for i in range(10): print(random())
# Out:
# 0.5345258841255592
# 0.6999699135099143
# 0.6902940523618766
# 0.26946297347088743
# 0.6052170011870712
# 0.24339221047438664
# 0.2483099934414491
# 0.31544793269952787
# 0.9403281575280901
# 0.31221911911458644

# %%
degradation = 0.05

# %%
for i in range(20):
    print(random() > degradation)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
