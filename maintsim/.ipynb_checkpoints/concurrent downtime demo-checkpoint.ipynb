# %%
from System import System
import numpy as np
import matplotlib.pyplot as plt
from itertools import permutations

# %%
def plot_production(sys, return_stats=False):
    machine_dat = sys.machine_data[['time']+['M{} forced idle'.format(m) for m in range(sys.M)]].fillna(0)
    machine_dat = machine_dat[machine_dat['time'] >= 0]
    
    b = sys.bottleneck
    
    bottleneck_uptime = sys.machine_data[['time', 'M{} functional'.format(b)]].fillna(1)
    bottleneck_uptime = bottleneck_uptime[bottleneck_uptime['time'] >= 0]
    
    dat = sys.machine_data[['time','M{} functional'.format(1)]].fillna(1)
    dat = dat[dat['time'] >= 0]
    dat = sum(1-dat['M1 functional'])
    
    
    lp_time = max([0, sum(machine_dat['M{} forced idle'.format(b)]) + dat - 1])#sum(1-bottleneck_uptime['M{} functional'.format(b)])
    lp_units = lp_time / sys.process_times[b]
    
    if return_stats:
        return lp_time, lp_units
        
    plt.figure(figsize=(12,6))
    dat = sys.production_data[sys.production_data['time'] >= 0]
    for m in range(sys.M):
        plt.plot(dat['time'], dat['M{} production'.format(m)], lw=3, label='M{}'.format(m))
    x = np.array([0, max(dat['time'])])
    y = x / max(sys.process_times)
    plt.plot(x, y, label='Ideal production')
    plt.xlabel('time')
    plt.ylabel('production')
    plt.legend(fontsize=16)
    plt.grid()
    plt.show()
    
    print()
    print('Bottleneck machine (M{}) idle for {} time units'.format(b, lp_time))
    print('{} units of lost production'.format(lp_units))

# %% [markdown]
# ## One machine with planned failure

# %%
sys1 = System(process_times=[3], degradation=[0], buffer_sizes=0,
              planned_failures=[(0,10,30)])
sys1.simulate(sim_time=100)
# Out:
# Simulation complete in 0.16s

# %%
#sys1.production_data[:20]

# %%
sys1.maintenance_data
# Out:
#     time machine  type activity duration
# 20    20       0  None   repair       10

# %%
plot_production(sys1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-1f9248aff67c> in <module>()
# ----> 1 plot_production(sys1)
#
# <ipython-input-2-15fcbc3a3814> in plot_production(sys, return_stats)
#       8     bottleneck_uptime = bottleneck_uptime[bottleneck_uptime['time'] >= 0]
#       9
# ---> 10     dat = sys.machine_data[['time','M{} functional'.format(1)]].fillna(1)
#      11     dat = dat[dat['time'] >= 0]
#      12     dat = sum(1-dat['M1 functional'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['M1 functional'] not in index"

# %% [markdown]
# ## Two machines with overlapping failures

# %%
sys2 = System(process_times=[3, 5], degradation=[0]*2, buffer_sizes=2,
              planned_failures=[(0,10,30), (1, 50, 10)])
sys2.simulate(sim_time=100, warmup_time=500)
# Out:
# Simulation complete in 1.00s

# %%
sys2.machines[1].planned_failures
# Out:
# [(1, 550, 10)]

# %%
sys2.maintenance_data
# Out:
#      time machine  type activity duration
# 540    40       0  None   repair       30
# 560    60       1  None   repair       10

# %%
plot_production(sys2)
# Out:
# Bottleneck machine (M1) idle for 31 time units
# 6.2 units of lost production

# %%
sys2.machine_data[sys2.machine_data['time'] >= 0]
# Out:
#      time M0 functional M0 forced idle M1 functional M1 forced idle
# 500     0           NaN            NaN           NaN            NaN
# 501     1           NaN              1           NaN            NaN
# 502     2           NaN              1           NaN            NaN
# 503     3           NaN              1           NaN            NaN
# 504     4           NaN            NaN           NaN            NaN
# 505     5           NaN            NaN           NaN            NaN
# 506     6           NaN              1           NaN            NaN
# 507     7           NaN              1           NaN            NaN
# 508     8           NaN              1           NaN            NaN
# 509     9           NaN            NaN           NaN            NaN
# 510    10           NaN            NaN           NaN            NaN
# 511    11           NaN              1           NaN            NaN
# 512    12           NaN              1           NaN            NaN
# 513    13           NaN              1           NaN            NaN
# 514    14           NaN            NaN           NaN            NaN
# 515    15           NaN            NaN           NaN            NaN
# 516    16           NaN              1           NaN            NaN
# 517    17           NaN              1           NaN            NaN
# 518    18           NaN              1           NaN            NaN
# 519    19           NaN            NaN           NaN            NaN
# 520    20           NaN            NaN           NaN            NaN
# 521    21           NaN              1           NaN            NaN
# 522    22           NaN              1           NaN            NaN
# 523    23           NaN              1           NaN            NaN
# 524    24           NaN            NaN           NaN            NaN
# 525    25           NaN            NaN           NaN            NaN
# 526    26           NaN              1           NaN            NaN
# 527    27           NaN              1           NaN            NaN
# 528    28           NaN              1           NaN            NaN
# 529    29           NaN            NaN           NaN            NaN
# ..    ...           ...            ...           ...            ...
# 570    70           NaN            NaN           NaN            NaN
# 571    71           NaN              1           NaN            NaN
# 572    72           NaN              1           NaN            NaN
# 573    73           NaN              1           NaN            NaN
# 574    74           NaN            NaN           NaN            NaN
# 575    75           NaN            NaN           NaN            NaN
# 576    76           NaN              1           NaN            NaN
# 577    77           NaN              1           NaN            NaN
# 578    78           NaN              1           NaN            NaN
# 579    79           NaN            NaN           NaN            NaN
# 580    80           NaN            NaN           NaN            NaN
# 581    81           NaN              1           NaN            NaN
# 582    82           NaN              1           NaN            NaN
# 583    83           NaN              1           NaN            NaN
# 584    84           NaN            NaN           NaN            NaN
# 585    85           NaN            NaN           NaN            NaN
# 586    86           NaN              1           NaN            NaN
# 587    87           NaN              1           NaN            NaN
# 588    88           NaN              1           NaN            NaN
# 589    89           NaN            NaN           NaN            NaN
# 590    90           NaN            NaN           NaN            NaN
# 591    91           NaN              1           NaN            NaN
# 592    92           NaN              1           NaN            NaN
# 593    93           NaN              1           NaN            NaN
# 594    94           NaN            NaN           NaN            NaN
# 595    95           NaN            NaN           NaN            NaN
# 596    96           NaN              1           NaN            NaN
# 597    97           NaN              1           NaN            NaN
# 598    98           NaN              1           NaN            NaN
# 599    99           NaN            NaN           NaN            NaN
#
# [100 rows x 5 columns]

# %%
sys2_forced_idle = sys2.machine_data[['M{} forced idle'.format(m) for m in range(sys2.M)]].fillna(0)

# %%
sys2.production_data.to_csv('sys2_production.csv')
sys2_forced_idle.to_csv('sys2_idle.csv')
sys2.state_data.to_csv('sys2_state.csv')

# %% [markdown]
# ## Ordering of three failures

# %%
'''
M0: (0, ?, 20)
M1: (1, ?, 25)
M2: (2, ?, 45)
'''
jobs = {0: 15,
        1: 20,
        2: 5}

for job_order in permutations([0, 1, 2]):
    first, second, third = job_order
    
    first_start = 10
    second_start = first_start + jobs[first]
    third_start = second_start + jobs[second]
    
    failures = [(first, first_start, jobs[first]),
                (second, second_start, jobs[second]),
                (third, third_start, jobs[third])]
    
    sys3 = System(process_times=[3, 5, 2], degradation=[0]*3, buffer_sizes=1,
                  planned_failures=failures)#[(first, first_start, 20), (job2, 30, 25), (job3, 55, 45)])
    sys3.simulate(sim_time=200, warmup_time=500, verbose=False)
    
    lp_time, lp_units = plot_production(sys3, return_stats=True)
    
    print('Order: {}, bottleneck idle for {} units'.format(job_order, lp_time))
# Out:
# Order: (0, 1, 2), bottleneck idle for 20 units
# Order: (0, 2, 1), bottleneck idle for 31 units
# Order: (1, 0, 2), bottleneck idle for 29 units
# Order: (1, 2, 0), bottleneck idle for 29 units
# Order: (2, 0, 1), bottleneck idle for 20 units
# Order: (2, 1, 0), bottleneck idle for 29 units

# %%
# service first machine first
sys5 = System(process_times=[3, 5, 2], degradation=[0]*3, buffer_sizes=1,
            planned_failures=[(0, 10, 15)])
sys5.simulate(sim_time=200, warmup_time=500, verbose=False)

lp_time, lp_units = plot_production(sys5, return_stats=True)
print('Bottleneck idle for {} units'.format(lp_time))
# Out:
# Bottleneck idle for 10 units

# %%
# service second machine (bottlenck) first
sys4 = System(process_times=[3, 5, 2], degradation=[0]*3, buffer_sizes=1,
            planned_failures=[(1, 10, 20)])
sys4.simulate(sim_time=200, warmup_time=500, verbose=False)

lp_time, lp_units = plot_production(sys4, return_stats=True)
print('Bottleneck idle for {} units'.format(lp_time))
# Out:
# Bottleneck idle for 20 units

# %%
# service third machine first
sys6 = System(process_times=[3, 5, 2], degradation=[0]*3, buffer_sizes=1,
            planned_failures=[(2, 10, 5)])
sys6.simulate(sim_time=200, warmup_time=500, verbose=False)

lp_time, lp_units = plot_production(sys6, return_stats=True)
print('Bottleneck idle for {} units'.format(lp_time))
# Out:
# Bottleneck idle for -1 units

# %%
sum(sys4.machine_data[sys4.machine_data['time'] >=0]['M1 forced idle'].fillna(0))
# Out:
# 0

# %%
sys4.machine_data[sys4.machine_data['time'] >= 0]
# Out:
#      time M0 functional M0 forced idle M1 functional M1 forced idle  \
# 500     0           NaN            NaN           NaN            NaN
# 501     1           NaN              1           NaN            NaN
# 502     2           NaN              1           NaN            NaN
# 503     3           NaN              1           NaN            NaN
# 504     4           NaN            NaN           NaN            NaN
# 505     5           NaN            NaN           NaN            NaN
# 506     6           NaN              1           NaN            NaN
# 507     7           NaN              1           NaN            NaN
# 508     8           NaN              1           NaN            NaN
# 509     9           NaN            NaN           NaN            NaN
# 510    10           NaN            NaN             0            NaN
# 511    11           NaN              1             0            NaN
# 512    12           NaN              1             0            NaN
# 513    13           NaN              1             0            NaN
# 514    14           NaN              1             0            NaN
# 515    15           NaN              1             0            NaN
# 516    16           NaN              1             0            NaN
# 517    17           NaN              1             0            NaN
# 518    18           NaN              1             0            NaN
# 519    19           NaN              1             0            NaN
# 520    20           NaN              1             0            NaN
# 521    21           NaN            NaN           NaN            NaN
# 522    22           NaN            NaN           NaN            NaN
# 523    23           NaN              1           NaN            NaN
# 524    24           NaN              1           NaN            NaN
# 525    25           NaN              1           NaN            NaN
# 526    26           NaN            NaN           NaN            NaN
# 527    27           NaN            NaN           NaN            NaN
# 528    28           NaN              1           NaN            NaN
# 529    29           NaN              1           NaN            NaN
# ..    ...           ...            ...           ...            ...
# 670   170           NaN              1           NaN            NaN
# 671   171           NaN            NaN           NaN            NaN
# 672   172           NaN            NaN           NaN            NaN
# 673   173           NaN              1           NaN            NaN
# 674   174           NaN              1           NaN            NaN
# 675   175           NaN              1           NaN            NaN
# 676   176           NaN            NaN           NaN            NaN
# 677   177           NaN            NaN           NaN            NaN
# 678   178           NaN              1           NaN            NaN
# 679   179           NaN              1           NaN            NaN
# 680   180           NaN              1           NaN            NaN
# 681   181           NaN            NaN           NaN            NaN
# 682   182           NaN            NaN           NaN            NaN
# 683   183           NaN              1           NaN            NaN
# 684   184           NaN              1           NaN            NaN
# 685   185           NaN              1           NaN            NaN
# 686   186           NaN            NaN           NaN            NaN
# 687   187           NaN            NaN           NaN            NaN
# 688   188           NaN              1           NaN            NaN
# 689   189           NaN              1           NaN            NaN
# 690   190           NaN              1           NaN            NaN
# 691   191           NaN            NaN           NaN            NaN
# 692   192           NaN            NaN           NaN            NaN
# 693   193           NaN              1           NaN            NaN
# 694   194           NaN              1           NaN            NaN
# 695   195           NaN              1           NaN            NaN
# 696   196           NaN            NaN           NaN            NaN
# 697   197           NaN            NaN           NaN            NaN
# 698   198           NaN            NaN           NaN            NaN
# 699   199           NaN            NaN           NaN            NaN
#
#     M2 functional M2 forced idle
# 500           NaN              1
# 501           NaN              1
# 502           NaN              1
# 503           NaN              1
# 504           NaN            NaN
# 505           NaN              1
# 506           NaN              1
# 507           NaN              1
# 508           NaN              1
# 509           NaN            NaN
# 510           NaN              1
# 511           NaN              1
# 512           NaN              1
# 513           NaN              1
# 514           NaN              1
# 515           NaN              1
# 516           NaN              1
# 517           NaN              1
# 518           NaN              1
# 519           NaN              1
# 520           NaN              1
# 521           NaN              1
# 522           NaN              1
# 523           NaN              1
# 524           NaN              1
# 525           NaN              1
# 526           NaN            NaN
# 527           NaN              1
# 528           NaN              1
# 529           NaN              1
# ..            ...            ...
# 670           NaN              1
# 671           NaN            NaN
# 672           NaN              1
# 673           NaN              1
# 674           NaN              1
# 675           NaN              1
# 676           NaN            NaN
# 677           NaN              1
# 678           NaN              1
# 679           NaN              1
# 680           NaN              1
# 681           NaN            NaN
# 682           NaN              1
# 683           NaN              1
# 684           NaN              1
# 685           NaN              1
# 686           NaN            NaN
# 687           NaN              1
# 688           NaN              1
# 689           NaN              1
# 690           NaN              1
# 691           NaN            NaN
# 692           NaN              1
# 693           NaN              1
# 694           NaN              1
# 695           NaN              1
# 696           NaN            NaN
# 697           NaN            NaN
# 698           NaN            NaN
# 699           NaN            NaN
#
# [200 rows x 7 columns]

# %%
sum(sys6.machine_data[sys6.machine_data['time'] >= 0]['M1 forced idle'].fillna(0))
# Out:
# 3

# %%
sys5 = System(process_times=[3, 5, 2], degradation=[0]*3, buffer_sizes=20, planned_failures=[(0,0,0)])
sys5.simulate(sim_time=1000, warmup_time=0, verbose=False)
