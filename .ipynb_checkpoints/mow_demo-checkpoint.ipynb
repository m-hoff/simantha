# %%
import maintsim
import numpy as np
import matplotlib.pyplot as plt

# %%
# serial line no maintenance
line = maintsim.SimulationParameters(
    process_times = [2, 1, 5, 3, 2],
    planned_failures = [(0, 10, 5), (1, 30, 15), (2, 60, 10)],
    sim_time = 100, warmup_time=1000)

scenario1 = maintsim.Scenario(line)

scenario1.simulate()
# Out:
#                processing time units produced       TH MTTF MTTR availability  \
# Machine 0                    2             20  0.20202  NaN  NaN           11
# Machine 1                    1             20  0.20202  NaN  NaN           11
# Machine 2                    5             20  0.20202  NaN  NaN           11
# Machine 3                    3             20  0.20202  NaN  NaN           11
# Machine 4                    2             20  0.20202  NaN  NaN           11
# System     bottleneck time = 5             20      0.2  NaN  NaN           11
#
#            avg queue time
# Machine 0             NaN
# Machine 1             NaN
# Machine 2             NaN
# Machine 3             NaN
# Machine 4             NaN
# System                NaN

# %% [markdown]
# ### Single planned failure on M0, critical downtime not exceeded

# %%
# single downtime
# serial line CM of planned failures
line = maintsim.SimulationParameters(
    process_times = [4, 2, 5, 3, 2],
    sim_time = 100,

    buffer_sizes = [2]*5,
    
    degradation = [1.]*5,
    
    maint_policy = 'CM',
    repair_dist = 'uniform',
    repair_params = [5, 15],
    queue_discipline = 'fifo',
    maint_capacity = 1,
    
    planned_failures = [(0, 50, 1)],
    
    cm_cost = 100,
    
    warmup_time = 1000)

scenario1 = maintsim.Scenario(line)

scenario1.simulate()
# Out:
# Planned downtime started on machine 0 at t=50
#                processing time units produced        TH MTTF MTTR  \
# Machine 0                    4             20   0.20202   50    1
# Machine 1                    2             20   0.20202  NaN  NaN
# Machine 2                    5             20   0.20202  NaN  NaN
# Machine 3                    3             19  0.191919  NaN  NaN
# Machine 4                    2             20   0.20202  NaN  NaN
# System     bottleneck time = 5             20       0.2   50    1
#
#           availability  avg queue time
# Machine 0        10.98          1000.0
# Machine 1           11             NaN
# Machine 2           11             NaN
# Machine 3           11             NaN
# Machine 4           11             NaN
# System          10.996          1000.0

# %%
machines = [0,2]
plt.figure(figsize=(12,8))
for i in machines:
    plt.plot(scenario1.production_data.loc[0:,'Machine {} production'.format(i)],
        label='M{}'.format(i))
plt.plot(scenario1.production_data.loc[0:,'Ideal production'])
plt.xticks(np.arange(0,101,10), np.arange(0, 101, 10))
plt.legend()
plt.grid()
plt.show()

# %%
scenario1.production_data[-20:]
# Out:
#     Machine 0 production  Machine 1 production  Machine 2 production  \
# 80                    16                    16                    16
# 81                    17                    17                    17
# 82                    17                    17                    17
# 83                    17                    17                    17
# 84                    17                    17                    17
# 85                    17                    17                    17
# 86                    18                    18                    18
# 87                    18                    18                    18
# 88                    18                    18                    18
# 89                    18                    18                    18
# 90                    18                    18                    18
# 91                    19                    19                    19
# 92                    19                    19                    19
# 93                    19                    19                    19
# 94                    19                    19                    19
# 95                    19                    19                    19
# 96                    19                    19                    19
# 97                    20                    20                    20
# 98                    20                    20                    20
# 99                    20                    20                    20
#
#     Machine 3 production  Machine 4 production  Machine 0 TH  Machine 1 TH  \
# 80                    16                    16      0.200000      0.200000
# 81                    16                    17      0.209877      0.209877
# 82                    16                    17      0.207317      0.207317
# 83                    16                    17      0.204819      0.204819
# 84                    17                    17      0.202381      0.202381
# 85                    17                    17      0.200000      0.200000
# 86                    17                    18      0.209302      0.209302
# 87                    17                    18      0.206897      0.206897
# 88                    17                    18      0.204545      0.204545
# 89                    18                    18      0.202247      0.202247
# 90                    18                    18      0.200000      0.200000
# 91                    18                    19      0.208791      0.208791
# 92                    18                    19      0.206522      0.206522
# 93                    18                    19      0.204301      0.204301
# 94                    19                    19      0.202128      0.202128
# 95                    19                    19      0.200000      0.200000
# 96                    19                    19      0.197917      0.197917
# 97                    19                    20      0.206186      0.206186
# 98                    19                    20      0.204082      0.204082
# 99                    19                    20      0.202020      0.202020
#
#     Machine 2 TH  Machine 3 TH  Machine 4 TH      ...       M1 running  \
# 80      0.200000      0.200000      0.200000      ...                1
# 81      0.209877      0.197531      0.209877      ...                1
# 82      0.207317      0.195122      0.207317      ...                1
# 83      0.204819      0.192771      0.204819      ...                1
# 84      0.202381      0.202381      0.202381      ...                1
# 85      0.200000      0.200000      0.200000      ...                1
# 86      0.209302      0.197674      0.209302      ...                1
# 87      0.206897      0.195402      0.206897      ...                1
# 88      0.204545      0.193182      0.204545      ...                1
# 89      0.202247      0.202247      0.202247      ...                1
# 90      0.200000      0.200000      0.200000      ...                1
# 91      0.208791      0.197802      0.208791      ...                1
# 92      0.206522      0.195652      0.206522      ...                1
# 93      0.204301      0.193548      0.204301      ...                1
# 94      0.202128      0.202128      0.202128      ...                1
# 95      0.200000      0.200000      0.200000      ...                1
# 96      0.197917      0.197917      0.197917      ...                1
# 97      0.206186      0.195876      0.206186      ...                1
# 98      0.204082      0.193878      0.204082      ...                1
# 99      0.202020      0.191919      0.202020      ...                1
#
#    M2 running M3 running M4 running Ideal production  M0 processing  \
# 80          1          1          1             16.0              1
# 81          1          1          1             16.2              1
# 82          1          1          1             16.4              1
# 83          1          1          1             16.6              1
# 84          1          1          1             16.8              1
# 85          1          1          1             17.0              1
# 86          1          1          1             17.2              1
# 87          1          1          1             17.4              1
# 88          1          1          1             17.6              1
# 89          1          1          1             17.8              1
# 90          1          1          1             18.0              1
# 91          1          1          1             18.2              1
# 92          1          1          1             18.4              1
# 93          1          1          1             18.6              1
# 94          1          1          1             18.8              1
# 95          1          1          1             19.0              1
# 96          1          1          1             19.2              1
# 97          1          1          1             19.4              1
# 98          1          1          1             19.6              1
# 99          1          1          1             19.8              1
#
#     M1 processing  M2 processing  M3 processing  M4 processing
# 80              1              1              1              1
# 81              1              1              1              1
# 82              1              1              1              1
# 83              1              1              1              1
# 84              1              1              1              1
# 85              1              1              1              1
# 86              1              1              1              1
# 87              1              1              1              1
# 88              1              1              1              1
# 89              1              1              1              1
# 90              1              1              1              1
# 91              1              1              1              1
# 92              1              1              1              1
# 93              1              1              1              1
# 94              1              1              1              1
# 95              1              1              1              1
# 96              1              1              1              1
# 97              1              1              1              1
# 98              1              1              1              1
# 99              1              1              1              1
#
# [20 rows x 21 columns]

# %%
scenario1.production_data.loc[85:95,'M1 pro']

# %% [markdown]
# ### Single planned failure on M0, critical downtime exceeded

# %%
# serial line CM of planned failures
line = maintsim.SimulationParameters(
    process_times = [4, 2, 5, 3, 2],
    sim_time = 100,

    buffer_sizes = [2]*5,
    
    degradation = [1.]*5,
    
    maint_policy = 'CM',
    repair_dist = 'uniform',
    repair_params = [5, 15],
    queue_discipline = 'fifo',
    maint_capacity = 1,
    
    planned_failures = [(0, 50, 30)],
    
    cm_cost = 100,
    
    warmup_time = 1000)

scenario2 = maintsim.Scenario(line)

scenario2.simulate()
# Out:
# Planned downtime started on machine 0 at t=50
#                processing time units produced        TH MTTF MTTR  \
# Machine 0                    4             14  0.141414   50   30
# Machine 1                    2             17  0.171717  NaN  NaN
# Machine 2                    5             18  0.181818  NaN  NaN
# Machine 3                    3             17  0.171717  NaN  NaN
# Machine 4                    2             18  0.181818  NaN  NaN
# System     bottleneck time = 5             18      0.18   50   30
#
#           availability  avg queue time
# Machine 0        10.69          1000.0
# Machine 1           11             NaN
# Machine 2           11             NaN
# Machine 3           11             NaN
# Machine 4           11             NaN
# System          10.938          1000.0

# %%
scenario2.maintenance_data
# Out:
#   time machine     type      activity TTF/TTR
# 0   50       0  planned       failure      50
# 1   50       0  planned  repair start    1000
# 2   51       0  planned    repair end       1

# %%
scenario2.production_data.loc[0:].tail()
# Out:
#     Machine 0 production  Machine 1 production  Machine 2 production  \
# 95                    19                    19                    19
# 96                    19                    19                    19
# 97                    20                    20                    20
# 98                    20                    20                    20
# 99                    20                    20                    20
#
#     Machine 3 production  Machine 4 production  Machine 0 TH  Machine 1 TH  \
# 95                    19                    19      0.200000      0.200000
# 96                    19                    19      0.197917      0.197917
# 97                    19                    20      0.206186      0.206186
# 98                    19                    20      0.204082      0.204082
# 99                    19                    20      0.202020      0.202020
#
#     Machine 2 TH  Machine 3 TH  Machine 4 TH M0 running M1 running M2 running  \
# 95      0.200000      0.200000      0.200000          1          1          1
# 96      0.197917      0.197917      0.197917          1          1          1
# 97      0.206186      0.195876      0.206186          1          1          1
# 98      0.204082      0.193878      0.204082          1          1          1
# 99      0.202020      0.191919      0.202020          1          1          1
#
#    M3 running M4 running  Ideal production
# 95          1          1              19.0
# 96          1          1              19.2
# 97          1          1              19.4
# 98          1          1              19.6
# 99          1          1              19.8

# %%
plt.plot(scenario2.production_data.loc[0:,['Machine {} TH'.format(i) for i in range(5)]])
plt.show()

# %%
machines = [0,2]
plt.figure(figsize=(12,8))
for i in machines:
    plt.plot(scenario2.production_data.loc[0:,'Machine {} production'.format(i)],
        label='M{}'.format(i))
plt.plot(scenario2.production_data.loc[0:,'Ideal production'])
plt.xticks(np.arange(0,101,10), np.arange(0, 101, 10))
plt.legend()
plt.grid()
plt.show()

# %%
line = maintsim.SimulationParameters(
    process_times = [4],
    sim_time = 100,

    buffer_sizes = [2],
    
    degradation = [1.],
    
    maint_policy = 'CM',
    repair_dist = 'uniform',
    repair_params = [5, 15],
    queue_discipline = 'fifo',
    maint_capacity = 1,
    
    planned_failures = [(0, 50, 20)],
    
    cm_cost = 100,
    
    warmup_time = 0)

scenario3 = maintsim.Scenario(line)

scenario3.simulate()
# Out:
# 0 50
#                processing time units produced        TH MTTF MTTR  \
# Machine 0                    4             24  0.242424  NaN  NaN
# -974                      0                     0     -0.000000     -0.000000
# -973                      0                     0     -0.000000     -0.000000
# -972                      0                     0     -0.000000     -0.000000
# -971                      0                     0     -0.000000     -0.000000
# ...                     ...                   ...           ...           ...
#  70                      14                    14      0.200000      0.200000
#  71                      14                    15      0.211268      0.211268
#  72                      14                    15      0.208333      0.208333
#  73                      14                    15      0.205479      0.205479
#  74                      15                    15      0.202703      0.202703
#  75                      15                    15      0.200000      0.200000
#  76                      15                    16      0.210526      0.210526
#  77                      15                    16      0.207792      0.207792
#  78                      15                    16      0.205128      0.205128
#  79                      16                    16      0.202532      0.202532
#  80                      16                    16      0.200000      0.200000
#  81                      16                    17      0.209877      0.209877
#  82                      16                    17      0.207317      0.207317
#  83                      16                    17      0.204819      0.204819
#  84                      17                    17      0.202381      0.202381
#  85                      17                    17      0.200000      0.200000
#  86                      17                    18      0.209302      0.209302
#  87                      17                    18      0.206897      0.206897
#  88                      17                    18      0.204545      0.204545
#  89                      18                    18      0.202247      0.202247
#  90                      18                    18      0.200000      0.200000
#  91                      18                    19      0.208791      0.208791
#  92                      18                    19      0.206522      0.206522
#  93                      18                    19      0.204301      0.204301
#  94                      19                    19      0.202128      0.202128
#  95                      19                    19      0.200000      0.200000
#  96                      19                    19      0.197917      0.197917
#  97                      19                    20      0.206186      0.206186
#  98                      19                    20      0.204082      0.204082
#  99                      19                    20      0.202020      0.202020
#
#        Machine 2 TH  Machine 3 TH  Machine 4 TH M0 running M1 running  \
# -1000     -0.000000     -0.000000     -0.000000          1          1
# -999      -0.000000     -0.000000     -0.000000          1          1
# -998      -0.000000     -0.000000     -0.000000          1          1
# -997      -0.000000     -0.000000     -0.000000          1          1
# -996      -0.000000     -0.000000     -0.000000          1          1
# -995      -0.000000     -0.000000     -0.000000          1          1
# -994      -0.000000     -0.000000     -0.000000          1          1
# -993      -0.000000     -0.000000     -0.000000          1          1
# -992      -0.000000     -0.000000     -0.000000          1          1
# -991      -0.000000     -0.000000     -0.000000          1          1
# -990      -0.000000     -0.000000     -0.000000          1          1
# -989      -0.000000     -0.000000     -0.000000          1          1
# -988      -0.000000     -0.000000     -0.000000          1          1
# -987      -0.000000     -0.000000     -0.000000          1          1
# -986      -0.000000     -0.000000     -0.000000          1          1
# -985      -0.000000     -0.000000     -0.000000          1          1
# -984      -0.000000     -0.000000     -0.000000          1          1
# -983      -0.000000     -0.000000     -0.000000          1          1
# -982      -0.000000     -0.000000     -0.000000          1          1
# -981      -0.000000     -0.000000     -0.000000          1          1
# -980      -0.000000     -0.000000     -0.000000          1          1
# -979      -0.000000     -0.000000     -0.000000          1          1
# -978      -0.000000     -0.000000     -0.000000          1          1
# -977      -0.000000     -0.000000     -0.000000          1          1
# -976      -0.000000     -0.000000     -0.000000          1          1
# -975      -0.000000     -0.000000     -0.000000          1          1
# -974      -0.000000     -0.000000     -0.000000          1          1
# -973      -0.000000     -0.000000     -0.000000          1          1
# -972      -0.000000     -0.000000     -0.000000          1          1
# -971      -0.000000     -0.000000     -0.000000          1          1
# ...             ...           ...           ...        ...        ...
#  70        0.200000      0.200000      0.200000          1          1
#  71        0.211268      0.197183      0.211268          1          1
