# %%
import random
import time

import matplotlib.pyplot as plt
import pandas as pd

from simantha import Source, Machine, Buffer, Sink, Repairman, System

random.seed(1)

# %%
random.seed(1)

degradation_matrix = [
    [0.9, 0.1, 0, 0, 0],
    [0, 0.9, 0.1, 0, 0],
    [0, 0, 0.9, 0.1, 0],
    [0, 0, 0, 0.9, 0.1],
    [0, 0, 0, 0, 1]
]

source = Source()
M1 = Machine(
    'M1', 
    cycle_time=2, 
    #degradation_matrix=degradation_matrix, 
    cbm_threshold=3,
    pm_distribution={'uniform':[5, 10]},
    cm_distribution={'uniform':[10, 20]}
)
sink = Sink()

M1.define_routing(upstream=[source], downstream=[sink])

system = System(objects=[source, M1, sink])

system.simulate(simulation_time=50, debug=True)
# Out:
# M1 getting part at t=0
# M1 processing part at t=0
# M1 processing part at t=1
# M1 putting part at t=2
# M1 getting part at t=2
# M1 processing part at t=2
# M1 processing part at t=3
# M1 putting part at t=4
# M1 getting part at t=4
# M1 processing part at t=4
# M1 processing part at t=5
# M1 putting part at t=6
# M1 getting part at t=6
# M1 processing part at t=6
# M1 processing part at t=7
# M1 putting part at t=8
# M1 getting part at t=8
# M1 processing part at t=8
# M1 processing part at t=9
# M1 putting part at t=10
# M1 getting part at t=10
# M1 processing part at t=10
# M1 processing part at t=11
# M1 putting part at t=12
# M1 getting part at t=12
# M1 processing part at t=12
# M1 processing part at t=13
# M1 putting part at t=14
# M1 getting part at t=14
# M1 processing part at t=14
# M1 processing part at t=15
# M1 putting part at t=16
# M1 getting part at t=16
# M1 processing part at t=16
# M1 processing part at t=17
# M1 putting part at t=18
# M1 getting part at t=18
# M1 processing part at t=18
# M1 processing part at t=19
# M1 putting part at t=20
# M1 getting part at t=20
# M1 processing part at t=20
# M1 processing part at t=21
# M1 putting part at t=22
# M1 getting part at t=22
# M1 processing part at t=22
# M1 processing part at t=23
# M1 putting part at t=24
# M1 getting part at t=24
# M1 processing part at t=24
# M1 processing part at t=25
# M1 putting part at t=26
# M1 getting part at t=26
# M1 processing part at t=26
# M1 processing part at t=27
# M1 putting part at t=28
# M1 getting part at t=28
# M1 processing part at t=28
# M1 processing part at t=29
# M1 putting part at t=30
# M1 getting part at t=30
# M1 processing part at t=30
# M1 processing part at t=31
# M1 putting part at t=32
# M1 getting part at t=32
# M1 processing part at t=32
# M1 processing part at t=33
# M1 putting part at t=34
# M1 getting part at t=34
# M1 processing part at t=34
# M1 processing part at t=35
# M1 putting part at t=36
# M1 getting part at t=36
# M1 processing part at t=36
# M1 processing part at t=37
# M1 putting part at t=38
# M1 getting part at t=38
# M1 processing part at t=38
# M1 processing part at t=39
# M1 putting part at t=40
# M1 getting part at t=40
# M1 processing part at t=40
# M1 processing part at t=41
# M1 putting part at t=42
# M1 getting part at t=42
# M1 processing part at t=42
# M1 processing part at t=43
# M1 putting part at t=44
# M1 getting part at t=44
# M1 processing part at t=44
# M1 processing part at t=45
# M1 putting part at t=46
# M1 getting part at t=46
# M1 processing part at t=46
# M1 processing part at t=47
# M1 putting part at t=48
# M1 getting part at t=48
# M1 processing part at t=48
# M1 processing part at t=49
# M1 putting part at t=50
# Simulation finished in 0.01s
# Parts made: 25

# %%
pd.DataFrame(M1.maintenance_data)
# Out:
# Empty DataFrame
# Columns: [event, time]
# Index: []

# %%
pd.DataFrame(M1.health_data)
# Out:
#    health  time
# 0       0     0
# 1       0    50

# %%
# 2 machine line

# old version:
# system = System(cycle_times=[1, 1], buffer_capacity=10)
# system.simulate(simulation_time=100)
# print(f'Parts made: {system.parts_made}')

random.seed(1)

degradation_matrix = [
    [0.9, 0.1, 0, 0, 0],
    [0, 0.9, 0.1, 0, 0],
    [0, 0, 0.9, 0.1, 0],
    [0, 0, 0, 0.9, 0.1],
    [0, 0, 0, 0, 1]
]

source = Source()

M1 = Machine(
    name='M1', 
    cycle_time=1, 
    degradation_matrix=degradation_matrix,
    pm_distribution={'uniform':[5, 10]},
    cm_distribution={'uniform':[30, 40]}
)
B1 = Buffer(capacity=10)
M2 = Machine(
    name='M2', 
    cycle_time=1, 
    degradation_matrix=degradation_matrix,
    pm_distribution={'uniform':[5, 10]},
    cm_distribution={'uniform':[30, 40]}
)
sink = Sink()

objects = [source, M1, B1, M2, sink]

source.define_routing(downstream=[M1])
M1.define_routing(upstream=[source], downstream=[B1])
B1.define_routing(upstream=[M1], downstream=[M2])
M2.define_routing(upstream=[B1], downstream=[sink])
sink.define_routing(upstream=[M2])

repairman = Repairman(capacity=1)

system = System(objects=objects, repairman=repairman)


system.simulate(simulation_time=100)
# Out:
# M1 getting part at t=0
# M1 processing part at t=0
# M1 putting part at t=1
# M2 getting part at t=1
# M1 getting part at t=1
# M1 processing part at t=1
# M2 processing part at t=1
# M1 putting part at t=2
# M2 putting part at t=2
# M1 getting part at t=2
# M2 getting part at t=2
# M1 processing part at t=2
# M2 processing part at t=2
# M1 putting part at t=3
# M2 putting part at t=3
# M1 getting part at t=3
# M2 getting part at t=3
# M1 processing part at t=3
# M2 processing part at t=3
# M1 putting part at t=4
# M2 putting part at t=4
# M1 getting part at t=4
# M2 getting part at t=4
# M1 processing part at t=4
# M2 processing part at t=4
# M1 putting part at t=5
# M2 putting part at t=5
# M1 getting part at t=5
# M2 getting part at t=5
# M1 processing part at t=5
# M2 processing part at t=5
# M1 putting part at t=6
# M2 putting part at t=6
# M1 getting part at t=6
# M2 getting part at t=6
# M1 processing part at t=6
# M2 processing part at t=6
# M1 putting part at t=7
# M2 putting part at t=7
# M2 getting part at t=7
# M1 getting part at t=7
# M1 processing part at t=7
# M2 processing part at t=7
# M1 putting part at t=8
# M2 putting part at t=8
# M1 getting part at t=8
# M2 getting part at t=8
# M1 processing part at t=8
# M2 processing part at t=8
# M1 putting part at t=9
# M2 putting part at t=9
# M2 getting part at t=9
# M1 getting part at t=9
# M1 processing part at t=9
# M2 processing part at t=9
# M1 putting part at t=10
# M2 putting part at t=10
# M1 getting part at t=10
# M2 getting part at t=10
# M1 processing part at t=10
# M2 processing part at t=10
# M1 putting part at t=11
# M2 putting part at t=11
# M1 getting part at t=11
# M2 getting part at t=11
# M1 processing part at t=11
# M2 processing part at t=11
# M1 putting part at t=12
# M2 putting part at t=12
# M1 getting part at t=12
# M2 getting part at t=12
# M1 processing part at t=12
# M2 processing part at t=12
# M1 putting part at t=13
# M2 putting part at t=13
# M2 getting part at t=13
# M1 getting part at t=13
# M1 processing part at t=13
# M2 processing part at t=13
# M1 putting part at t=14
# M2 putting part at t=14
# M2 getting part at t=14
# M1 getting part at t=14
# M1 processing part at t=14
# M2 processing part at t=14
# M1 putting part at t=15
# M2 putting part at t=15
# M1 getting part at t=15
# M2 getting part at t=15
# M1 processing part at t=15
# M2 processing part at t=15
# M1 putting part at t=16
# M2 putting part at t=16
# M1 getting part at t=16
# M2 getting part at t=16
# M1 processing part at t=16
# M2 processing part at t=16
# M1 putting part at t=17
# M2 putting part at t=17
# M2 getting part at t=17
# M1 getting part at t=17
# M1 processing part at t=17
# M2 processing part at t=17
# M1 putting part at t=18
# M2 putting part at t=18
# M1 getting part at t=18
# M2 getting part at t=18
# M1 processing part at t=18
# M2 processing part at t=18
# M1 putting part at t=19
# M2 putting part at t=19
# M1 getting part at t=19
# M2 getting part at t=19
# M1 processing part at t=19
# M2 processing part at t=19
# M1 putting part at t=20
# M2 putting part at t=20
# M2 getting part at t=20
# M1 getting part at t=20
# M1 processing part at t=20
# M2 processing part at t=20
# M1 putting part at t=21
# M2 putting part at t=21
# M1 getting part at t=21
# M2 getting part at t=21
# M1 processing part at t=21
# M2 processing part at t=21
# M1 putting part at t=22
# M2 putting part at t=22
# M1 getting part at t=22
# M2 getting part at t=22
# M1 processing part at t=22
# M2 processing part at t=22
# M1 putting part at t=23
# M2 putting part at t=23
# M2 getting part at t=23
# M1 getting part at t=23
# M1 processing part at t=23
# M2 processing part at t=23
# M1 putting part at t=24
# M2 putting part at t=24
# M2 getting part at t=24
# M1 getting part at t=24
# M1 processing part at t=24
# M2 processing part at t=24
# M1 putting part at t=25
# M2 putting part at t=25
# M1 getting part at t=25
# M2 getting part at t=25
# M1 processing part at t=25
# M2 processing part at t=25
# M1 putting part at t=26
# M2 putting part at t=26
# M2 getting part at t=26
# M1 getting part at t=26
# M1 processing part at t=26
# M2 processing part at t=26
# M1 putting part at t=27
# M2 putting part at t=27
# M1 getting part at t=27
# M2 getting part at t=27
# M1 processing part at t=27
# M2 processing part at t=27
# M1 putting part at t=28
# M2 putting part at t=28
# M2 getting part at t=28
# M1 getting part at t=28
# M1 processing part at t=28
# M2 processing part at t=28
# M1 putting part at t=29
# M2 putting part at t=29
# M1 getting part at t=29
# M2 getting part at t=29
# M1 processing part at t=29
# M2 processing part at t=29
# M1 putting part at t=30
# M2 putting part at t=30
# M1 getting part at t=30
# M2 getting part at t=30
# M1 processing part at t=30
# M2 processing part at t=30
# M1 putting part at t=31
# M2 putting part at t=31
# M1 getting part at t=31
# M2 getting part at t=31
# M1 processing part at t=31
# M2 processing part at t=31
# M1 putting part at t=32
# M2 putting part at t=32
# M1 getting part at t=32
# M2 getting part at t=32
# M1 processing part at t=32
# M2 processing part at t=32
# M1 putting part at t=33
# M2 putting part at t=33
# M1 getting part at t=33
# M2 getting part at t=33
# M1 processing part at t=33
# M2 processing part at t=33
# M1 putting part at t=34
# M2 putting part at t=34
# M1 getting part at t=34
# M2 getting part at t=34
# M1 processing part at t=34
# M2 processing part at t=34
# M1 putting part at t=35
# M2 putting part at t=35
# M2 getting part at t=35
# M1 getting part at t=35
# M1 processing part at t=35
# M2 processing part at t=35
# M1 putting part at t=36
# M2 putting part at t=36
# Assigning maintenence utilization at t=36
# M2 maintaining at t=36
# M2 TTR at t=36: 31
# M1 getting part at t=36
# M1 processing part at t=36
# M1 putting part at t=37
# M2 maintaining at t=37
# M1 getting part at t=37
# M1 processing part at t=37
# M1 putting part at t=38
# M2 maintaining at t=38
# M1 getting part at t=38
# M1 processing part at t=38
# M1 putting part at t=39
# M2 maintaining at t=39
# M1 getting part at t=39
# M1 processing part at t=39
# M1 putting part at t=40
# M2 maintaining at t=40
# M1 getting part at t=40
# M1 processing part at t=40
# M1 putting part at t=41
# M2 maintaining at t=41
# M1 getting part at t=41
# M1 processing part at t=41
# M1 putting part at t=42
# M2 maintaining at t=42
# M1 getting part at t=42
# M1 processing part at t=42
# M1 putting part at t=43
# M2 maintaining at t=43
# M1 getting part at t=43
# M1 processing part at t=43
# M1 putting part at t=44
# M2 maintaining at t=44
# M1 getting part at t=44
# M1 processing part at t=44
# M1 putting part at t=45
# M2 maintaining at t=45
# M1 getting part at t=45
# M1 processing part at t=45
# M1 putting part at t=46
# M2 maintaining at t=46
# M1 putting part at t=47
# M2 maintaining at t=47
# M1 putting part at t=48
# M2 maintaining at t=48
# M1 putting part at t=49
# M2 maintaining at t=49
# M1 putting part at t=50
# M2 maintaining at t=50
# M1 putting part at t=51
# M2 maintaining at t=51
# M1 putting part at t=52
# M2 maintaining at t=52
# M1 putting part at t=53
# M2 maintaining at t=53
# M1 putting part at t=54
# M2 maintaining at t=54
# M1 putting part at t=55
# M2 maintaining at t=55
# M1 putting part at t=56
# M2 maintaining at t=56
# M2 maintaining at t=57
# M2 maintaining at t=58
# M2 maintaining at t=59
# M2 maintaining at t=60
# M2 maintaining at t=61
# M2 maintaining at t=62
# M2 maintaining at t=63
# M2 maintaining at t=64
# M2 maintaining at t=65
# M2 maintaining at t=66
# M2 restored at t=67
# Releasing maintenance utilization at t=67
# Assigning maintenence utilization at t=67
# M1 maintaining at t=67
# M1 TTR at t=67: 33
# M2 getting part at t=67
# M2 processing part at t=67
# M2 putting part at t=68
# M1 maintaining at t=68
# M2 getting part at t=68
# M2 processing part at t=68
# M2 putting part at t=69
# M1 maintaining at t=69
# M2 getting part at t=69
# M2 processing part at t=69
# M2 putting part at t=70
# M1 maintaining at t=70
# M2 getting part at t=70
# M2 processing part at t=70
# M2 putting part at t=71
# M1 maintaining at t=71
# M2 getting part at t=71
# M2 processing part at t=71
# M2 putting part at t=72
# M1 maintaining at t=72
# M2 getting part at t=72
# M2 processing part at t=72
# M2 putting part at t=73
# M1 maintaining at t=73
# M2 getting part at t=73
# M2 processing part at t=73
# M2 putting part at t=74
# M1 maintaining at t=74
# M2 getting part at t=74
# M2 processing part at t=74
# M2 putting part at t=75
# M1 maintaining at t=75
# M2 getting part at t=75
# M2 processing part at t=75
# M2 putting part at t=76
# M1 maintaining at t=76
# M2 getting part at t=76
# M2 processing part at t=76
# M2 putting part at t=77
# M1 maintaining at t=77
# M1 maintaining at t=78
# M1 maintaining at t=79
# M1 maintaining at t=80
# M1 maintaining at t=81
# M1 maintaining at t=82
# M1 maintaining at t=83
# M1 maintaining at t=84
# M1 maintaining at t=85
# M1 maintaining at t=86
# M1 maintaining at t=87
# M1 maintaining at t=88
# M1 maintaining at t=89
# M1 maintaining at t=90
# M1 maintaining at t=91
# M1 maintaining at t=92
# M1 maintaining at t=93
# M1 maintaining at t=94
# M1 maintaining at t=95
# M1 maintaining at t=96
# M1 maintaining at t=97
# M1 maintaining at t=98
# M1 maintaining at t=99
# Simulation finished in 0.01s
# Parts made: 45

# %%
pd.DataFrame(M1.maintenance_data)
# Out:
#                event  time
# 0      entered queue    56
# 1            failure    56
# 2  begin maintenance    67

# %%
pd.DataFrame(M2.maintenance_data)
# Out:
#                event  time
# 0      entered queue    36
# 1            failure    36
# 2  begin maintenance    36
# 3           repaired    67

# %% [markdown]
# ### Degradation and Maintenance of a Complex System

# %%
source = Source()

cm = {'uniform': [10, 20]}

M1 = Machine('M1', cycle_time=1, degradation_matrix=degradation_matrix, cm_distribution=cm)
B1 = Buffer(capacity=10)

M2 = Machine('M2', cycle_time=3, degradation_matrix=degradation_matrix, cm_distribution=cm)
B2 = Buffer(capacity=5)
M3 = Machine('M3', cycle_time=2, degradation_matrix=degradation_matrix, cm_distribution=cm)

M4 = Machine('M4', cycle_time=1, degradation_matrix=degradation_matrix, cm_distribution=cm)
B4 = Buffer(capacity=5)
M5 = Machine('M5', cycle_time=2, degradation_matrix=degradation_matrix, cm_distribution=cm)
M6 = Machine('M6', cycle_time=2, degradation_matrix=degradation_matrix, cm_distribution=cm)
B5 = Buffer(capacity=5)
M7 = Machine('M7', cycle_time=3, degradation_matrix=degradation_matrix, cm_distribution=cm)

sink = Sink()

source.define_routing(downstream=[M1])

M1.define_routing(upstream=[source], downstream=[B1])
B1.define_routing(upstream=[M1], downstream=[M2, M4])

M2.define_routing(upstream=[B1], downstream=[B2])
B2.define_routing(upstream=[M2], downstream=[M3])
M3.define_routing(upstream=[B2], downstream=[sink])

M4.define_routing(upstream=[B1], downstream=[B4])
B4.define_routing(upstream=[M4], downstream=[M5, M6])
M5.define_routing(upstream=[B4], downstream=[B5])
M6.define_routing(upstream=[B4], downstream=[B5])
B5.define_routing(upstream=[M5, M6], downstream=[M7])
M7.define_routing(upstream=[B5], downstream=[sink])

sink.define_routing(upstream=[M3, M7])

objects = [source, M1, M2, M3, M4, M5, M6, M7, B1, B2, B4, B5, sink]

repairman = Repairman(capacity=1)

system = System(objects=objects, repairman=repairman)

system.simulate(simulation_time=7*24*60)
# Out:
# M1 getting part at t=0
# M1 processing part at t=0
# M1 putting part at t=1
# M2 getting part at t=1
# M1 getting part at t=1
# M1 processing part at t=1
# M2 processing part at t=1
# M1 putting part at t=2
# M4 getting part at t=2
# M1 getting part at t=2
# M1 processing part at t=2
# M2 processing part at t=2
# M4 processing part at t=2
# M1 putting part at t=3
# M4 putting part at t=3
# M6 getting part at t=3
# M1 getting part at t=3
# M4 getting part at t=3
# M1 processing part at t=3
# M2 processing part at t=3
# M4 processing part at t=3
# M6 processing part at t=3
# M1 putting part at t=4
# M2 putting part at t=4
# M4 putting part at t=4
# M5 getting part at t=4
# M2 getting part at t=4
# M3 getting part at t=4
# M1 getting part at t=4
# M1 processing part at t=4
# M2 processing part at t=4
# M3 processing part at t=4
# M5 processing part at t=4
# M6 processing part at t=4
# M1 putting part at t=5
# M6 putting part at t=5
# M7 getting part at t=5
# M1 getting part at t=5
# M4 getting part at t=5
# M1 processing part at t=5
# M2 processing part at t=5
# M3 processing part at t=5
# M4 processing part at t=5
# M5 processing part at t=5
# M7 processing part at t=5
# M1 putting part at t=6
# M3 putting part at t=6
# M4 putting part at t=6
# M5 putting part at t=6
# M4 getting part at t=6
# M1 getting part at t=6
# M5 getting part at t=6
# M1 processing part at t=6
# M2 processing part at t=6
# M4 processing part at t=6
# M5 processing part at t=6
# M7 processing part at t=6
# M1 putting part at t=7
# M2 putting part at t=7
# M4 putting part at t=7
# M2 getting part at t=7
# M6 getting part at t=7
# M3 getting part at t=7
# M1 getting part at t=7
# M1 processing part at t=7
# M2 processing part at t=7
# M3 processing part at t=7
# M5 processing part at t=7
# M6 processing part at t=7
# M7 processing part at t=7
# M1 putting part at t=8
# M5 putting part at t=8
# M7 putting part at t=8
# M4 getting part at t=8
# M7 getting part at t=8
# M1 getting part at t=8
# M1 processing part at t=8
# M2 processing part at t=8
# M3 processing part at t=8
# M4 processing part at t=8
# M6 processing part at t=8
# M7 processing part at t=8
# M1 putting part at t=9
# M3 putting part at t=9
# M4 putting part at t=9
# M6 putting part at t=9
# M1 getting part at t=9
# M4 getting part at t=9
# M6 getting part at t=9
# M1 processing part at t=9
# M2 processing part at t=9
# M4 processing part at t=9
# M6 processing part at t=9
# M7 processing part at t=9
# M1 putting part at t=10
# M2 putting part at t=10
# M4 putting part at t=10
# M3 getting part at t=10
# M4 getting part at t=10
# M5 getting part at t=10
# M1 getting part at t=10
# M1 processing part at t=10
# M3 processing part at t=10
# M4 processing part at t=10
# M5 processing part at t=10
# M6 processing part at t=10
# M7 processing part at t=10
# M1 putting part at t=11
# M4 putting part at t=11
# M6 putting part at t=11
# M7 putting part at t=11
# M1 getting part at t=11
# M6 getting part at t=11
# M7 getting part at t=11
# M4 getting part at t=11
# M1 processing part at t=11
# M3 processing part at t=11
# M4 processing part at t=11
# M5 processing part at t=11
# M6 processing part at t=11
# M7 processing part at t=11
# M1 putting part at t=12
# M3 putting part at t=12
# M4 putting part at t=12
# M5 putting part at t=12
# M4 getting part at t=12
# M1 getting part at t=12
# M5 getting part at t=12
# M1 processing part at t=12
# M4 processing part at t=12
# M5 processing part at t=12
# M6 processing part at t=12
# M7 processing part at t=12
# M1 putting part at t=13
# M4 putting part at t=13
# M6 putting part at t=13
# M1 getting part at t=13
# M2 getting part at t=13
# M6 getting part at t=13
# M1 processing part at t=13
# M2 processing part at t=13
# M5 processing part at t=13
# M6 processing part at t=13
# M7 processing part at t=13
# M1 putting part at t=14
# M5 putting part at t=14
# M7 putting part at t=14
# M7 getting part at t=14
# M1 getting part at t=14
# M4 getting part at t=14
# M1 processing part at t=14
# M2 processing part at t=14
# M4 processing part at t=14
# M6 processing part at t=14
# M7 processing part at t=14
# M1 putting part at t=15
# M4 putting part at t=15
# M6 putting part at t=15
# Assigning maintenence utilization at t=15
# M5 maintaining at t=15
# M5 TTR at t=15: 12
# M1 getting part at t=15
# M4 getting part at t=15
# M6 getting part at t=15
# M1 processing part at t=15
# M2 processing part at t=15
# M4 processing part at t=15
# M6 processing part at t=15
# M7 processing part at t=15
# M1 putting part at t=16
# M2 putting part at t=16
# M4 putting part at t=16
# M5 maintaining at t=16
# M1 getting part at t=16
# M3 getting part at t=16
# M2 getting part at t=16
# M1 processing part at t=16
# M2 processing part at t=16
# M3 processing part at t=16
# M6 processing part at t=16
# M7 processing part at t=16
# M1 putting part at t=17
# M6 putting part at t=17
# M7 putting part at t=17
# M5 maintaining at t=17
# M7 getting part at t=17
# M4 getting part at t=17
# M1 getting part at t=17
# M1 processing part at t=17
# M2 processing part at t=17
# M3 processing part at t=17
# M4 processing part at t=17
# M7 processing part at t=17
# M1 putting part at t=18
# M3 putting part at t=18
# M4 putting part at t=18
# M6 putting part at t=18
# M5 maintaining at t=18
# M6 getting part at t=18
# M4 getting part at t=18
# M1 getting part at t=18
# M1 processing part at t=18
# M2 processing part at t=18
# M4 processing part at t=18
# M6 processing part at t=18
# M7 processing part at t=18
# M1 putting part at t=19
# M2 putting part at t=19
# M4 putting part at t=19
# M5 maintaining at t=19
# M3 getting part at t=19
# M4 getting part at t=19
# M1 getting part at t=19
# M1 processing part at t=19
# M3 processing part at t=19
# M4 processing part at t=19
# M6 processing part at t=19
# M7 processing part at t=19
# M1 putting part at t=20
# M4 putting part at t=20
# M6 putting part at t=20
# M7 putting part at t=20
# M5 maintaining at t=20
# M7 getting part at t=20
# M1 getting part at t=20
# M4 getting part at t=20
# M1 processing part at t=20
# M3 processing part at t=20
# M4 processing part at t=20
# M7 processing part at t=20
# M1 putting part at t=21
# M3 putting part at t=21
# M4 putting part at t=21
# M6 putting part at t=21
# M5 maintaining at t=21
# M6 getting part at t=21
# M4 getting part at t=21
# M1 getting part at t=21
# M1 processing part at t=21
# M4 processing part at t=21
# M6 processing part at t=21
# M7 processing part at t=21
# M1 putting part at t=22
# M4 putting part at t=22
# M5 maintaining at t=22
# M4 getting part at t=22
# M1 getting part at t=22
# M1 processing part at t=22
# M4 processing part at t=22
# M6 processing part at t=22
# M1 putting part at t=23
# M4 putting part at t=23
# M6 putting part at t=23
# M5 maintaining at t=23
# M4 getting part at t=23
# M1 getting part at t=23
# M1 processing part at t=23
# M4 processing part at t=23
# M1 putting part at t=24
# M4 putting part at t=24
# M5 maintaining at t=24
# M1 getting part at t=24
# M1 processing part at t=24
# M1 putting part at t=25
# M4 putting part at t=25
# M5 maintaining at t=25
# M1 getting part at t=25
# M1 processing part at t=25
# M1 putting part at t=26
# M4 putting part at t=26
# M5 maintaining at t=26
# M1 getting part at t=26
# M1 processing part at t=26
# M1 putting part at t=27
# M4 putting part at t=27
# M5 restored at t=27
# Releasing maintenance utilization at t=27
# Assigning maintenence utilization at t=27
# M2 maintaining at t=27
# M2 TTR at t=27: 17
# M5 getting part at t=27
# M1 getting part at t=27
# M1 processing part at t=27
# M5 processing part at t=27
# M1 putting part at t=28
# M4 putting part at t=28
# M2 maintaining at t=28
# M4 getting part at t=28
# M1 getting part at t=28
# M1 processing part at t=28
# M4 processing part at t=28
# M5 processing part at t=28
# M1 putting part at t=29
# M4 putting part at t=29
# M5 putting part at t=29
# M2 maintaining at t=29
# M1 getting part at t=29
# M1 processing part at t=29
# M1 putting part at t=30
# M4 putting part at t=30
# M5 putting part at t=30
# M2 maintaining at t=30
# M1 getting part at t=30
# M1 processing part at t=30
# M1 putting part at t=31
# M4 putting part at t=31
# M5 putting part at t=31
# M2 maintaining at t=31
# M1 getting part at t=31
# M1 processing part at t=31
# M1 putting part at t=32
# M4 putting part at t=32
# M5 putting part at t=32
# M2 maintaining at t=32
# M1 getting part at t=32
# M1 processing part at t=32
# M1 putting part at t=33
# M4 putting part at t=33
# M5 putting part at t=33
# M2 maintaining at t=33
# M1 getting part at t=33
# M1 processing part at t=33
# M1 putting part at t=34
# M4 putting part at t=34
# M5 putting part at t=34
# M2 maintaining at t=34
# M1 getting part at t=34
# M1 processing part at t=34
# M1 putting part at t=35
# M4 putting part at t=35
# M5 putting part at t=35
# M2 maintaining at t=35
# M1 putting part at t=36
# M4 putting part at t=36
# M5 putting part at t=36
# M2 maintaining at t=36
# M1 putting part at t=37
# M4 putting part at t=37
# M5 putting part at t=37
# M2 maintaining at t=37
# M1 putting part at t=38
# M4 putting part at t=38
# M5 putting part at t=38
# M2 maintaining at t=38
# M1 putting part at t=39
# M4 putting part at t=39
# M5 putting part at t=39
# M2 maintaining at t=39
# M1 putting part at t=40
# M4 putting part at t=40
# M5 putting part at t=40
# M2 maintaining at t=40
# M1 putting part at t=41
# M4 putting part at t=41
# M5 putting part at t=41
# M2 maintaining at t=41
# M1 putting part at t=42
# M4 putting part at t=42
# M5 putting part at t=42
# M2 maintaining at t=42
# M1 putting part at t=43
# M4 putting part at t=43
# M5 putting part at t=43
# M2 maintaining at t=43
# M1 putting part at t=44
# M4 putting part at t=44
# M5 putting part at t=44
# M2 restored at t=44
# Releasing maintenance utilization at t=44
# Assigning maintenence utilization at t=44
# M3 maintaining at t=44
# M3 TTR at t=44: 19
# M2 getting part at t=44
# M2 processing part at t=44
# M1 putting part at t=45
# M4 putting part at t=45
# M5 putting part at t=45
# M3 maintaining at t=45
# M1 getting part at t=45
# M1 processing part at t=45
# M2 processing part at t=45
# M1 putting part at t=46
# M4 putting part at t=46
# M5 putting part at t=46
# M3 maintaining at t=46
# M2 processing part at t=46
# M1 putting part at t=47
# M2 putting part at t=47
# M4 putting part at t=47
# M5 putting part at t=47
# M3 maintaining at t=47
# M2 getting part at t=47
# M2 processing part at t=47
# M1 putting part at t=48
# M4 putting part at t=48
# M5 putting part at t=48
# M3 maintaining at t=48
# M1 getting part at t=48
# M1 processing part at t=48
# M2 processing part at t=48
# M1 putting part at t=49
# M4 putting part at t=49
# M5 putting part at t=49
# M3 maintaining at t=49
# M2 processing part at t=49
# M1 putting part at t=50
# M2 putting part at t=50
# M4 putting part at t=50
# M5 putting part at t=50
# M3 maintaining at t=50
# M2 getting part at t=50
# M2 processing part at t=50
# M1 putting part at t=51
# M4 putting part at t=51
# M5 putting part at t=51
# M3 maintaining at t=51
# M1 getting part at t=51
# M1 processing part at t=51
# M2 processing part at t=51
# M1 putting part at t=52
# M4 putting part at t=52
# M5 putting part at t=52
# M3 maintaining at t=52
# M2 processing part at t=52
# M1 putting part at t=53
# M2 putting part at t=53
# M4 putting part at t=53
# M5 putting part at t=53
# M3 maintaining at t=53
# M2 getting part at t=53
# M2 processing part at t=53
# M1 putting part at t=54
# M4 putting part at t=54
# M5 putting part at t=54
# M3 maintaining at t=54
# M2 processing part at t=54
# M4 putting part at t=55
# M5 putting part at t=55
# M3 maintaining at t=55
# M2 processing part at t=55
# M2 putting part at t=56
# M4 putting part at t=56
# M5 putting part at t=56
# M3 maintaining at t=56
# M2 getting part at t=56
# M2 processing part at t=56
# M4 putting part at t=57
# M5 putting part at t=57
# M3 maintaining at t=57
# M2 processing part at t=57
# M4 putting part at t=58
# M5 putting part at t=58
# M3 maintaining at t=58
# M2 processing part at t=58
# M2 putting part at t=59
# M4 putting part at t=59
# M5 putting part at t=59
# M3 maintaining at t=59
# M2 getting part at t=59
# M2 processing part at t=59
# M4 putting part at t=60
# M5 putting part at t=60
# M3 maintaining at t=60
# M2 processing part at t=60
# M4 putting part at t=61
# M5 putting part at t=61
# M3 maintaining at t=61
# M2 processing part at t=61
# M2 putting part at t=62
# M4 putting part at t=62
# M5 putting part at t=62
# M3 maintaining at t=62
# M2 putting part at t=63
# M4 putting part at t=63
# M5 putting part at t=63
# M3 restored at t=63
# Releasing maintenance utilization at t=63
# Assigning maintenence utilization at t=63
# M7 maintaining at t=63
# M7 TTR at t=63: 13
# M3 getting part at t=63
# M3 processing part at t=63
# M2 putting part at t=64
# M4 putting part at t=64
# M5 putting part at t=64
# M7 maintaining at t=64
# M2 getting part at t=64
# M2 processing part at t=64
# M3 processing part at t=64
# M3 putting part at t=65
# M4 putting part at t=65
# M5 putting part at t=65
# M7 maintaining at t=65
# M3 getting part at t=65
# M2 processing part at t=65
# M3 processing part at t=65
# M4 putting part at t=66
# M7 maintaining at t=66
# M3 processing part at t=66
# M3 putting part at t=67
# M4 putting part at t=67
# M7 maintaining at t=67
# M3 getting part at t=67
# M3 processing part at t=67
# M4 putting part at t=68
# M7 maintaining at t=68
# M3 processing part at t=68
# M3 putting part at t=69
# M4 putting part at t=69
# M7 maintaining at t=69
# M3 getting part at t=69
# M3 processing part at t=69
# M4 putting part at t=70
# M7 maintaining at t=70
# M3 processing part at t=70
# M3 putting part at t=71
# M4 putting part at t=71
# M7 maintaining at t=71
# M3 getting part at t=71
# M3 processing part at t=71
# M7 maintaining at t=72
# M3 processing part at t=72
# M3 putting part at t=73
# M7 maintaining at t=73
# M3 getting part at t=73
# M3 processing part at t=73
# M7 maintaining at t=74
# M3 processing part at t=74
# M3 putting part at t=75
# M7 maintaining at t=75
# M7 restored at t=76
# Releasing maintenance utilization at t=76
# Assigning maintenence utilization at t=76
# M6 maintaining at t=76
# M6 TTR at t=76: 20
# M7 getting part at t=76
# M7 processing part at t=76
# M6 maintaining at t=77
# M7 processing part at t=77
# M6 maintaining at t=78
# M7 processing part at t=78
# M7 putting part at t=79
# M6 maintaining at t=79
# M7 getting part at t=79
# M7 processing part at t=79
# M6 maintaining at t=80
# M7 processing part at t=80
# M6 maintaining at t=81
# M7 processing part at t=81
# M7 putting part at t=82
# M6 maintaining at t=82
# M7 getting part at t=82
# M7 processing part at t=82
# M6 maintaining at t=83
# M7 processing part at t=83
# M6 maintaining at t=84
# M7 processing part at t=84
# M7 putting part at t=85
# M6 maintaining at t=85
# M7 getting part at t=85
# M7 processing part at t=85
# M6 maintaining at t=86
# M7 processing part at t=86
# M6 maintaining at t=87
# M7 processing part at t=87
# M7 putting part at t=88
# M6 maintaining at t=88
# M7 getting part at t=88
# M7 processing part at t=88
# M6 maintaining at t=89
# M7 processing part at t=89
# M6 maintaining at t=90
# M7 processing part at t=90
# M7 putting part at t=91
# M6 maintaining at t=91
# M6 maintaining at t=92
# M6 maintaining at t=93
# M6 maintaining at t=94
# M6 maintaining at t=95
# M6 restored at t=96
# Releasing maintenance utilization at t=96
# Assigning maintenence utilization at t=96
# M1 maintaining at t=96
# M1 TTR at t=96: 20
# M6 getting part at t=96
# M6 processing part at t=96
# M1 maintaining at t=97
# M6 processing part at t=97
# M6 putting part at t=98
# M1 maintaining at t=98
# M6 getting part at t=98
# M6 processing part at t=98
# M1 maintaining at t=99
# M6 processing part at t=99
# M6 putting part at t=100
# M1 maintaining at t=100
# M6 getting part at t=100
# M6 processing part at t=100
# M1 maintaining at t=101
# M6 processing part at t=101
# M6 putting part at t=102
# M1 maintaining at t=102
# M6 getting part at t=102
# M6 processing part at t=102
# M1 maintaining at t=103
# M6 processing part at t=103
# M6 putting part at t=104
# M1 maintaining at t=104
# M6 getting part at t=104
# M6 processing part at t=104
# M1 maintaining at t=105
# M6 processing part at t=105
# M6 putting part at t=106
# M1 maintaining at t=106
# M1 maintaining at t=107
# M1 maintaining at t=108
# M1 maintaining at t=109
# M1 maintaining at t=110
# M1 maintaining at t=111
# M1 maintaining at t=112
# M1 maintaining at t=113
# M1 maintaining at t=114
# M1 maintaining at t=115
# M1 restored at t=116
# Releasing maintenance utilization at t=116
# Assigning maintenence utilization at t=116
# M5 maintaining at t=116
# M5 TTR at t=116: 14
# M1 getting part at t=116
# M1 processing part at t=116
# M1 putting part at t=117
# M5 maintaining at t=117
# M1 getting part at t=117
# M1 processing part at t=117
# M1 putting part at t=118
# M5 maintaining at t=118
# M1 getting part at t=118
# M1 processing part at t=118
# M1 putting part at t=119
# M5 maintaining at t=119
# M1 getting part at t=119
# M1 processing part at t=119
# M1 putting part at t=120
# M5 maintaining at t=120
# M1 putting part at t=121
# M5 maintaining at t=121
# M1 putting part at t=122
# M5 maintaining at t=122
# M1 putting part at t=123
# M5 maintaining at t=123
# M1 putting part at t=124
# M5 maintaining at t=124
# M1 putting part at t=125
# M5 maintaining at t=125
# M1 putting part at t=126
# M5 maintaining at t=126
# M1 putting part at t=127
# M5 maintaining at t=127
# M1 putting part at t=128
# M5 maintaining at t=128
# M1 putting part at t=129
# M5 maintaining at t=129
# M1 putting part at t=130
# M5 restored at t=130
# Releasing maintenance utilization at t=130
# Assigning maintenence utilization at t=130
# M2 maintaining at t=130
# M2 TTR at t=130: 19
# M1 putting part at t=131
# M2 maintaining at t=131
# M1 putting part at t=132
# M2 maintaining at t=132
# M1 putting part at t=133
# M2 maintaining at t=133
# M1 putting part at t=134
# M2 maintaining at t=134
# M1 putting part at t=135
# M2 maintaining at t=135
# M1 putting part at t=136
# M2 maintaining at t=136
# M1 putting part at t=137
# M2 maintaining at t=137
# M1 putting part at t=138
# M2 maintaining at t=138
# M1 putting part at t=139
# M2 maintaining at t=139
# M1 putting part at t=140
# M2 maintaining at t=140
# M1 putting part at t=141
# M2 maintaining at t=141
# M1 putting part at t=142
# M2 maintaining at t=142
# M1 putting part at t=143
# M2 maintaining at t=143
# M1 putting part at t=144
# M2 maintaining at t=144
# M1 putting part at t=145
# M2 maintaining at t=145
# M1 putting part at t=146
# M2 maintaining at t=146
# M1 putting part at t=147
# M2 maintaining at t=147
# M1 putting part at t=148
# M2 maintaining at t=148
# M1 putting part at t=149
# M2 restored at t=149
# Releasing maintenance utilization at t=149
# Assigning maintenence utilization at t=149
# M4 maintaining at t=149
# M4 TTR at t=149: 16
# M2 getting part at t=149
# M2 processing part at t=149
# M1 putting part at t=150
# M4 maintaining at t=150
# M1 getting part at t=150
# M1 processing part at t=150
# M2 processing part at t=150
# M1 putting part at t=151
# M4 maintaining at t=151
# M2 processing part at t=151
# M1 putting part at t=152
# M2 putting part at t=152
# M4 maintaining at t=152
# M2 getting part at t=152
# M2 processing part at t=152
# M1 putting part at t=153
# M4 maintaining at t=153
# M1 getting part at t=153
# M1 processing part at t=153
# M2 processing part at t=153
# M1 putting part at t=154
# M4 maintaining at t=154
# M2 processing part at t=154
# M1 putting part at t=155
# M2 putting part at t=155
# M4 maintaining at t=155
# M2 getting part at t=155
# M2 processing part at t=155
# M1 putting part at t=156
# M4 maintaining at t=156
# M1 getting part at t=156
# M1 processing part at t=156
# M2 processing part at t=156
# M1 putting part at t=157
# M4 maintaining at t=157
# M2 processing part at t=157
# M1 putting part at t=158
# M2 putting part at t=158
# M4 maintaining at t=158
# M2 getting part at t=158
# M2 processing part at t=158
# M4 maintaining at t=159
# M2 processing part at t=159
# M4 maintaining at t=160
# M2 processing part at t=160
# M2 putting part at t=161
# M4 maintaining at t=161
# M2 getting part at t=161
# M2 processing part at t=161
# M4 maintaining at t=162
# M2 processing part at t=162
# M4 maintaining at t=163
# M2 processing part at t=163
# M2 putting part at t=164
# M4 maintaining at t=164
# M2 getting part at t=164
# M2 processing part at t=164
# M4 restored at t=165
# Releasing maintenance utilization at t=165
# Assigning maintenence utilization at t=165
# M7 maintaining at t=165
# M7 TTR at t=165: 15
# M4 getting part at t=165
# M2 processing part at t=165
# M4 processing part at t=165
# M4 putting part at t=166
# M7 maintaining at t=166
# M4 getting part at t=166
# M5 getting part at t=166
# M2 processing part at t=166
# M4 processing part at t=166
# M5 processing part at t=166
# M2 putting part at t=167
# M4 putting part at t=167
# M7 maintaining at t=167
# M4 getting part at t=167
# M4 processing part at t=167
# M5 processing part at t=167
# M2 putting part at t=168
# M4 putting part at t=168
# M5 putting part at t=168
# M7 maintaining at t=168
# M4 getting part at t=168
# M4 processing part at t=168
# M2 putting part at t=169
# M4 putting part at t=169
# M5 putting part at t=169
# M7 maintaining at t=169
# M4 getting part at t=169
# M4 processing part at t=169
# M2 putting part at t=170
# M4 putting part at t=170
# M5 putting part at t=170
# M7 maintaining at t=170
# M4 getting part at t=170
# M4 processing part at t=170
# M2 putting part at t=171
# M4 putting part at t=171
# M5 putting part at t=171
# M7 maintaining at t=171
# M4 getting part at t=171
# M4 processing part at t=171
# M2 putting part at t=172
# M4 putting part at t=172
# M5 putting part at t=172
# M7 maintaining at t=172
# M2 putting part at t=173
# M4 putting part at t=173
# M5 putting part at t=173
# M7 maintaining at t=173
# M4 putting part at t=174
# M5 putting part at t=174
# M7 maintaining at t=174
# M4 putting part at t=175
# M5 putting part at t=175
# M7 maintaining at t=175
# M4 putting part at t=176
# M5 putting part at t=176
# M7 maintaining at t=176
# M4 putting part at t=177
# M5 putting part at t=177
# M7 maintaining at t=177
# M4 putting part at t=178
# M5 putting part at t=178
# M7 maintaining at t=178
# M4 putting part at t=179
# M7 maintaining at t=179
# M4 putting part at t=180
# M7 restored at t=180
# Releasing maintenance utilization at t=180
# Assigning maintenence utilization at t=180
# M3 maintaining at t=180
# M3 TTR at t=180: 19
# M7 getting part at t=180
# M7 processing part at t=180
# M4 putting part at t=181
# M3 maintaining at t=181
# M7 processing part at t=181
# M4 putting part at t=182
# M3 maintaining at t=182
# M7 processing part at t=182
# M4 putting part at t=183
# M7 putting part at t=183
# M3 maintaining at t=183
# M7 getting part at t=183
# M7 processing part at t=183
# M4 putting part at t=184
# M3 maintaining at t=184
# M7 processing part at t=184
# M4 putting part at t=185
# M3 maintaining at t=185
# M7 processing part at t=185
# M4 putting part at t=186
# M7 putting part at t=186
# M3 maintaining at t=186
# M7 getting part at t=186
# M7 processing part at t=186
# M4 putting part at t=187
# M3 maintaining at t=187
# M7 processing part at t=187
# M4 putting part at t=188
# M3 maintaining at t=188
# M7 processing part at t=188
# M4 putting part at t=189
# M7 putting part at t=189
# M3 maintaining at t=189
# M7 getting part at t=189
# M7 processing part at t=189
# M4 putting part at t=190
# M3 maintaining at t=190
# M7 processing part at t=190
# M4 putting part at t=191
# M3 maintaining at t=191
# M7 processing part at t=191
# M4 putting part at t=192
# M7 putting part at t=192
# M3 maintaining at t=192
# M7 getting part at t=192
# M7 processing part at t=192
# M4 putting part at t=193
# M3 maintaining at t=193
# M7 processing part at t=193
# M4 putting part at t=194
# M3 maintaining at t=194
# M7 processing part at t=194
# M4 putting part at t=195
# M7 putting part at t=195
# M3 maintaining at t=195
# M4 putting part at t=196
# M3 maintaining at t=196
# M4 putting part at t=197
# M3 maintaining at t=197
# M4 putting part at t=198
# M3 maintaining at t=198
# M4 putting part at t=199
# M3 restored at t=199
# Releasing maintenance utilization at t=199
# Assigning maintenence utilization at t=199
# M6 maintaining at t=199
# M6 TTR at t=199: 20
# M3 getting part at t=199
# M3 processing part at t=199
# M4 putting part at t=200
# M6 maintaining at t=200
# M3 processing part at t=200
# M3 putting part at t=201
# M4 putting part at t=201
# M6 maintaining at t=201
# M3 getting part at t=201
# M3 processing part at t=201
# M4 putting part at t=202
# M6 maintaining at t=202
# M3 processing part at t=202
# M3 putting part at t=203
# M4 putting part at t=203
# M6 maintaining at t=203
# M3 getting part at t=203
# M3 processing part at t=203
# M4 putting part at t=204
# M6 maintaining at t=204
# M3 processing part at t=204
# M3 putting part at t=205
# M4 putting part at t=205
# M6 maintaining at t=205
# M3 getting part at t=205
# M3 processing part at t=205
# M4 putting part at t=206
# M6 maintaining at t=206
# M3 processing part at t=206
# M3 putting part at t=207
# M4 putting part at t=207
# M6 maintaining at t=207
# M3 getting part at t=207
# M3 processing part at t=207
# M4 putting part at t=208
# M6 maintaining at t=208
# M3 processing part at t=208
# M3 putting part at t=209
# M4 putting part at t=209
# M6 maintaining at t=209
# M4 putting part at t=210
# M6 maintaining at t=210
# M4 putting part at t=211
# M6 maintaining at t=211
# M4 putting part at t=212
# M6 maintaining at t=212
# M4 putting part at t=213
# M6 maintaining at t=213
# M6 maintaining at t=214
# M6 maintaining at t=215
# M6 maintaining at t=216
# M6 maintaining at t=217
# M6 maintaining at t=218
# M6 restored at t=219
# Releasing maintenance utilization at t=219
# Assigning maintenence utilization at t=219
# M1 maintaining at t=219
# M1 TTR at t=219: 17
# M6 getting part at t=219
# M6 processing part at t=219
# M1 maintaining at t=220
# M6 processing part at t=220
# M6 putting part at t=221
# M1 maintaining at t=221
# M7 getting part at t=221
# M6 getting part at t=221
# M6 processing part at t=221
# M7 processing part at t=221
# M1 maintaining at t=222
# M6 processing part at t=222
# M7 processing part at t=222
# M6 putting part at t=223
# M1 maintaining at t=223
# M6 getting part at t=223
# M6 processing part at t=223
# M7 processing part at t=223
# M7 putting part at t=224
# M1 maintaining at t=224
# M7 getting part at t=224
# M6 processing part at t=224
# M7 processing part at t=224
# M6 putting part at t=225
# M1 maintaining at t=225
# M6 getting part at t=225
# M6 processing part at t=225
# M7 processing part at t=225
# M1 maintaining at t=226
# M6 processing part at t=226
# M7 processing part at t=226
# M6 putting part at t=227
# M7 putting part at t=227
# M1 maintaining at t=227
# M6 getting part at t=227
# M7 getting part at t=227
# M6 processing part at t=227
# M7 processing part at t=227
# M1 maintaining at t=228
# M6 processing part at t=228
# M7 processing part at t=228
# M6 putting part at t=229
# M1 maintaining at t=229
# M7 processing part at t=229
# M7 putting part at t=230
# M1 maintaining at t=230
# M7 getting part at t=230
# M7 processing part at t=230
# M1 maintaining at t=231
# M7 processing part at t=231
# M1 maintaining at t=232
# M7 processing part at t=232
# M7 putting part at t=233
# M1 maintaining at t=233
# M1 maintaining at t=234
# M1 maintaining at t=235
# M1 restored at t=236
# Releasing maintenance utilization at t=236
# Assigning maintenence utilization at t=236
# M2 maintaining at t=236
# M2 TTR at t=236: 15
# M1 getting part at t=236
# M1 processing part at t=236
# M1 putting part at t=237
# M2 maintaining at t=237
# M1 getting part at t=237
# M1 processing part at t=237
# M1 putting part at t=238
# M2 maintaining at t=238
# M1 getting part at t=238
# M1 processing part at t=238
# M1 putting part at t=239
# M2 maintaining at t=239
# M1 getting part at t=239
# M1 processing part at t=239
# M1 putting part at t=240
# M2 maintaining at t=240
# M1 getting part at t=240
# M1 processing part at t=240
# M1 putting part at t=241
# M2 maintaining at t=241
# M1 getting part at t=241
# M1 processing part at t=241
# M1 putting part at t=242
# M2 maintaining at t=242
# M1 getting part at t=242
# M1 processing part at t=242
# M1 putting part at t=243
# M2 maintaining at t=243
# M1 getting part at t=243
# M1 processing part at t=243
# M1 putting part at t=244
# M2 maintaining at t=244
# M1 getting part at t=244
# M1 processing part at t=244
# M1 putting part at t=245
# M2 maintaining at t=245
# M1 getting part at t=245
# M1 processing part at t=245
# M1 putting part at t=246
# M2 maintaining at t=246
# M1 getting part at t=246
# M1 processing part at t=246
# M1 putting part at t=247
# M2 maintaining at t=247
# M1 putting part at t=248
# M2 maintaining at t=248
# M1 putting part at t=249
# M2 maintaining at t=249
# M1 putting part at t=250
# M2 maintaining at t=250
# M1 putting part at t=251
# M2 restored at t=251
# Releasing maintenance utilization at t=251
# Assigning maintenence utilization at t=251
# M5 maintaining at t=251
# M5 TTR at t=251: 20
# M2 getting part at t=251
# M2 processing part at t=251
# M1 putting part at t=252
# M5 maintaining at t=252
# M1 getting part at t=252
# M1 processing part at t=252
# M2 processing part at t=252
# M1 putting part at t=253
# M5 maintaining at t=253
# M2 processing part at t=253
# M1 putting part at t=254
# M2 putting part at t=254
# M5 maintaining at t=254
# M2 getting part at t=254
# M2 processing part at t=254
# M1 putting part at t=255
# M5 maintaining at t=255
# M1 getting part at t=255
# M1 processing part at t=255
# M2 processing part at t=255
# M1 putting part at t=256
# M5 maintaining at t=256
# M2 processing part at t=256
# M1 putting part at t=257
# M2 putting part at t=257
# M5 maintaining at t=257
# M2 getting part at t=257
# M2 processing part at t=257
# M1 putting part at t=258
# M5 maintaining at t=258
# M1 getting part at t=258
# M1 processing part at t=258
# M2 processing part at t=258
# M1 putting part at t=259
# M5 maintaining at t=259
# M2 processing part at t=259
# M1 putting part at t=260
# M2 putting part at t=260
# M5 maintaining at t=260
# M2 getting part at t=260
# M2 processing part at t=260
# M5 maintaining at t=261
# M2 processing part at t=261
# M5 maintaining at t=262
# M2 processing part at t=262
# M2 putting part at t=263
# M5 maintaining at t=263
# M2 getting part at t=263
# M2 processing part at t=263
# M5 maintaining at t=264
# M2 processing part at t=264
# M5 maintaining at t=265
# M2 processing part at t=265
# M2 putting part at t=266
# M5 maintaining at t=266
# M2 getting part at t=266
# M2 processing part at t=266
# M5 maintaining at t=267
# M2 processing part at t=267
# M5 maintaining at t=268
# M2 processing part at t=268
# M2 putting part at t=269
# M5 maintaining at t=269
# M2 putting part at t=270
# M5 maintaining at t=270
# M2 putting part at t=271
# M5 restored at t=271
# Releasing maintenance utilization at t=271
# Assigning maintenence utilization at t=271
# M4 maintaining at t=271
# M4 TTR at t=271: 16
# M2 putting part at t=272
# M4 maintaining at t=272
# M2 putting part at t=273
# M4 maintaining at t=273
# M2 putting part at t=274
# M4 maintaining at t=274
# M2 putting part at t=275
# M4 maintaining at t=275
# M2 putting part at t=276
# M4 maintaining at t=276
# M2 putting part at t=277
# M4 maintaining at t=277
# M2 putting part at t=278
# M4 maintaining at t=278
# M2 putting part at t=279
# M4 maintaining at t=279
# M2 putting part at t=280
# M4 maintaining at t=280
# M2 putting part at t=281
# M4 maintaining at t=281
# M2 putting part at t=282
# M4 maintaining at t=282
# M2 putting part at t=283
# M4 maintaining at t=283
# M2 putting part at t=284
# M4 maintaining at t=284
# M2 putting part at t=285
# M4 maintaining at t=285
# M2 putting part at t=286
# M4 maintaining at t=286
# M2 putting part at t=287
# M4 restored at t=287
# Releasing maintenance utilization at t=287
# Assigning maintenence utilization at t=287
# M3 maintaining at t=287
# M3 TTR at t=287: 13
# M4 getting part at t=287
# M4 processing part at t=287
# M2 putting part at t=288
# M4 putting part at t=288
# M3 maintaining at t=288
# M4 getting part at t=288
# M5 getting part at t=288
# M4 processing part at t=288
# M5 processing part at t=288
# M2 putting part at t=289
# M4 putting part at t=289
# M3 maintaining at t=289
# M4 getting part at t=289
# M4 processing part at t=289
# M5 processing part at t=289
# M2 putting part at t=290
# M4 putting part at t=290
# M5 putting part at t=290
# M3 maintaining at t=290
# M5 getting part at t=290
# M4 getting part at t=290
# M4 processing part at t=290
# M5 processing part at t=290
# M2 putting part at t=291
# M4 putting part at t=291
# M3 maintaining at t=291
# M4 getting part at t=291
# M4 processing part at t=291
# M5 processing part at t=291
# M2 putting part at t=292
# M4 putting part at t=292
# M5 putting part at t=292
# M3 maintaining at t=292
# M4 getting part at t=292
# M5 getting part at t=292
# M4 processing part at t=292
# M5 processing part at t=292
# M2 putting part at t=293
# M4 putting part at t=293
# M3 maintaining at t=293
# M4 getting part at t=293
# M4 processing part at t=293
# M5 processing part at t=293
# M2 putting part at t=294
# M4 putting part at t=294
# M5 putting part at t=294
# M3 maintaining at t=294
# M5 getting part at t=294
# M5 processing part at t=294
# M2 putting part at t=295
# M3 maintaining at t=295
# M5 processing part at t=295
# M2 putting part at t=296
# M5 putting part at t=296
# M3 maintaining at t=296
# M5 getting part at t=296
# M5 processing part at t=296
# M2 putting part at t=297
# M3 maintaining at t=297
# M5 processing part at t=297
# M2 putting part at t=298
# M5 putting part at t=298
# M3 maintaining at t=298
# M2 putting part at t=299
# M5 putting part at t=299
# M3 maintaining at t=299
# M2 putting part at t=300
# M5 putting part at t=300
# M3 restored at t=300
# Releasing maintenance utilization at t=300
# Assigning maintenence utilization at t=300
# M7 maintaining at t=300
# M7 TTR at t=300: 15
# M3 getting part at t=300
# M3 processing part at t=300
# M2 putting part at t=301
# M5 putting part at t=301
# M7 maintaining at t=301
# M3 processing part at t=301
# M3 putting part at t=302
# M5 putting part at t=302
# M7 maintaining at t=302
# M3 getting part at t=302
# M3 processing part at t=302
# M5 putting part at t=303
# M7 maintaining at t=303
# M3 processing part at t=303
# M3 putting part at t=304
# M5 putting part at t=304
# M7 maintaining at t=304
# M3 getting part at t=304
# M3 processing part at t=304
# M5 putting part at t=305
# M7 maintaining at t=305
# M3 processing part at t=305
# M3 putting part at t=306
# M5 putting part at t=306
# M7 maintaining at t=306
# M3 getting part at t=306
# M3 processing part at t=306
# M5 putting part at t=307
# M7 maintaining at t=307
# M3 processing part at t=307
# M3 putting part at t=308
# M5 putting part at t=308
# M7 maintaining at t=308
# M3 getting part at t=308
# M3 processing part at t=308
# M7 maintaining at t=309
# M3 processing part at t=309
# M3 putting part at t=310
# M7 maintaining at t=310
# M3 getting part at t=310
# M3 processing part at t=310
# M7 maintaining at t=311
# M3 processing part at t=311
# M3 putting part at t=312
# M7 maintaining at t=312
# M7 maintaining at t=313
# M7 maintaining at t=314
# M7 restored at t=315
# Releasing maintenance utilization at t=315
# Assigning maintenence utilization at t=315
# M6 maintaining at t=315
# M6 TTR at t=315: 19
# M7 getting part at t=315
# M7 processing part at t=315
# M6 maintaining at t=316
# M7 processing part at t=316
# M6 maintaining at t=317
# M7 processing part at t=317
# M7 putting part at t=318
# M6 maintaining at t=318
# M7 getting part at t=318
# M7 processing part at t=318
# M6 maintaining at t=319
# M7 processing part at t=319
# M6 maintaining at t=320
# M7 processing part at t=320
# M7 putting part at t=321
# M6 maintaining at t=321
# M7 getting part at t=321
# M7 processing part at t=321
# M6 maintaining at t=322
# M7 processing part at t=322
# M6 maintaining at t=323
# M7 processing part at t=323
# M7 putting part at t=324
# M6 maintaining at t=324
# M7 getting part at t=324
# M7 processing part at t=324
# M6 maintaining at t=325
# M7 processing part at t=325
# M6 maintaining at t=326
# M7 processing part at t=326
# M7 putting part at t=327
# M6 maintaining at t=327
# M7 getting part at t=327
# M7 processing part at t=327
# M6 maintaining at t=328
# M7 processing part at t=328
# M6 maintaining at t=329
# M7 processing part at t=329
# M7 putting part at t=330
# M6 maintaining at t=330
# M6 maintaining at t=331
# M6 maintaining at t=332
# M6 maintaining at t=333
# M6 restored at t=334
# Releasing maintenance utilization at t=334
# Assigning maintenence utilization at t=334
# M1 maintaining at t=334
# M1 TTR at t=334: 14
# M6 getting part at t=334
# M6 processing part at t=334
# M1 maintaining at t=335
# M6 processing part at t=335
# M6 putting part at t=336
# M1 maintaining at t=336
# M7 getting part at t=336
# M6 getting part at t=336
# M6 processing part at t=336
# M7 processing part at t=336
# M1 maintaining at t=337
# M6 processing part at t=337
# M7 processing part at t=337
# M6 putting part at t=338
# M1 maintaining at t=338
# M7 processing part at t=338
# M7 putting part at t=339
# M1 maintaining at t=339
# M7 getting part at t=339
# M7 processing part at t=339
# M1 maintaining at t=340
# M7 processing part at t=340
# M1 maintaining at t=341
# M7 processing part at t=341
# M7 putting part at t=342
# M1 maintaining at t=342
# M1 maintaining at t=343
# M1 maintaining at t=344
# M1 maintaining at t=345
# M1 maintaining at t=346
# M1 maintaining at t=347
# M1 restored at t=348
# Releasing maintenance utilization at t=348
# Assigning maintenence utilization at t=348
# M2 maintaining at t=348
# M2 TTR at t=348: 13
# M1 getting part at t=348
# M1 processing part at t=348
# M1 putting part at t=349
# M2 maintaining at t=349
# M1 getting part at t=349
# M1 processing part at t=349
# M1 putting part at t=350
# M2 maintaining at t=350
# M1 getting part at t=350
# M1 processing part at t=350
# M1 putting part at t=351
# M2 maintaining at t=351
# M1 getting part at t=351
# M1 processing part at t=351
# M1 putting part at t=352
# M2 maintaining at t=352
# M1 getting part at t=352
# M1 processing part at t=352
# M1 putting part at t=353
# M2 maintaining at t=353
# M1 getting part at t=353
# M1 processing part at t=353
# M1 putting part at t=354
# M2 maintaining at t=354
# M1 getting part at t=354
# M1 processing part at t=354
# M1 putting part at t=355
# M2 maintaining at t=355
# M1 getting part at t=355
# M1 processing part at t=355
# M1 putting part at t=356
# M2 maintaining at t=356
# M1 getting part at t=356
# M1 processing part at t=356
# M1 putting part at t=357
# M2 maintaining at t=357
# M1 getting part at t=357
# M1 processing part at t=357
# M1 putting part at t=358
# M2 maintaining at t=358
# M1 getting part at t=358
# M1 processing part at t=358
# M1 putting part at t=359
# M2 maintaining at t=359
# M1 putting part at t=360
# M2 maintaining at t=360
# M1 putting part at t=361
# M2 restored at t=361
# Releasing maintenance utilization at t=361
# Assigning maintenence utilization at t=361
# M5 maintaining at t=361
# M5 TTR at t=361: 18
# M2 getting part at t=361
# M2 processing part at t=361
# M1 putting part at t=362
# M5 maintaining at t=362
# M1 getting part at t=362
# M1 processing part at t=362
# M2 processing part at t=362
# M1 putting part at t=363
# M5 maintaining at t=363
# M2 processing part at t=363
# M1 putting part at t=364
# M2 putting part at t=364
# M5 maintaining at t=364
# M2 getting part at t=364
# M2 processing part at t=364
# M1 putting part at t=365
# M5 maintaining at t=365
# M1 getting part at t=365
# M1 processing part at t=365
# M2 processing part at t=365
# M1 putting part at t=366
# M5 maintaining at t=366
# M2 processing part at t=366
# M1 putting part at t=367
# M2 putting part at t=367
# M5 maintaining at t=367
# M2 getting part at t=367
# M2 processing part at t=367
# M1 putting part at t=368
# M5 maintaining at t=368
# M1 getting part at t=368
# M1 processing part at t=368
# M2 processing part at t=368
# M1 putting part at t=369
# M5 maintaining at t=369
# M2 processing part at t=369
# M1 putting part at t=370
# M2 putting part at t=370
# M5 maintaining at t=370
# M2 getting part at t=370
# M2 processing part at t=370
# M1 putting part at t=371
# M5 maintaining at t=371
# M1 getting part at t=371
# M1 processing part at t=371
# M2 processing part at t=371
# M1 putting part at t=372
# M5 maintaining at t=372
# M2 processing part at t=372
# M1 putting part at t=373
# M2 putting part at t=373
# M5 maintaining at t=373
# M2 getting part at t=373
# M2 processing part at t=373
# M1 putting part at t=374
# M5 maintaining at t=374
# M1 getting part at t=374
# M1 processing part at t=374
# M2 processing part at t=374
# M1 putting part at t=375
# M5 maintaining at t=375
# M2 processing part at t=375
# M1 putting part at t=376
# M2 putting part at t=376
# M5 maintaining at t=376
# M2 getting part at t=376
# M2 processing part at t=376
# M1 putting part at t=377
# M5 maintaining at t=377
# M1 getting part at t=377
# M1 processing part at t=377
# M2 processing part at t=377
# M1 putting part at t=378
# M5 maintaining at t=378
# M2 processing part at t=378
# M1 putting part at t=379
# M2 putting part at t=379
# M5 restored at t=379
# Releasing maintenance utilization at t=379
# Assigning maintenence utilization at t=379
# M4 maintaining at t=379
# M4 TTR at t=379: 16
# M1 putting part at t=380
# M2 putting part at t=380
# M4 maintaining at t=380
# M1 putting part at t=381
# M2 putting part at t=381
# M4 maintaining at t=381
# M1 putting part at t=382
# M2 putting part at t=382
# M4 maintaining at t=382
# M1 putting part at t=383
# M2 putting part at t=383
# M4 maintaining at t=383
# M1 putting part at t=384
# M2 putting part at t=384
# M4 maintaining at t=384
# M1 putting part at t=385
# M2 putting part at t=385
# M4 maintaining at t=385
# M1 putting part at t=386
# M2 putting part at t=386
# M4 maintaining at t=386
# M1 putting part at t=387
# M2 putting part at t=387
# M4 maintaining at t=387
# M1 putting part at t=388
# M2 putting part at t=388
# M4 maintaining at t=388
# M1 putting part at t=389
# M2 putting part at t=389
# M4 maintaining at t=389
# M1 putting part at t=390
# M2 putting part at t=390
# M4 maintaining at t=390
# M2 putting part at t=391
# M4 maintaining at t=391
# M2 putting part at t=392
# M4 maintaining at t=392
# M2 putting part at t=393
# M4 maintaining at t=393
# M2 putting part at t=394
# M4 maintaining at t=394
# M2 putting part at t=395
# M4 restored at t=395
# Releasing maintenance utilization at t=395
# Assigning maintenence utilization at t=395
# M3 maintaining at t=395
# M3 TTR at t=395: 10
# M4 getting part at t=395
# M4 processing part at t=395
# M2 putting part at t=396
# M4 putting part at t=396
# M3 maintaining at t=396
# M5 getting part at t=396
# M4 getting part at t=396
# M4 processing part at t=396
# M5 processing part at t=396
# M2 putting part at t=397
# M4 putting part at t=397
# M3 maintaining at t=397
# M4 getting part at t=397
# M6 getting part at t=397
# M4 processing part at t=397
# M5 processing part at t=397
# M6 processing part at t=397
# M2 putting part at t=398
# M4 putting part at t=398
# M5 putting part at t=398
# M3 maintaining at t=398
# M5 getting part at t=398
# M4 getting part at t=398
# M4 processing part at t=398
# M5 processing part at t=398
# M6 processing part at t=398
# M2 putting part at t=399
# M4 putting part at t=399
# M6 putting part at t=399
# M3 maintaining at t=399
# M4 getting part at t=399
# M6 getting part at t=399
# M4 processing part at t=399
# M5 processing part at t=399
# M6 processing part at t=399
# M2 putting part at t=400
# M4 putting part at t=400
# M5 putting part at t=400
# M3 maintaining at t=400
# M5 getting part at t=400
# M4 getting part at t=400
# M4 processing part at t=400
# M5 processing part at t=400
# M6 processing part at t=400
# M2 putting part at t=401
# M4 putting part at t=401
# M6 putting part at t=401
# M3 maintaining at t=401
# M4 getting part at t=401
# M6 getting part at t=401
# M4 processing part at t=401
# M6 processing part at t=401
# M2 putting part at t=402
# M4 putting part at t=402
# M3 maintaining at t=402
# M4 getting part at t=402
# M4 processing part at t=402
# M6 processing part at t=402
# M2 putting part at t=403
# M4 putting part at t=403
# M6 putting part at t=403
# M3 maintaining at t=403
# M4 getting part at t=403
# M6 getting part at t=403
# M4 processing part at t=403
# M6 processing part at t=403
# M2 putting part at t=404
# M4 putting part at t=404
# M3 maintaining at t=404
# M4 getting part at t=404
# M4 processing part at t=404
# M6 processing part at t=404
# M2 putting part at t=405
# M4 putting part at t=405
# M6 putting part at t=405
# M3 restored at t=405
# Releasing maintenance utilization at t=405
# Assigning maintenence utilization at t=405
# M7 maintaining at t=405
# M7 TTR at t=405: 16
# M3 getting part at t=405
# M3 processing part at t=405
# M2 putting part at t=406
# M6 putting part at t=406
# M7 maintaining at t=406
# M3 processing part at t=406
# M3 putting part at t=407
# M6 putting part at t=407
# M7 maintaining at t=407
# M3 getting part at t=407
# M3 processing part at t=407
# M6 putting part at t=408
# M7 maintaining at t=408
# M3 processing part at t=408
# M3 putting part at t=409
# M6 putting part at t=409
# M7 maintaining at t=409
# M3 getting part at t=409
# M3 processing part at t=409
# M6 putting part at t=410
# M7 maintaining at t=410
# M3 processing part at t=410
# M3 putting part at t=411
# M6 putting part at t=411
# M7 maintaining at t=411
# M3 getting part at t=411
# M3 processing part at t=411
# M6 putting part at t=412
# M7 maintaining at t=412
# M3 processing part at t=412
# M3 putting part at t=413
# M6 putting part at t=413
# M7 maintaining at t=413
# M3 getting part at t=413
# M3 processing part at t=413
# M6 putting part at t=414
# M7 maintaining at t=414
# M3 processing part at t=414
# M3 putting part at t=415
# M6 putting part at t=415
# M7 maintaining at t=415
# M3 getting part at t=415
# M3 processing part at t=415
# M6 putting part at t=416
# M7 maintaining at t=416
# M3 processing part at t=416
# M3 putting part at t=417
# M6 putting part at t=417
# M7 maintaining at t=417
# M6 putting part at t=418
# M7 maintaining at t=418
# M6 putting part at t=419
# M7 maintaining at t=419
# M6 putting part at t=420
# M7 maintaining at t=420
# M6 putting part at t=421
# M7 restored at t=421
# Releasing maintenance utilization at t=421
# Assigning maintenence utilization at t=421
# M1 maintaining at t=421
# M1 TTR at t=421: 12
# M7 getting part at t=421
# M7 processing part at t=421
# M6 putting part at t=422
# M1 maintaining at t=422
# M6 getting part at t=422
# M6 processing part at t=422
# M7 processing part at t=422
# M1 maintaining at t=423
# M6 processing part at t=423
# M7 processing part at t=423
# M6 putting part at t=424
# M7 putting part at t=424
# M1 maintaining at t=424
# M7 getting part at t=424
# M7 processing part at t=424
# M1 maintaining at t=425
# M7 processing part at t=425
# M1 maintaining at t=426
# M7 processing part at t=426
# M7 putting part at t=427
# M1 maintaining at t=427
# M7 getting part at t=427
# M7 processing part at t=427
# M1 maintaining at t=428
# M7 processing part at t=428
# M1 maintaining at t=429
# M7 processing part at t=429
# M7 putting part at t=430
# M1 maintaining at t=430
# M7 getting part at t=430
# M7 processing part at t=430
# M1 maintaining at t=431
# M7 processing part at t=431
# M1 maintaining at t=432
# M7 processing part at t=432
# M7 putting part at t=433
# M1 restored at t=433
# Releasing maintenance utilization at t=433
# Assigning maintenence utilization at t=433
# M5 maintaining at t=433
# M5 TTR at t=433: 17
# M1 getting part at t=433
# M7 getting part at t=433
# M1 processing part at t=433
# M7 processing part at t=433
# M1 putting part at t=434
# M5 maintaining at t=434
# M1 getting part at t=434
# M2 getting part at t=434
# M1 processing part at t=434
# M2 processing part at t=434
# M7 processing part at t=434
# M1 putting part at t=435
# M5 maintaining at t=435
# M1 getting part at t=435
# M1 processing part at t=435
# M7 processing part at t=435
# M1 putting part at t=436
# M7 putting part at t=436
# M5 maintaining at t=436
# M1 getting part at t=436
# M7 getting part at t=436
# M1 processing part at t=436
# M7 processing part at t=436
# M1 putting part at t=437
# M5 maintaining at t=437
# M1 getting part at t=437
# M1 processing part at t=437
# M7 processing part at t=437
# M1 putting part at t=438
# M5 maintaining at t=438
# M1 getting part at t=438
# M1 processing part at t=438
# M7 processing part at t=438
# M1 putting part at t=439
# M7 putting part at t=439
# M5 maintaining at t=439
# M1 getting part at t=439
# M1 processing part at t=439
# M1 putting part at t=440
# M5 maintaining at t=440
# M1 getting part at t=440
# M1 processing part at t=440
# M1 putting part at t=441
# M5 maintaining at t=441
# M1 getting part at t=441
# M1 processing part at t=441
# M1 putting part at t=442
# M5 maintaining at t=442
# M1 getting part at t=442
# M1 processing part at t=442
# M1 putting part at t=443
# M5 maintaining at t=443
# M1 getting part at t=443
# M1 processing part at t=443
# M1 putting part at t=444
# M5 maintaining at t=444
# M1 getting part at t=444
# M1 processing part at t=444
# M1 putting part at t=445
# M5 maintaining at t=445
# M1 putting part at t=446
# M5 maintaining at t=446
# M1 putting part at t=447
# M5 maintaining at t=447
# M1 putting part at t=448
# M5 maintaining at t=448
# M1 putting part at t=449
# M5 maintaining at t=449
# M1 putting part at t=450
# M5 restored at t=450
# Releasing maintenance utilization at t=450
# Assigning maintenence utilization at t=450
# M3 maintaining at t=450
# M3 TTR at t=450: 17
# M5 getting part at t=450
# M5 processing part at t=450
# M1 putting part at t=451
# M3 maintaining at t=451
# M5 processing part at t=451
# M1 putting part at t=452
# M5 putting part at t=452
# M3 maintaining at t=452
# M5 getting part at t=452
# M5 processing part at t=452
# M1 putting part at t=453
# M3 maintaining at t=453
# M5 processing part at t=453
# M1 putting part at t=454
# M5 putting part at t=454
# M3 maintaining at t=454
# M1 putting part at t=455
# M3 maintaining at t=455
# M1 putting part at t=456
# M3 maintaining at t=456
# M1 putting part at t=457
# M3 maintaining at t=457
# M1 putting part at t=458
# M3 maintaining at t=458
# M1 putting part at t=459
# M3 maintaining at t=459
# M1 putting part at t=460
# M3 maintaining at t=460
# M1 putting part at t=461
# M3 maintaining at t=461
# M1 putting part at t=462
# M3 maintaining at t=462
# M1 putting part at t=463
# M3 maintaining at t=463
# M1 putting part at t=464
# M3 maintaining at t=464
# M1 putting part at t=465
# M3 maintaining at t=465
# M1 putting part at t=466
# M3 maintaining at t=466
# M1 putting part at t=467
# M3 restored at t=467
# ...
# M4 restored at t=9972
# Releasing maintenance utilization at t=9972
# Assigning maintenence utilization at t=9972
# M6 maintaining at t=9972
# M6 TTR at t=9972: 12
# M4 getting part at t=9972
# M4 processing part at t=9972
# M1 putting part at t=9973
# M2 putting part at t=9973
# M4 putting part at t=9973
# M6 maintaining at t=9973
# M1 getting part at t=9973
# M4 getting part at t=9973
# M1 processing part at t=9973
# M4 processing part at t=9973
# M1 putting part at t=9974
# M2 putting part at t=9974
# M4 putting part at t=9974
# M6 maintaining at t=9974
# M1 getting part at t=9974
# M4 getting part at t=9974
# M1 processing part at t=9974
# M4 processing part at t=9974
# M1 putting part at t=9975
# M2 putting part at t=9975
# M4 putting part at t=9975
# M6 maintaining at t=9975
# M4 getting part at t=9975
# M1 getting part at t=9975
# M1 processing part at t=9975
# M4 processing part at t=9975
# M1 putting part at t=9976
# M2 putting part at t=9976
# M4 putting part at t=9976
# M6 maintaining at t=9976
# M1 getting part at t=9976
# M4 getting part at t=9976
# M1 processing part at t=9976
# M4 processing part at t=9976
# M1 putting part at t=9977
# M2 putting part at t=9977
# M4 putting part at t=9977
# M6 maintaining at t=9977
# M1 getting part at t=9977
# M4 getting part at t=9977
# M1 processing part at t=9977
# M4 processing part at t=9977
# M1 putting part at t=9978
# M2 putting part at t=9978
# M4 putting part at t=9978
# M6 maintaining at t=9978
# M1 getting part at t=9978
# M1 processing part at t=9978
# M1 putting part at t=9979
# M2 putting part at t=9979
# M4 putting part at t=9979
# M6 maintaining at t=9979
# M1 putting part at t=9980
# M2 putting part at t=9980
# M4 putting part at t=9980
# M6 maintaining at t=9980
# M1 putting part at t=9981
# M2 putting part at t=9981
# M4 putting part at t=9981
# M6 maintaining at t=9981
# M1 putting part at t=9982
# M2 putting part at t=9982
# M4 putting part at t=9982
# M6 maintaining at t=9982
# M1 putting part at t=9983
# M2 putting part at t=9983
# M4 putting part at t=9983
# M6 maintaining at t=9983
# M1 putting part at t=9984
# M2 putting part at t=9984
# M4 putting part at t=9984
# M6 restored at t=9984
# Releasing maintenance utilization at t=9984
# Assigning maintenence utilization at t=9984
# M3 maintaining at t=9984
# M3 TTR at t=9984: 10
# M6 getting part at t=9984
# M6 processing part at t=9984
# M1 putting part at t=9985
# M2 putting part at t=9985
# M4 putting part at t=9985
# M3 maintaining at t=9985
# M4 getting part at t=9985
# M4 processing part at t=9985
# M6 processing part at t=9985
# M1 putting part at t=9986
# M2 putting part at t=9986
# M4 putting part at t=9986
# M6 putting part at t=9986
# M3 maintaining at t=9986
# M6 getting part at t=9986
# M1 getting part at t=9986
# M1 processing part at t=9986
# M6 processing part at t=9986
# M1 putting part at t=9987
# M2 putting part at t=9987
# M4 putting part at t=9987
# M3 maintaining at t=9987
# M4 getting part at t=9987
# M4 processing part at t=9987
# M6 processing part at t=9987
# M1 putting part at t=9988
# M2 putting part at t=9988
# M4 putting part at t=9988
# M6 putting part at t=9988
# M3 maintaining at t=9988
# M6 getting part at t=9988
# M1 getting part at t=9988
# M1 processing part at t=9988
# M6 processing part at t=9988
# M1 putting part at t=9989
# M2 putting part at t=9989
# M4 putting part at t=9989
# M3 maintaining at t=9989
# M4 getting part at t=9989
# M4 processing part at t=9989
# M6 processing part at t=9989
# M1 putting part at t=9990
# M2 putting part at t=9990
# M4 putting part at t=9990
# M6 putting part at t=9990
# M3 maintaining at t=9990
# M6 getting part at t=9990
# M1 getting part at t=9990
# M1 processing part at t=9990
# M6 processing part at t=9990
# M1 putting part at t=9991
# M2 putting part at t=9991
# M4 putting part at t=9991
# M3 maintaining at t=9991
# M4 getting part at t=9991
# M4 processing part at t=9991
# M6 processing part at t=9991
# M1 putting part at t=9992
# M2 putting part at t=9992
# M4 putting part at t=9992
# M6 putting part at t=9992
# M3 maintaining at t=9992
# M6 getting part at t=9992
# M1 getting part at t=9992
# M1 processing part at t=9992
# M6 processing part at t=9992
# M1 putting part at t=9993
# M4 putting part at t=9993
# M3 maintaining at t=9993
# M4 getting part at t=9993
# M4 processing part at t=9993
# M6 processing part at t=9993
# M1 putting part at t=9994
# M4 putting part at t=9994
# M6 putting part at t=9994
# M3 restored at t=9994
# Releasing maintenance utilization at t=9994
# Assigning maintenence utilization at t=9994
# M5 maintaining at t=9994
# M5 TTR at t=9994: 15
# M6 getting part at t=9994
# M3 getting part at t=9994
# M1 getting part at t=9994
# M1 processing part at t=9994
# M3 processing part at t=9994
# M6 processing part at t=9994
# M1 putting part at t=9995
# M4 putting part at t=9995
# M5 maintaining at t=9995
# M4 getting part at t=9995
# M3 processing part at t=9995
# M4 processing part at t=9995
# M6 processing part at t=9995
# M1 putting part at t=9996
# M3 putting part at t=9996
# M4 putting part at t=9996
# M6 putting part at t=9996
# M5 maintaining at t=9996
# M3 getting part at t=9996
# M1 getting part at t=9996
# M1 processing part at t=9996
# M3 processing part at t=9996
# M1 putting part at t=9997
# M4 putting part at t=9997
# M6 putting part at t=9997
# M5 maintaining at t=9997
# M3 processing part at t=9997
# M1 putting part at t=9998
# M3 putting part at t=9998
# M4 putting part at t=9998
# M6 putting part at t=9998
# M5 maintaining at t=9998
# M3 getting part at t=9998
# M3 processing part at t=9998
# M1 putting part at t=9999
# M4 putting part at t=9999
# M6 putting part at t=9999
# M5 maintaining at t=9999
# M3 processing part at t=9999
# M1 putting part at t=10000
# M3 putting part at t=10000
# M4 putting part at t=10000
# M6 putting part at t=10000
# M5 maintaining at t=10000
# M3 getting part at t=10000
# M3 processing part at t=10000
# M1 putting part at t=10001
# M4 putting part at t=10001
# M6 putting part at t=10001
# M5 maintaining at t=10001
# M3 processing part at t=10001
# M1 putting part at t=10002
# M3 putting part at t=10002
# M4 putting part at t=10002
# M6 putting part at t=10002
# M5 maintaining at t=10002
# M3 getting part at t=10002
# M3 processing part at t=10002
# M1 putting part at t=10003
# M4 putting part at t=10003
# M6 putting part at t=10003
# M5 maintaining at t=10003
# M3 processing part at t=10003
# M1 putting part at t=10004
# M3 putting part at t=10004
# M4 putting part at t=10004
# M6 putting part at t=10004
# M5 maintaining at t=10004
# M1 putting part at t=10005
# M4 putting part at t=10005
# M6 putting part at t=10005
# M5 maintaining at t=10005
# M1 putting part at t=10006
# M4 putting part at t=10006
# M6 putting part at t=10006
# M5 maintaining at t=10006
# M1 putting part at t=10007
# M4 putting part at t=10007
# M6 putting part at t=10007
# M5 maintaining at t=10007
# M1 putting part at t=10008
# M4 putting part at t=10008
# M6 putting part at t=10008
# M5 maintaining at t=10008
# M4 putting part at t=10009
# M6 putting part at t=10009
# M5 restored at t=10009
# Releasing maintenance utilization at t=10009
# Assigning maintenence utilization at t=10009
# M7 maintaining at t=10009
# M7 TTR at t=10009: 13
# M5 getting part at t=10009
# M5 processing part at t=10009
# M4 putting part at t=10010
# M6 putting part at t=10010
# M7 maintaining at t=10010
# M4 getting part at t=10010
# M4 processing part at t=10010
# M5 processing part at t=10010
# M4 putting part at t=10011
# M5 putting part at t=10011
# M6 putting part at t=10011
# M7 maintaining at t=10011
# M4 putting part at t=10012
# M5 putting part at t=10012
# M6 putting part at t=10012
# M7 maintaining at t=10012
# M4 putting part at t=10013
# M5 putting part at t=10013
# M6 putting part at t=10013
# M7 maintaining at t=10013
# M4 putting part at t=10014
# M5 putting part at t=10014
# M6 putting part at t=10014
# M7 maintaining at t=10014
# M5 putting part at t=10015
# M6 putting part at t=10015
# M7 maintaining at t=10015
# M5 putting part at t=10016
# M6 putting part at t=10016
# M7 maintaining at t=10016
# M5 putting part at t=10017
# M6 putting part at t=10017
# M7 maintaining at t=10017
# M5 putting part at t=10018
# M6 putting part at t=10018
# M7 maintaining at t=10018
# M5 putting part at t=10019
# M6 putting part at t=10019
# M7 maintaining at t=10019
# M5 putting part at t=10020
# M6 putting part at t=10020
# M7 maintaining at t=10020
# M5 putting part at t=10021
# M6 putting part at t=10021
# M7 maintaining at t=10021
# M5 putting part at t=10022
# M6 putting part at t=10022
# M7 restored at t=10022
# Releasing maintenance utilization at t=10022
# Assigning maintenence utilization at t=10022
# M2 maintaining at t=10022
# M2 TTR at t=10022: 13
# M7 getting part at t=10022
# M7 processing part at t=10022
# M5 putting part at t=10023
# M2 maintaining at t=10023
# M5 getting part at t=10023
# M5 processing part at t=10023
# M7 processing part at t=10023
# M2 maintaining at t=10024
# M5 processing part at t=10024
# M7 processing part at t=10024
# M5 putting part at t=10025
# M7 putting part at t=10025
# M2 maintaining at t=10025
# M7 getting part at t=10025
# M7 processing part at t=10025
# M5 putting part at t=10026
# M2 maintaining at t=10026
# M5 getting part at t=10026
# M5 processing part at t=10026
# M7 processing part at t=10026
# M2 maintaining at t=10027
# M5 processing part at t=10027
# M7 processing part at t=10027
# M5 putting part at t=10028
# M7 putting part at t=10028
# M2 maintaining at t=10028
# M7 getting part at t=10028
# M7 processing part at t=10028
# M5 putting part at t=10029
# M2 maintaining at t=10029
# M5 getting part at t=10029
# M5 processing part at t=10029
# M7 processing part at t=10029
# M2 maintaining at t=10030
# M5 processing part at t=10030
# M7 processing part at t=10030
# M5 putting part at t=10031
# M7 putting part at t=10031
# M2 maintaining at t=10031
# M7 getting part at t=10031
# M7 processing part at t=10031
# M5 putting part at t=10032
# M2 maintaining at t=10032
# M5 getting part at t=10032
# M5 processing part at t=10032
# M7 processing part at t=10032
# M2 maintaining at t=10033
# M5 processing part at t=10033
# M7 processing part at t=10033
# M5 putting part at t=10034
# M7 putting part at t=10034
# M2 maintaining at t=10034
# M7 getting part at t=10034
# M7 processing part at t=10034
# M5 putting part at t=10035
# M2 restored at t=10035
# Releasing maintenance utilization at t=10035
# Assigning maintenence utilization at t=10035
# M1 maintaining at t=10035
# M1 TTR at t=10035: 18
# M2 getting part at t=10035
# M5 getting part at t=10035
# M2 processing part at t=10035
# M5 processing part at t=10035
# M7 processing part at t=10035
# M1 maintaining at t=10036
# M2 processing part at t=10036
# M5 processing part at t=10036
# M7 processing part at t=10036
# M5 putting part at t=10037
# M7 putting part at t=10037
# M1 maintaining at t=10037
# M7 getting part at t=10037
# M2 processing part at t=10037
# M7 processing part at t=10037
# M2 putting part at t=10038
# M5 putting part at t=10038
# M1 maintaining at t=10038
# M3 getting part at t=10038
# M2 getting part at t=10038
# M2 processing part at t=10038
# M3 processing part at t=10038
# M7 processing part at t=10038
# M1 maintaining at t=10039
# M2 processing part at t=10039
# M3 processing part at t=10039
# M7 processing part at t=10039
# M3 putting part at t=10040
# M7 putting part at t=10040
# M1 maintaining at t=10040
# M7 getting part at t=10040
# M2 processing part at t=10040
# M7 processing part at t=10040
# M2 putting part at t=10041
# M1 maintaining at t=10041
# M2 getting part at t=10041
# M3 getting part at t=10041
# M2 processing part at t=10041
# M3 processing part at t=10041
# M7 processing part at t=10041
# M1 maintaining at t=10042
# M2 processing part at t=10042
# M7 processing part at t=10042
# M7 putting part at t=10043
# M1 maintaining at t=10043
# M7 getting part at t=10043
# M2 processing part at t=10043
# M7 processing part at t=10043
# M2 putting part at t=10044
# M1 maintaining at t=10044
# M2 getting part at t=10044
# M2 processing part at t=10044
# M7 processing part at t=10044
# M1 maintaining at t=10045
# M2 processing part at t=10045
# M7 processing part at t=10045
# M7 putting part at t=10046
# M1 maintaining at t=10046
# M7 getting part at t=10046
# M2 processing part at t=10046
# M7 processing part at t=10046
# M2 putting part at t=10047
# M1 maintaining at t=10047
# M2 getting part at t=10047
# M2 processing part at t=10047
# M7 processing part at t=10047
# M1 maintaining at t=10048
# M2 processing part at t=10048
# M7 processing part at t=10048
# M7 putting part at t=10049
# M1 maintaining at t=10049
# M7 getting part at t=10049
# M2 processing part at t=10049
# M7 processing part at t=10049
# M2 putting part at t=10050
# M1 maintaining at t=10050
# M2 getting part at t=10050
# M2 processing part at t=10050
# M7 processing part at t=10050
# M1 maintaining at t=10051
# M2 processing part at t=10051
# M7 processing part at t=10051
# M7 putting part at t=10052
# M1 maintaining at t=10052
# M2 processing part at t=10052
# M2 putting part at t=10053
# M1 restored at t=10053
# Releasing maintenance utilization at t=10053
# Assigning maintenence utilization at t=10053
# M4 maintaining at t=10053
# M4 TTR at t=10053: 16
# M1 getting part at t=10053
# M2 getting part at t=10053
# M1 processing part at t=10053
# M2 processing part at t=10053
# M1 putting part at t=10054
# M4 maintaining at t=10054
# M1 getting part at t=10054
# M1 processing part at t=10054
# M2 processing part at t=10054
# M1 putting part at t=10055
# M4 maintaining at t=10055
# M1 getting part at t=10055
# M1 processing part at t=10055
# M2 processing part at t=10055
# M1 putting part at t=10056
# M2 putting part at t=10056
# M4 maintaining at t=10056
# M1 getting part at t=10056
# M2 getting part at t=10056
# M1 processing part at t=10056
# M2 processing part at t=10056
# M1 putting part at t=10057
# M4 maintaining at t=10057
# M1 getting part at t=10057
# M1 processing part at t=10057
# M1 putting part at t=10058
# M4 maintaining at t=10058
# M1 getting part at t=10058
# M1 processing part at t=10058
# M1 putting part at t=10059
# M4 maintaining at t=10059
# M1 getting part at t=10059
# M1 processing part at t=10059
# M1 putting part at t=10060
# M4 maintaining at t=10060
# M1 getting part at t=10060
# M1 processing part at t=10060
# M1 putting part at t=10061
# M4 maintaining at t=10061
# M1 getting part at t=10061
# M1 processing part at t=10061
# M1 putting part at t=10062
# M4 maintaining at t=10062
# M1 getting part at t=10062
# M1 processing part at t=10062
# M1 putting part at t=10063
# M4 maintaining at t=10063
# M1 putting part at t=10064
# M4 maintaining at t=10064
# M1 putting part at t=10065
# M4 maintaining at t=10065
# M1 putting part at t=10066
# M4 maintaining at t=10066
# M1 putting part at t=10067
# M4 maintaining at t=10067
# M1 putting part at t=10068
# M4 maintaining at t=10068
# M1 putting part at t=10069
# M4 restored at t=10069
# Releasing maintenance utilization at t=10069
# Assigning maintenence utilization at t=10069
# M6 maintaining at t=10069
# M6 TTR at t=10069: 10
# M4 getting part at t=10069
# M4 processing part at t=10069
# M1 putting part at t=10070
# M4 putting part at t=10070
# M6 maintaining at t=10070
# M4 getting part at t=10070
# M1 getting part at t=10070
# M1 processing part at t=10070
# M4 processing part at t=10070
# M1 putting part at t=10071
# M4 putting part at t=10071
# M6 maintaining at t=10071
# M1 getting part at t=10071
# M4 getting part at t=10071
# M1 processing part at t=10071
# M4 processing part at t=10071
# M1 putting part at t=10072
# M4 putting part at t=10072
# M6 maintaining at t=10072
# M1 getting part at t=10072
# M4 getting part at t=10072
# M1 processing part at t=10072
# M4 processing part at t=10072
# M1 putting part at t=10073
# M4 putting part at t=10073
# M6 maintaining at t=10073
# M4 getting part at t=10073
# M1 getting part at t=10073
# M1 processing part at t=10073
# M4 processing part at t=10073
# M1 putting part at t=10074
# M4 putting part at t=10074
# M6 maintaining at t=10074
# M4 getting part at t=10074
# M1 getting part at t=10074
# M1 processing part at t=10074
# M4 processing part at t=10074
# M1 putting part at t=10075
# M4 putting part at t=10075
# M6 maintaining at t=10075
# M1 getting part at t=10075
# M1 processing part at t=10075
# M1 putting part at t=10076
# M4 putting part at t=10076
# M6 maintaining at t=10076
# M1 putting part at t=10077
# M4 putting part at t=10077
# M6 maintaining at t=10077
# M1 putting part at t=10078
# M4 putting part at t=10078
# M6 maintaining at t=10078
# M1 putting part at t=10079
# M4 putting part at t=10079
# M6 restored at t=10079
# Releasing maintenance utilization at t=10079
# Assigning maintenence utilization at t=10079
# M3 maintaining at t=10079
# M3 TTR at t=10079: 17
# M6 getting part at t=10079
# M6 processing part at t=10079
# Simulation finished in 5.45s
# Parts made: 1415

# %%
random.seed(1)

p = 0.1 # degradation probability at each time step
h_max = 10 # failure state
degradation_matrix = []
for h in range(h_max):
    transitions = [0] * (h_max + 1)
    transitions[h] = 1 - p
    transitions[h+1] = p
    degradation_matrix.append(transitions)
degradation_matrix.append([0]*h_max + [1])

production = []
policies = range(1, 11)
n = 30

for policy in policies:
    samples = []
    start = time.time()
    for _ in range(n):
        source = Source()

        M1 = Machine('M1', cycle_time=1, degradation_matrix=degradation_matrix, cbm_threshold=policy)
        B1 = Buffer(capacity=10)

        M2 = Machine('M2', cycle_time=3, degradation_matrix=degradation_matrix, cbm_threshold=policy)
        B2 = Buffer(capacity=5)
        M3 = Machine('M3', cycle_time=2, degradation_matrix=degradation_matrix, cbm_threshold=policy)

        M4 = Machine('M4', cycle_time=1, degradation_matrix=degradation_matrix, cbm_threshold=policy)
        B4 = Buffer(capacity=5)
        M5 = Machine('M5', cycle_time=2, degradation_matrix=degradation_matrix, cbm_threshold=policy)
        M6 = Machine('M6', cycle_time=2, degradation_matrix=degradation_matrix, cbm_threshold=policy)
        B5 = Buffer(capacity=5)
        M7 = Machine('M7', cycle_time=3, degradation_matrix=degradation_matrix, cbm_threshold=policy)

        sink = Sink()

        source.define_routing(downstream=[M1])

        M1.define_routing(upstream=[source], downstream=[B1])
        B1.define_routing(upstream=[M1], downstream=[M2, M4])

        M2.define_routing(upstream=[B1], downstream=[B2])
        B2.define_routing(upstream=[M2], downstream=[M3])
        M3.define_routing(upstream=[B2], downstream=[sink])

        M4.define_routing(upstream=[B1], downstream=[B4])
        B4.define_routing(upstream=[M4], downstream=[M5, M6])
        M5.define_routing(upstream=[B4], downstream=[B5])
        M6.define_routing(upstream=[B4], downstream=[B5])
        B5.define_routing(upstream=[M5, M6], downstream=[M7])
        M7.define_routing(upstream=[B5], downstream=[sink])

        sink.define_routing(upstream=[M3, M7])

        objects = [source, M1, M2, M3, M4, M5, M6, M7, B1, B2, B4, B5, sink]

        repairman = Repairman(capacity=1)

        system = System(objects=objects, repairman=repairman)

        system.simulate(simulation_time=7*24*60)
        
        samples.append(sink.level)
    stop = time.time()
    print(f'Policy {policy} finished in {stop-start:.2f}s')
    production.append(samples)
# Out:
# M1 getting part at t=0
# M1 processing part at t=0
# M1 putting part at t=1
# M1 getting part at t=1
# M4 getting part at t=1
# M1 processing part at t=1
# M4 processing part at t=1
# M1 putting part at t=2
# M4 putting part at t=2
# M6 getting part at t=2
# M1 getting part at t=2
# M2 getting part at t=2
# M1 processing part at t=2
# M2 processing part at t=2
# M6 processing part at t=2
# M1 putting part at t=3
# M1 getting part at t=3
# M4 getting part at t=3
# M1 processing part at t=3
# M2 processing part at t=3
# M4 processing part at t=3
# M6 processing part at t=3
# M1 putting part at t=4
# M4 putting part at t=4
# M6 putting part at t=4
# M1 getting part at t=4
# M7 getting part at t=4
# M5 getting part at t=4
# M4 getting part at t=4
# M1 processing part at t=4
# M2 processing part at t=4
# M4 processing part at t=4
# M5 processing part at t=4
# M7 processing part at t=4
# M1 putting part at t=5
# M2 putting part at t=5
# M4 putting part at t=5
# Assigning maintenence utilization at t=5
# M1 maintaining at t=5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-36e423157408> in <module>()
#      61         system = System(objects=objects, repairman=repairman)
#      62
# ---> 63         system.simulate(simulation_time=7*24*60)
#      64
#      65         samples.append(sink.level)
#
# C:\Users\Michael\Dev\simantha\simantha\System.py in simulate(self, warm_up_time, simulation_time, verbose, debug)
#     117             # test this here
#     118             for machine in self.machines:
# --> 119                 machine.maintain()
#     120
#     121             shuffled_machines = random.sample(self.machines, len(self.machines))
#
# C:\Users\Michael\Dev\simantha\simantha\Machine.py in maintain(self)
#     179                 self.maintenance_data['event'].append('begin maintenance')
#     180
# --> 181                 self.remaining_ttr = self.get_ttr()
#     182                 print(f'{self.name} TTR at t={self.env.clock}: {self.remaining_ttr}')
#     183
#
# C:\Users\Michael\Dev\simantha\simantha\Machine.py in get_ttr(self)
#     248             return rng(self.cm_distribution)
#     249         else:
# --> 250             return rng(self.pm_distribution)
#     251
#     252     def define_routing(self, upstream=[], downstream=[]):
#
# C:\Users\Michael\Dev\simantha\simantha\simulation.py in rng(dist)
#      12
#      13 def rng(dist):
# ---> 14     if 'constant' in dist.keys():
#      15         # return deterministic value
#      16         return dist['constant']
#
# AttributeError: 'int' object has no attribute 'keys'

# %%
plt.figure(figsize=(12,6))

plt.plot(policies, [sum(samples)/n for samples in production])

plt.xlabel('CBM policy')
plt.ylabel('Average weekly production')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-307479c64cf6> in <module>()
#       1 plt.figure(figsize=(12,6))
#       2
# ----> 3 plt.plot(policies, [sum(samples)/n for samples in production])
#       4
#       5 plt.xlabel('CBM policy')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     383             x, y = index_of(tup[-1])
#     384
# --> 385         x, y = self._xy_from_xy(x, y)
#     386
#     387         if self.command == 'plot':
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     242         if x.shape[0] != y.shape[0]:
#     243             raise ValueError("x and y must have same first dimension, but "
# --> 244                              "have shapes {} and {}".format(x.shape, y.shape))
#     245         if x.ndim > 2 or y.ndim > 2:
#     246             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (0,)

# %%
random.seed(1)

degradation_matrix = [
    [0.9, 0.1, 0, 0, 0],
    [0, 0.9, 0.1, 0, 0],
    [0, 0, 0.9, 0.1, 0],
    [0, 0, 0, 0.9, 0.1],
    [0, 0, 0, 0, 1]
]

source = Source()
M1 = Machine(
    'M1', 
    cycle_time=2, 
    degradation_matrix=degradation_matrix, 
    cbm_threshold=3,
    pm_distribution={'uniform':[5, 10]},
    cm_distribution={'uniform':[10, 20]}
)
sink = Sink()

M1.define_routing(upstream=[source], downstream=[sink])

system = System(objects=[source, M1, sink])

system.simulate(simulation_time=200)
# Out:
# M1 getting part at t=0
# M1 processing part at t=0
# M1 processing part at t=1
# M1 putting part at t=2
# M1 getting part at t=2
# M1 processing part at t=2
# M1 processing part at t=3
# M1 putting part at t=4
# M1 getting part at t=4
# M1 processing part at t=4
# M1 processing part at t=5
# M1 putting part at t=6
# M1 getting part at t=6
# M1 processing part at t=6
# M1 processing part at t=7
# M1 putting part at t=8
# M1 getting part at t=8
# M1 processing part at t=8
# M1 processing part at t=9
# M1 putting part at t=10
# M1 getting part at t=10
# M1 processing part at t=10
# M1 processing part at t=11
# M1 putting part at t=12
# M1 getting part at t=12
# M1 processing part at t=12
# M1 processing part at t=13
# M1 putting part at t=14
# M1 getting part at t=14
# M1 processing part at t=14
# M1 processing part at t=15
# M1 putting part at t=16
# M1 getting part at t=16
# M1 processing part at t=16
# M1 processing part at t=17
# M1 putting part at t=18
# M1 getting part at t=18
# M1 processing part at t=18
# M1 processing part at t=19
# M1 putting part at t=20
# M1 getting part at t=20
# M1 processing part at t=20
# M1 processing part at t=21
# M1 putting part at t=22
# M1 getting part at t=22
# M1 processing part at t=22
# M1 processing part at t=23
# M1 putting part at t=24
# M1 getting part at t=24
# M1 processing part at t=24
# M1 processing part at t=25
# M1 putting part at t=26
# Assigning maintenence utilization at t=26
# M1 maintaining at t=26
# M1 TTR at t=26: 10
# M1 maintaining at t=27
# M1 maintaining at t=28
# M1 maintaining at t=29
# M1 maintaining at t=30
# M1 maintaining at t=31
# M1 maintaining at t=32
# M1 maintaining at t=33
# M1 maintaining at t=34
# M1 maintaining at t=35
# M1 restored at t=36
# Releasing maintenance utilization at t=36
# M1 getting part at t=36
# M1 processing part at t=36
# M1 processing part at t=37
# M1 putting part at t=38
# M1 getting part at t=38
# M1 processing part at t=38
# M1 processing part at t=39
# M1 putting part at t=40
# M1 getting part at t=40
# M1 processing part at t=40
# M1 processing part at t=41
# M1 putting part at t=42
# M1 getting part at t=42
# M1 processing part at t=42
# M1 processing part at t=43
# M1 putting part at t=44
# M1 getting part at t=44
# M1 processing part at t=44
# M1 processing part at t=45
# M1 putting part at t=46
# M1 getting part at t=46
# M1 processing part at t=46
# M1 processing part at t=47
# M1 putting part at t=48
# M1 getting part at t=48
# M1 processing part at t=48
# M1 processing part at t=49
# M1 putting part at t=50
# M1 getting part at t=50
# M1 processing part at t=50
# M1 processing part at t=51
# M1 putting part at t=52
# M1 getting part at t=52
# M1 processing part at t=52
# M1 processing part at t=53
# M1 putting part at t=54
# M1 getting part at t=54
# M1 processing part at t=54
# M1 processing part at t=55
# M1 putting part at t=56
# M1 getting part at t=56
# M1 processing part at t=56
# M1 processing part at t=57
# M1 putting part at t=58
# M1 getting part at t=58
# M1 processing part at t=58
# M1 processing part at t=59
# M1 putting part at t=60
# M1 getting part at t=60
# M1 processing part at t=60
# M1 processing part at t=61
# M1 putting part at t=62
# Assigning maintenence utilization at t=62
# M1 maintaining at t=62
# M1 TTR at t=62: 7
# M1 maintaining at t=63
# M1 maintaining at t=64
# M1 maintaining at t=65
# M1 maintaining at t=66
# M1 maintaining at t=67
# M1 maintaining at t=68
# M1 restored at t=69
# Releasing maintenance utilization at t=69
# M1 getting part at t=69
# M1 processing part at t=69
# M1 processing part at t=70
# M1 putting part at t=71
# M1 getting part at t=71
# M1 processing part at t=71
# M1 processing part at t=72
# M1 putting part at t=73
# M1 getting part at t=73
# M1 processing part at t=73
# M1 processing part at t=74
# M1 putting part at t=75
# M1 getting part at t=75
# M1 processing part at t=75
# M1 processing part at t=76
# M1 putting part at t=77
# M1 getting part at t=77
# M1 processing part at t=77
# M1 processing part at t=78
# M1 putting part at t=79
# M1 getting part at t=79
# M1 processing part at t=79
# M1 processing part at t=80
# M1 putting part at t=81
# M1 getting part at t=81
# M1 processing part at t=81
# M1 processing part at t=82
# M1 putting part at t=83
# M1 getting part at t=83
# M1 processing part at t=83
# M1 processing part at t=84
# M1 putting part at t=85
# M1 getting part at t=85
# M1 processing part at t=85
# M1 processing part at t=86
# M1 putting part at t=87
# M1 getting part at t=87
# M1 processing part at t=87
# M1 processing part at t=88
# M1 putting part at t=89
# M1 getting part at t=89
# M1 processing part at t=89
# M1 processing part at t=90
# M1 putting part at t=91
# M1 getting part at t=91
# M1 processing part at t=91
# M1 processing part at t=92
# M1 putting part at t=93
# M1 getting part at t=93
# M1 processing part at t=93
# M1 processing part at t=94
# M1 putting part at t=95
# M1 getting part at t=95
# M1 processing part at t=95
# M1 processing part at t=96
# M1 putting part at t=97
# M1 getting part at t=97
# M1 processing part at t=97
# M1 processing part at t=98
# M1 putting part at t=99
# Assigning maintenence utilization at t=99
# M1 maintaining at t=99
# M1 TTR at t=99: 8
# M1 maintaining at t=100
# M1 maintaining at t=101
# M1 maintaining at t=102
# M1 maintaining at t=103
# M1 maintaining at t=104
# M1 maintaining at t=105
# M1 maintaining at t=106
# M1 restored at t=107
# Releasing maintenance utilization at t=107
# M1 getting part at t=107
# M1 processing part at t=107
# M1 processing part at t=108
# M1 putting part at t=109
# M1 getting part at t=109
# M1 processing part at t=109
# M1 processing part at t=110
# M1 putting part at t=111
# M1 getting part at t=111
# M1 processing part at t=111
# M1 processing part at t=112
# M1 putting part at t=113
# M1 getting part at t=113
# M1 processing part at t=113
# M1 processing part at t=114
# M1 putting part at t=115
# M1 getting part at t=115
# M1 processing part at t=115
# M1 processing part at t=116
# M1 putting part at t=117
# M1 getting part at t=117
# M1 processing part at t=117
# M1 processing part at t=118
# M1 putting part at t=119
# M1 getting part at t=119
# M1 processing part at t=119
# M1 processing part at t=120
# M1 putting part at t=121
# M1 getting part at t=121
# M1 processing part at t=121
# M1 processing part at t=122
# M1 putting part at t=123
# M1 getting part at t=123
# M1 processing part at t=123
# M1 processing part at t=124
# M1 putting part at t=125
# M1 getting part at t=125
# M1 processing part at t=125
# M1 processing part at t=126
# M1 putting part at t=127
# M1 getting part at t=127
# M1 processing part at t=127
# M1 processing part at t=128
# M1 putting part at t=129
# M1 getting part at t=129
# M1 processing part at t=129
# M1 processing part at t=130
# M1 putting part at t=131
# M1 getting part at t=131
# M1 processing part at t=131
# M1 processing part at t=132
# M1 putting part at t=133
# M1 getting part at t=133
# M1 processing part at t=133
# M1 processing part at t=134
# M1 putting part at t=135
# M1 getting part at t=135
# M1 processing part at t=135
# M1 processing part at t=136
# M1 putting part at t=137
# M1 getting part at t=137
# M1 processing part at t=137
# M1 processing part at t=138
# M1 putting part at t=139
# M1 getting part at t=139
# M1 processing part at t=139
# M1 processing part at t=140
# M1 putting part at t=141
# M1 getting part at t=141
# M1 processing part at t=141
# M1 processing part at t=142
# M1 putting part at t=143
# M1 getting part at t=143
# M1 processing part at t=143
# M1 processing part at t=144
# M1 putting part at t=145
# M1 getting part at t=145
# M1 processing part at t=145
# M1 processing part at t=146
# M1 putting part at t=147
# M1 getting part at t=147
# M1 processing part at t=147
# M1 processing part at t=148
# M1 putting part at t=149
# M1 getting part at t=149
# M1 processing part at t=149
# M1 processing part at t=150
# M1 putting part at t=151
# Assigning maintenence utilization at t=151
# M1 maintaining at t=151
# M1 TTR at t=151: 10
# M1 maintaining at t=152
# M1 maintaining at t=153
# M1 maintaining at t=154
# M1 maintaining at t=155
# M1 maintaining at t=156
# M1 maintaining at t=157
# M1 maintaining at t=158
# M1 maintaining at t=159
# M1 maintaining at t=160
# M1 restored at t=161
# Releasing maintenance utilization at t=161
# M1 getting part at t=161
# M1 processing part at t=161
# M1 processing part at t=162
# M1 putting part at t=163
# M1 getting part at t=163
# M1 processing part at t=163
# M1 processing part at t=164
# M1 putting part at t=165
# M1 getting part at t=165
# M1 processing part at t=165
# M1 processing part at t=166
# M1 putting part at t=167
# M1 getting part at t=167
# M1 processing part at t=167
# M1 processing part at t=168
# M1 putting part at t=169
# M1 getting part at t=169
# M1 processing part at t=169
# M1 processing part at t=170
# M1 putting part at t=171
# M1 getting part at t=171
# M1 processing part at t=171
# M1 processing part at t=172
# M1 putting part at t=173
# M1 getting part at t=173
# M1 processing part at t=173
# M1 processing part at t=174
# M1 putting part at t=175
# M1 getting part at t=175
# M1 processing part at t=175
# M1 processing part at t=176
# M1 putting part at t=177
# M1 getting part at t=177
# M1 processing part at t=177
# M1 processing part at t=178
# M1 putting part at t=179
# M1 getting part at t=179
# M1 processing part at t=179
# Assigning maintenence utilization at t=180
# M1 maintaining at t=180
# M1 TTR at t=180: 10
# M1 maintaining at t=181
# M1 maintaining at t=182
# M1 maintaining at t=183
# M1 maintaining at t=184
# M1 maintaining at t=185
# M1 maintaining at t=186
# M1 maintaining at t=187
# M1 maintaining at t=188
# M1 maintaining at t=189
# M1 restored at t=190
# Releasing maintenance utilization at t=190
# M1 getting part at t=190
# M1 processing part at t=190
# M1 processing part at t=191
# M1 putting part at t=192
# M1 getting part at t=192
# M1 processing part at t=192
# M1 processing part at t=193
# M1 putting part at t=194
# M1 getting part at t=194
# M1 processing part at t=194
# M1 processing part at t=195
# M1 putting part at t=196
# M1 getting part at t=196
# M1 processing part at t=196
# M1 processing part at t=197
# M1 putting part at t=198
# M1 getting part at t=198
# M1 processing part at t=198
# M1 processing part at t=199
# Simulation finished in 0.01s
# Parts made: 76

# %%
pd.DataFrame(M1.maintenance_data)
# Out:
#                 event  time
# 0       entered queue    26
# 1   begin maintenance    26
# 2            repaired    36
# 3       entered queue    62
# 4   begin maintenance    62
# 5            repaired    69
# 6       entered queue    99
# 7   begin maintenance    99
# 8            repaired   107
# 9       entered queue   151
# 10  begin maintenance   151
# 11           repaired   161
# 12      entered queue   180
# 13  begin maintenance   180
# 14           repaired   190

# %%
pd.DataFrame(M1.production_data)
# Out:
#     production  time
# 0            1     2
# 1            2     4
# 2            3     6
# 3            4     8
# 4            5    10
# 5            6    12
# 6            7    14
# 7            8    16
# 8            9    18
# 9           10    20
# 10          11    22
# 11          12    24
# 12          13    26
# 13          14    38
# 14          15    40
# 15          16    42
# 16          17    44
# 17          18    46
# 18          19    48
# 19          20    50
# 20          21    52
# 21          22    54
# 22          23    56
# 23          24    58
# 24          25    60
# 25          26    62
# 26          27    71
# 27          28    73
# 28          29    75
# 29          30    77
# ..         ...   ...
# 46          47   119
# 47          48   121
# 48          49   123
# 49          50   125
# 50          51   127
# 51          52   129
# 52          53   131
# 53          54   133
# 54          55   135
# 55          56   137
# 56          57   139
# 57          58   141
# 58          59   143
# 59          60   145
# 60          61   147
# 61          62   149
# 62          63   151
# 63          64   163
# 64          65   165
# 65          66   167
# 66          67   169
# 67          68   171
# 68          69   173
# 69          70   175
# 70          71   177
# 71          72   179
# 72          73   192
# 73          74   194
# 74          75   196
# 75          76   198
#
# [76 rows x 2 columns]

# %%
random.seed(1)

degradation_matrix = [
    [0.9, 0.1, 0, 0, 0],
    [0, 0.9, 0.1, 0, 0],
    [0, 0, 0.9, 0.1, 0],
    [0, 0, 0, 0.9, 0.1],
    [0, 0, 0, 0, 1]
]

source = Source()
M1 = Machine('M1', cycle_time=1, degradation_matrix=degradation_matrix, cbm_threshold=3)
B1 = Buffer(capacity=10)
M2 = Machine('M2', cycle_time=1, degradation_matrix=degradation_matrix, cbm_threshold=3)
sink = Sink()

repairman = Repairman(capacity=2)

M1.define_routing(upstream=[source], downstream=[B1])
B1.define_routing(upstream=[M1], downstream=[M2])
M2.define_routing(upstream=[B1], downstream=[sink])

system = System(objects=[source, M1, B1, M2, sink], repairman=repairman)

system.simulate(simulation_time=200)
# Out:
# M1 getting part at t=0
# M1 processing part at t=0
# M1 putting part at t=1
# M2 getting part at t=1
# M1 getting part at t=1
# M1 processing part at t=1
# M2 processing part at t=1
# M1 putting part at t=2
# M2 putting part at t=2
# M1 getting part at t=2
# M2 getting part at t=2
# M1 processing part at t=2
# M2 processing part at t=2
# M1 putting part at t=3
# M2 putting part at t=3
# M1 getting part at t=3
# M2 getting part at t=3
# M1 processing part at t=3
# M2 processing part at t=3
# M1 putting part at t=4
# M2 putting part at t=4
# M1 getting part at t=4
# M2 getting part at t=4
# M1 processing part at t=4
# M2 processing part at t=4
# M1 putting part at t=5
# M2 putting part at t=5
# M1 getting part at t=5
# M2 getting part at t=5
# M1 processing part at t=5
# M2 processing part at t=5
# M1 putting part at t=6
# M2 putting part at t=6
# M1 getting part at t=6
# M2 getting part at t=6
# M1 processing part at t=6
# M2 processing part at t=6
# M1 putting part at t=7
# M2 putting part at t=7
# M2 getting part at t=7
# M1 getting part at t=7
# M1 processing part at t=7
# M2 processing part at t=7
# M1 putting part at t=8
# M2 putting part at t=8
# M1 getting part at t=8
# M2 getting part at t=8
# M1 processing part at t=8
# M2 processing part at t=8
# M1 putting part at t=9
# M2 putting part at t=9
# M2 getting part at t=9
# M1 getting part at t=9
# M1 processing part at t=9
# M2 processing part at t=9
# M1 putting part at t=10
# M2 putting part at t=10
# M1 getting part at t=10
# M2 getting part at t=10
# M1 processing part at t=10
# M2 processing part at t=10
# M1 putting part at t=11
# M2 putting part at t=11
# M1 getting part at t=11
# M2 getting part at t=11
# M1 processing part at t=11
# M2 processing part at t=11
# M1 putting part at t=12
# M2 putting part at t=12
# M1 getting part at t=12
# M2 getting part at t=12
# M1 processing part at t=12
# M2 processing part at t=12
# M1 putting part at t=13
# M2 putting part at t=13
# M2 getting part at t=13
# M1 getting part at t=13
# M1 processing part at t=13
# M2 processing part at t=13
# M1 putting part at t=14
# M2 putting part at t=14
# M2 getting part at t=14
# M1 getting part at t=14
# M1 processing part at t=14
# M2 processing part at t=14
# M1 putting part at t=15
# M2 putting part at t=15
# M1 getting part at t=15
# M2 getting part at t=15
# M1 processing part at t=15
# M2 processing part at t=15
# M1 putting part at t=16
# M2 putting part at t=16
# M1 getting part at t=16
# M2 getting part at t=16
# M1 processing part at t=16
# M2 processing part at t=16
# M1 putting part at t=17
# M2 putting part at t=17
# M2 getting part at t=17
# M1 getting part at t=17
# M1 processing part at t=17
# M2 processing part at t=17
# M1 putting part at t=18
# M2 putting part at t=18
# M1 getting part at t=18
# M2 getting part at t=18
# M1 processing part at t=18
# M2 processing part at t=18
# M1 putting part at t=19
# M2 putting part at t=19
# M1 getting part at t=19
# M2 getting part at t=19
# M1 processing part at t=19
# M2 processing part at t=19
# M1 putting part at t=20
# M2 putting part at t=20
# M2 getting part at t=20
# M1 getting part at t=20
# M1 processing part at t=20
# M2 processing part at t=20
# M1 putting part at t=21
# M2 putting part at t=21
# M1 getting part at t=21
# M2 getting part at t=21
# M1 processing part at t=21
# M2 processing part at t=21
# M1 putting part at t=22
# M2 putting part at t=22
# M1 getting part at t=22
# M2 getting part at t=22
# M1 processing part at t=22
# M2 processing part at t=22
# M1 putting part at t=23
# M2 putting part at t=23
# M2 getting part at t=23
# M1 getting part at t=23
# M1 processing part at t=23
# M2 processing part at t=23
# M1 putting part at t=24
# M2 putting part at t=24
# M2 getting part at t=24
# M1 getting part at t=24
# M1 processing part at t=24
# M2 processing part at t=24
# M1 putting part at t=25
# M2 putting part at t=25
# M1 getting part at t=25
# M2 getting part at t=25
# M1 processing part at t=25
# M2 processing part at t=25
# M1 putting part at t=26
# M2 putting part at t=26
# Assigning maintenence utilization at t=26
# M2 maintaining at t=26
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-d3afe349ccd7> in <module>()
#      23 system = System(objects=[source, M1, B1, M2, sink], repairman=repairman)
#      24
# ---> 25 system.simulate(simulation_time=200)
#
# C:\Users\Michael\Dev\simantha\simantha\System.py in simulate(self, warm_up_time, simulation_time, verbose, debug)
#     117             # test this here
#     118             for machine in self.machines:
# --> 119                 machine.maintain()
#     120
#     121             shuffled_machines = random.sample(self.machines, len(self.machines))
#
# C:\Users\Michael\Dev\simantha\simantha\Machine.py in maintain(self)
#     179                 self.maintenance_data['event'].append('begin maintenance')
#     180
# --> 181                 self.remaining_ttr = self.get_ttr()
#     182                 print(f'{self.name} TTR at t={self.env.clock}: {self.remaining_ttr}')
#     183
#
# C:\Users\Michael\Dev\simantha\simantha\Machine.py in get_ttr(self)
#     248             return rng(self.cm_distribution)
#     249         else:
# --> 250             return rng(self.pm_distribution)
#     251
#     252     def define_routing(self, upstream=[], downstream=[]):
#
# C:\Users\Michael\Dev\simantha\simantha\simulation.py in rng(dist)
#      12
#      13 def rng(dist):
# ---> 14     if 'constant' in dist.keys():
#      15         # return deterministic value
#      16         return dist['constant']
#
# AttributeError: 'int' object has no attribute 'keys'

# %%
results = system.iterate_simulation(simulation_time=1440, replications=10)
# Out:
# M2 maintaining at t=0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-cb41aa3e2bce> in <module>()
# ----> 1 results = system.iterate_simulation(simulation_time=1440, replications=10)
#
# C:\Users\Michael\Dev\simantha\simantha\System.py in iterate_simulation(self, replications, warm_up_time, simulation_time, verbose, jobs)
#     163         results = []
#     164         for _ in range(replications):
# --> 165             self.simulate(warm_up_time, simulation_time, verbose=False)
#     166             results.append(sum([sink.level for sink in self.sinks]))
#     167         stop = time.time()
#
# C:\Users\Michael\Dev\simantha\simantha\System.py in simulate(self, warm_up_time, simulation_time, verbose, debug)
#     117             # test this here
#     118             for machine in self.machines:
# --> 119                 machine.maintain()
#     120
#     121             shuffled_machines = random.sample(self.machines, len(self.machines))
#
# C:\Users\Michael\Dev\simantha\simantha\Machine.py in maintain(self)
#     179                 self.maintenance_data['event'].append('begin maintenance')
#     180
# --> 181                 self.remaining_ttr = self.get_ttr()
#     182                 print(f'{self.name} TTR at t={self.env.clock}: {self.remaining_ttr}')
#     183
#
# C:\Users\Michael\Dev\simantha\simantha\Machine.py in get_ttr(self)
#     248             return rng(self.cm_distribution)
#     249         else:
# --> 250             return rng(self.pm_distribution)
#     251
#     252     def define_routing(self, upstream=[], downstream=[]):
#
# C:\Users\Michael\Dev\simantha\simantha\simulation.py in rng(dist)
#      12
#      13 def rng(dist):
# ---> 14     if 'constant' in dist.keys():
#      15         # return deterministic value
#      16         return dist['constant']
#
# AttributeError: 'int' object has no attribute 'keys'

# %%
pd.DataFrame(M1.maintenance_data)
# Out:
# Empty DataFrame
# Columns: [event, time]
# Index: []

# %%
pd.DataFrame(M2.maintenance_data)
# Out:
#                event  time
# 0      entered queue    26
# 1  begin maintenance    26
# 2  begin maintenance     0

# %% [markdown]
# Random part routing test - multiple machines drawing from one buffer should be prioritized randomly

# %%
random.seed(1)

n = 100
m2_production = []
m3_production = []
for _ in range(n):
    source = Source()

    M1 = Machine(name='M1', cycle_time=2)
    B1 = Buffer(capacity=10)

    M2 = Machine(name='M2', cycle_time=2)
    M3 = Machine(name='M3', cycle_time=2)

    sink = Sink()

    source.define_routing(downstream=[M1])
    M1.define_routing(upstream=[source], downstream=[B1])
    B1.define_routing(upstream=[M1], downstream=[M2, M3])
    M2.define_routing(upstream=[B1], downstream=[sink])
    M3.define_routing(upstream=[B1], downstream=[sink])
    sink.define_routing(upstream=[M2, M3])

    objects = [source, M1, M2, M3, sink]
    system = System(objects=objects)

    system.simulate(simulation_time=100)
    
    m2_production.append(M2.parts_made)
    m3_production.append(M3.parts_made)

# for machine in [M1, M2, M3]:
#     print(f'{machine.name} parts made: {machine.parts_made}')
# print(f'\nTotal parts made: {sink.level}')

print(f'M2 average parts made: {sum(m2_production)/n}')
print(f'M3 average parts made: {sum(m3_production)/n}')
# Out:
# M1 getting part at t=0
# M1 processing part at t=0
# M1 processing part at t=1
# M1 putting part at t=2
# M2 getting part at t=2
# M1 getting part at t=2
# M1 processing part at t=2
# M2 processing part at t=2
# M1 processing part at t=3
# M2 processing part at t=3
# M1 putting part at t=4
# M2 putting part at t=4
# M2 getting part at t=4
# M1 getting part at t=4
# M1 processing part at t=4
# M2 processing part at t=4
# M1 processing part at t=5
# M2 processing part at t=5
# M1 putting part at t=6
# M2 putting part at t=6
# M3 getting part at t=6
# M1 getting part at t=6
# M1 processing part at t=6
# M3 processing part at t=6
# M1 processing part at t=7
# M3 processing part at t=7
# M1 putting part at t=8
# M3 putting part at t=8
# M2 getting part at t=8
# M1 getting part at t=8
# M1 processing part at t=8
# M2 processing part at t=8
# M1 processing part at t=9
# M2 processing part at t=9
# M1 putting part at t=10
# M2 putting part at t=10
# M2 getting part at t=10
# M1 getting part at t=10
# M1 processing part at t=10
# M2 processing part at t=10
# M1 processing part at t=11
# M2 processing part at t=11
# M1 putting part at t=12
# M2 putting part at t=12
# M3 getting part at t=12
# M1 getting part at t=12
# M1 processing part at t=12
# M3 processing part at t=12
# M1 processing part at t=13
# M3 processing part at t=13
# M1 putting part at t=14
# M3 putting part at t=14
# M3 getting part at t=14
# M1 getting part at t=14
# M1 processing part at t=14
# M3 processing part at t=14
# M1 processing part at t=15
# M3 processing part at t=15
# M1 putting part at t=16
# M3 putting part at t=16
# M2 getting part at t=16
# M1 getting part at t=16
# M1 processing part at t=16
# M2 processing part at t=16
# M1 processing part at t=17
# M2 processing part at t=17
# M1 putting part at t=18
# M2 putting part at t=18
# M2 getting part at t=18
# M1 getting part at t=18
# M1 processing part at t=18
# M2 processing part at t=18
# M1 processing part at t=19
# M2 processing part at t=19
# M1 putting part at t=20
# M2 putting part at t=20
# M2 getting part at t=20
# M1 getting part at t=20
# M1 processing part at t=20
# M2 processing part at t=20
# M1 processing part at t=21
# M2 processing part at t=21
# M1 putting part at t=22
# M2 putting part at t=22
# M1 getting part at t=22
# M2 getting part at t=22
# M1 processing part at t=22
# M2 processing part at t=22
# M1 processing part at t=23
# M2 processing part at t=23
# M1 putting part at t=24
# M2 putting part at t=24
# M3 getting part at t=24
# M1 getting part at t=24
# M1 processing part at t=24
# M3 processing part at t=24
# M1 processing part at t=25
# M3 processing part at t=25
# M1 putting part at t=26
# M3 putting part at t=26
# M3 getting part at t=26
# M1 getting part at t=26
# M1 processing part at t=26
# M3 processing part at t=26
# M1 processing part at t=27
# M3 processing part at t=27
# M1 putting part at t=28
# M3 putting part at t=28
# M3 getting part at t=28
# M1 getting part at t=28
# M1 processing part at t=28
# M3 processing part at t=28
# M1 processing part at t=29
# M3 processing part at t=29
# M1 putting part at t=30
# M3 putting part at t=30
# M1 getting part at t=30
# M3 getting part at t=30
# M1 processing part at t=30
# M3 processing part at t=30
# M1 processing part at t=31
# M3 processing part at t=31
# M1 putting part at t=32
# M3 putting part at t=32
# M2 getting part at t=32
# M1 getting part at t=32
# M1 processing part at t=32
# M2 processing part at t=32
# M1 processing part at t=33
# M2 processing part at t=33
# M1 putting part at t=34
# M2 putting part at t=34
# M1 getting part at t=34
# M2 getting part at t=34
# M1 processing part at t=34
# M2 processing part at t=34
# M1 processing part at t=35
# M2 processing part at t=35
# M1 putting part at t=36
# M2 putting part at t=36
# M2 getting part at t=36
# M1 getting part at t=36
# M1 processing part at t=36
# M2 processing part at t=36
# M1 processing part at t=37
# M2 processing part at t=37
# M1 putting part at t=38
# M2 putting part at t=38
# M1 getting part at t=38
# M2 getting part at t=38
# M1 processing part at t=38
# M2 processing part at t=38
# M1 processing part at t=39
# M2 processing part at t=39
# M1 putting part at t=40
# M2 putting part at t=40
# M2 getting part at t=40
# M1 getting part at t=40
# M1 processing part at t=40
# M2 processing part at t=40
# M1 processing part at t=41
# M2 processing part at t=41
# M1 putting part at t=42
# M2 putting part at t=42
# M2 getting part at t=42
# M1 getting part at t=42
# M1 processing part at t=42
# M2 processing part at t=42
# M1 processing part at t=43
# M2 processing part at t=43
# M1 putting part at t=44
# M2 putting part at t=44
# M1 getting part at t=44
# M3 getting part at t=44
# M1 processing part at t=44
# M3 processing part at t=44
# M1 processing part at t=45
# M3 processing part at t=45
# M1 putting part at t=46
# M3 putting part at t=46
# M1 getting part at t=46
# M2 getting part at t=46
# M1 processing part at t=46
# M2 processing part at t=46
# M1 processing part at t=47
# M2 processing part at t=47
# M1 putting part at t=48
# M2 putting part at t=48
# M2 getting part at t=48
# M1 getting part at t=48
# M1 processing part at t=48
# M2 processing part at t=48
# M1 processing part at t=49
# M2 processing part at t=49
# M1 putting part at t=50
# M2 putting part at t=50
# M3 getting part at t=50
# M1 getting part at t=50
# M1 processing part at t=50
# M3 processing part at t=50
# M1 processing part at t=51
# M3 processing part at t=51
# M1 putting part at t=52
# M3 putting part at t=52
# M2 getting part at t=52
# M1 getting part at t=52
# M1 processing part at t=52
# M2 processing part at t=52
# M1 processing part at t=53
# M2 processing part at t=53
# M1 putting part at t=54
# M2 putting part at t=54
# M3 getting part at t=54
# M1 getting part at t=54
# M1 processing part at t=54
# M3 processing part at t=54
# M1 processing part at t=55
# M3 processing part at t=55
# M1 putting part at t=56
# M3 putting part at t=56
# M3 getting part at t=56
# M1 getting part at t=56
# M1 processing part at t=56
# M3 processing part at t=56
# M1 processing part at t=57
# M3 processing part at t=57
# M1 putting part at t=58
# M3 putting part at t=58
# M1 getting part at t=58
# M2 getting part at t=58
# M1 processing part at t=58
# M2 processing part at t=58
# M1 processing part at t=59
# M2 processing part at t=59
# M1 putting part at t=60
# M2 putting part at t=60
# M2 getting part at t=60
# M1 getting part at t=60
# M1 processing part at t=60
# M2 processing part at t=60
# M1 processing part at t=61
# M2 processing part at t=61
# M1 putting part at t=62
# M2 putting part at t=62
# M1 getting part at t=62
# M2 getting part at t=62
# M1 processing part at t=62
# M2 processing part at t=62
# M1 processing part at t=63
# M2 processing part at t=63
# M1 putting part at t=64
# M2 putting part at t=64
# M2 getting part at t=64
# M1 getting part at t=64
# M1 processing part at t=64
# M2 processing part at t=64
# M1 processing part at t=65
# M2 processing part at t=65
# M1 putting part at t=66
# M2 putting part at t=66
# M1 getting part at t=66
# M2 getting part at t=66
# M1 processing part at t=66
# M2 processing part at t=66
# M1 processing part at t=67
# M2 processing part at t=67
# M1 putting part at t=68
# M2 putting part at t=68
# M3 getting part at t=68
# M1 getting part at t=68
# M1 processing part at t=68
# M3 processing part at t=68
# M1 processing part at t=69
# M3 processing part at t=69
# M1 putting part at t=70
# M3 putting part at t=70
# M1 getting part at t=70
# M2 getting part at t=70
# M1 processing part at t=70
# M2 processing part at t=70
# M1 processing part at t=71
# M2 processing part at t=71
# M1 putting part at t=72
# M2 putting part at t=72
# M2 getting part at t=72
# M1 getting part at t=72
# M1 processing part at t=72
# M2 processing part at t=72
# M1 processing part at t=73
# M2 processing part at t=73
# M1 putting part at t=74
# M2 putting part at t=74
# M3 getting part at t=74
# M1 getting part at t=74
# M1 processing part at t=74
# M3 processing part at t=74
# M1 processing part at t=75
# M3 processing part at t=75
# M1 putting part at t=76
# M3 putting part at t=76
# M1 getting part at t=76
# M2 getting part at t=76
# M1 processing part at t=76
# M2 processing part at t=76
# M1 processing part at t=77
# M2 processing part at t=77
# M1 putting part at t=78
# M2 putting part at t=78
# M2 getting part at t=78
# M1 getting part at t=78
# M1 processing part at t=78
# M2 processing part at t=78
# M1 processing part at t=79
# M2 processing part at t=79
# M1 putting part at t=80
# M2 putting part at t=80
# M3 getting part at t=80
# M1 getting part at t=80
# M1 processing part at t=80
# M3 processing part at t=80
# M1 processing part at t=81
# M3 processing part at t=81
# M1 putting part at t=82
# M3 putting part at t=82
# M3 getting part at t=82
# M1 getting part at t=82
# M1 processing part at t=82
# M3 processing part at t=82
# M1 processing part at t=83
# M3 processing part at t=83
# M1 putting part at t=84
# M3 putting part at t=84
# M1 getting part at t=84
# M2 getting part at t=84
# M1 processing part at t=84
# M2 processing part at t=84
# M1 processing part at t=85
# M2 processing part at t=85
# M1 putting part at t=86
# M2 putting part at t=86
# M1 getting part at t=86
# M3 getting part at t=86
# M1 processing part at t=86
# M3 processing part at t=86
# M1 processing part at t=87
# M3 processing part at t=87
# M1 putting part at t=88
# M3 putting part at t=88
# M3 getting part at t=88
# M1 getting part at t=88
# M1 processing part at t=88
# M3 processing part at t=88
# M1 processing part at t=89
# M3 processing part at t=89
# M1 putting part at t=90
# M3 putting part at t=90
# M1 getting part at t=90
# M2 getting part at t=90
# M1 processing part at t=90
# M2 processing part at t=90
# M1 processing part at t=91
# M2 processing part at t=91
# M1 putting part at t=92
# M2 putting part at t=92
# M1 getting part at t=92
# M3 getting part at t=92
# M1 processing part at t=92
# M3 processing part at t=92
# M1 processing part at t=93
# M3 processing part at t=93
# M1 putting part at t=94
# M3 putting part at t=94
# M3 getting part at t=94
# M1 getting part at t=94
# M1 processing part at t=94
# M3 processing part at t=94
# M1 processing part at t=95
# M3 processing part at t=95
# M1 putting part at t=96
# M3 putting part at t=96
# M3 getting part at t=96
# M1 getting part at t=96
# M1 processing part at t=96
# M3 processing part at t=96
# M1 processing part at t=97
# M3 processing part at t=97
# M1 putting part at t=98
# M3 putting part at t=98
# M2 getting part at t=98
# M1 getting part at t=98
# M1 processing part at t=98
# M2 processing part at t=98
# M1 processing part at t=99
# M2 processing part at t=99
# Simulation finished in 0.01s
# Parts made: 48
# M1 getting part at t=0
# M1 processing part at t=0
# M1 processing part at t=1
# M1 putting part at t=2
# M2 getting part at t=2
# M1 getting part at t=2
# M1 processing part at t=2
# M2 processing part at t=2
# M1 processing part at t=3
# M2 processing part at t=3
# M1 putting part at t=4
# M2 putting part at t=4
# M3 getting part at t=4
# M1 getting part at t=4
# M1 processing part at t=4
# M3 processing part at t=4
# M1 processing part at t=5
# M3 processing part at t=5
# M1 putting part at t=6
# M3 putting part at t=6
# M3 getting part at t=6
# M1 getting part at t=6
# M1 processing part at t=6
# M3 processing part at t=6
# M1 processing part at t=7
# M3 processing part at t=7
# M1 putting part at t=8
# M3 putting part at t=8
# M3 getting part at t=8
# M1 getting part at t=8
# M1 processing part at t=8
# M3 processing part at t=8
# M1 processing part at t=9
# M3 processing part at t=9
# M1 putting part at t=10
# M3 putting part at t=10
# M3 getting part at t=10
# M1 getting part at t=10
# M1 processing part at t=10
# M3 processing part at t=10
# M1 processing part at t=11
# M3 processing part at t=11
# M1 putting part at t=12
# M3 putting part at t=12
# M3 getting part at t=12
# M1 getting part at t=12
# M1 processing part at t=12
# M3 processing part at t=12
# M1 processing part at t=13
# M3 processing part at t=13
# M1 putting part at t=14
# M3 putting part at t=14
# M2 getting part at t=14
# M1 getting part at t=14
# M1 processing part at t=14
# M2 processing part at t=14
# M1 processing part at t=15
# M2 processing part at t=15
# M1 putting part at t=16
# M2 putting part at t=16
# M1 getting part at t=16
# M3 getting part at t=16
# M1 processing part at t=16
# M3 processing part at t=16
# M1 processing part at t=17
# M3 processing part at t=17
# M1 putting part at t=18
# M3 putting part at t=18
# M3 getting part at t=18
# M1 getting part at t=18
# M1 processing part at t=18
# M3 processing part at t=18
# M1 processing part at t=19
# M3 processing part at t=19
# M1 putting part at t=20
# M3 putting part at t=20
# M3 getting part at t=20
# M1 getting part at t=20
# M1 processing part at t=20
# M3 processing part at t=20
# M1 processing part at t=21
# M3 processing part at t=21
# M1 putting part at t=22
# M3 putting part at t=22
# M3 getting part at t=22
# M1 getting part at t=22
# M1 processing part at t=22
# M3 processing part at t=22
# M1 processing part at t=23
# M3 processing part at t=23
# M1 putting part at t=24
# M3 putting part at t=24
# M1 getting part at t=24
# M2 getting part at t=24
# M1 processing part at t=24
# M2 processing part at t=24
# M1 processing part at t=25
# M2 processing part at t=25
# M1 putting part at t=26
# M2 putting part at t=26
# M1 getting part at t=26
# M3 getting part at t=26
# M1 processing part at t=26
# M3 processing part at t=26
# M1 processing part at t=27
# M3 processing part at t=27
# M1 putting part at t=28
# M3 putting part at t=28
# M3 getting part at t=28
# M1 getting part at t=28
# M1 processing part at t=28
# M3 processing part at t=28
# M1 processing part at t=29
# M3 processing part at t=29
# M1 putting part at t=30
# M3 putting part at t=30
# M3 getting part at t=30
# M1 getting part at t=30
# M1 processing part at t=30
# M3 processing part at t=30
# M1 processing part at t=31
# M3 processing part at t=31
# M1 putting part at t=32
# M3 putting part at t=32
# M1 getting part at t=32
# M3 getting part at t=32
# M1 processing part at t=32
# M3 processing part at t=32
# M1 processing part at t=33
# M3 processing part at t=33
# M1 putting part at t=34
# M3 putting part at t=34
# M3 getting part at t=34
# M1 getting part at t=34
# M1 processing part at t=34
# M3 processing part at t=34
# M1 processing part at t=35
# M3 processing part at t=35
# M1 putting part at t=36
# M3 putting part at t=36
# M2 getting part at t=36
# M1 getting part at t=36
# M1 processing part at t=36
# M2 processing part at t=36
# M1 processing part at t=37
# M2 processing part at t=37
# M1 putting part at t=38
# M2 putting part at t=38
# M3 getting part at t=38
# M1 getting part at t=38
# M1 processing part at t=38
# M3 processing part at t=38
# M1 processing part at t=39
# M3 processing part at t=39
# M1 putting part at t=40
# M3 putting part at t=40
# M3 getting part at t=40
# M1 getting part at t=40
# M1 processing part at t=40
# M3 processing part at t=40
# M1 processing part at t=41
# M3 processing part at t=41
# M1 putting part at t=42
# M3 putting part at t=42
# M3 getting part at t=42
# M1 getting part at t=42
# M1 processing part at t=42
# M3 processing part at t=42
# M1 processing part at t=43
# M3 processing part at t=43
# M1 putting part at t=44
# M3 putting part at t=44
# M1 getting part at t=44
# M3 getting part at t=44
# M1 processing part at t=44
# M3 processing part at t=44
# M1 processing part at t=45
# M3 processing part at t=45
# M1 putting part at t=46
# M3 putting part at t=46
# M3 getting part at t=46
# M1 getting part at t=46
# M1 processing part at t=46
# M3 processing part at t=46
# M1 processing part at t=47
# M3 processing part at t=47
# M1 putting part at t=48
# M3 putting part at t=48
# M2 getting part at t=48
# M1 getting part at t=48
# M1 processing part at t=48
# M2 processing part at t=48
# M1 processing part at t=49
# M2 processing part at t=49
# M1 putting part at t=50
# M2 putting part at t=50
# M2 getting part at t=50
# M1 getting part at t=50
# M1 processing part at t=50
# M2 processing part at t=50
# M1 processing part at t=51
# M2 processing part at t=51
# M1 putting part at t=52
# M2 putting part at t=52
# M3 getting part at t=52
# M1 getting part at t=52
# M1 processing part at t=52
# M3 processing part at t=52
# M1 processing part at t=53
# M3 processing part at t=53
# M1 putting part at t=54
# M3 putting part at t=54
# M1 getting part at t=54
# M2 getting part at t=54
# M1 processing part at t=54
# M2 processing part at t=54
# M1 processing part at t=55
# M2 processing part at t=55
# M1 putting part at t=56
# M2 putting part at t=56
# M2 getting part at t=56
# M1 getting part at t=56
# M1 processing part at t=56
# M2 processing part at t=56
# M1 processing part at t=57
# M2 processing part at t=57
# M1 putting part at t=58
# M2 putting part at t=58
# M3 getting part at t=58
# M1 getting part at t=58
# M1 processing part at t=58
# M3 processing part at t=58
# M1 processing part at t=59
# M3 processing part at t=59
# M1 putting part at t=60
# M3 putting part at t=60
# M2 getting part at t=60
# M1 getting part at t=60
# M1 processing part at t=60
# M2 processing part at t=60
# M1 processing part at t=61
# M2 processing part at t=61
# M1 putting part at t=62
# M2 putting part at t=62
# M1 getting part at t=62
# M2 getting part at t=62
# M1 processing part at t=62
# M2 processing part at t=62
# M1 processing part at t=63
# M2 processing part at t=63
# M1 putting part at t=64
# M2 putting part at t=64
# M2 getting part at t=64
# M1 getting part at t=64
# M1 processing part at t=64
# M2 processing part at t=64
# M1 processing part at t=65
# M2 processing part at t=65
# M1 putting part at t=66
# M2 putting part at t=66
# M3 getting part at t=66
# M1 getting part at t=66
# M1 processing part at t=66
# M3 processing part at t=66
# M1 processing part at t=67
# M3 processing part at t=67
# M1 putting part at t=68
# M3 putting part at t=68
# M3 getting part at t=68
# M1 getting part at t=68
# M1 processing part at t=68
# M3 processing part at t=68
# M1 processing part at t=69
# M3 processing part at t=69
# M1 putting part at t=70
# M3 putting part at t=70
# M3 getting part at t=70
# M1 getting part at t=70
# M1 processing part at t=70
# M3 processing part at t=70
# M1 processing part at t=71
# M3 processing part at t=71
# M1 putting part at t=72
# M3 putting part at t=72
# M1 getting part at t=72
# M2 getting part at t=72
# M1 processing part at t=72
# M2 processing part at t=72
# M1 processing part at t=73
# M2 processing part at t=73
# M1 putting part at t=74
# M2 putting part at t=74
# M1 getting part at t=74
# M3 getting part at t=74
# M1 processing part at t=74
# M3 processing part at t=74
# M1 processing part at t=75
# M3 processing part at t=75
# M1 putting part at t=76
# M3 putting part at t=76
# M3 getting part at t=76
# M1 getting part at t=76
# M1 processing part at t=76
# M3 processing part at t=76
# M1 processing part at t=77
# M3 processing part at t=77
# M1 putting part at t=78
# M3 putting part at t=78
# M1 getting part at t=78
# M3 getting part at t=78
# M1 processing part at t=78
# M3 processing part at t=78
# M1 processing part at t=79
# M3 processing part at t=79
# M1 putting part at t=80
# M3 putting part at t=80
# M1 getting part at t=80
# M3 getting part at t=80
# M1 processing part at t=80
# M3 processing part at t=80
# M1 processing part at t=81
# M3 processing part at t=81
# M1 putting part at t=82
# M3 putting part at t=82
# M2 getting part at t=82
# M1 getting part at t=82
# M1 processing part at t=82
# M2 processing part at t=82
# M1 processing part at t=83
# M2 processing part at t=83
# M1 putting part at t=84
# M2 putting part at t=84
# M2 getting part at t=84
# M1 getting part at t=84
# M1 processing part at t=84
# M2 processing part at t=84
# M1 processing part at t=85
# M2 processing part at t=85
# M1 putting part at t=86
# M2 putting part at t=86
# M1 getting part at t=86
# M3 getting part at t=86
# M1 processing part at t=86
# M3 processing part at t=86
# M1 processing part at t=87
# M3 processing part at t=87
# M1 putting part at t=88
# M3 putting part at t=88
# M3 getting part at t=88
# M1 getting part at t=88
# M1 processing part at t=88
# M3 processing part at t=88
# M1 processing part at t=89
# M3 processing part at t=89
# M1 putting part at t=90
# M3 putting part at t=90
# M1 getting part at t=90
# M3 getting part at t=90
# M1 processing part at t=90
# M3 processing part at t=90
# M1 processing part at t=91
# M3 processing part at t=91
# M1 putting part at t=92
# M3 putting part at t=92
# M1 getting part at t=92
# M3 getting part at t=92
# M1 processing part at t=92
# M3 processing part at t=92
# M1 processing part at t=93
# M3 processing part at t=93
# M1 putting part at t=94
# M3 putting part at t=94
# M2 getting part at t=94
# M1 getting part at t=94
# M1 processing part at t=94
# M2 processing part at t=94
# M1 processing part at t=95
# M2 processing part at t=95
# M1 putting part at t=96
# M2 putting part at t=96
# M1 getting part at t=96
# M2 getting part at t=96
# M1 processing part at t=96
# M2 processing part at t=96
# M1 processing part at t=97
# M2 processing part at t=97
# M1 putting part at t=98
# M2 putting part at t=98
# M3 getting part at t=98
# M1 getting part at t=98
# M1 processing part at t=98
# M3 processing part at t=98
# M1 processing part at t=99
# M3 processing part at t=99
# Simulation finished in 0.02s
# Parts made: 48
# M1 getting part at t=0
# M1 processing part at t=0
# M1 processing part at t=1
# M1 putting part at t=2
# M3 getting part at t=2
# M1 getting part at t=2
# M1 processing part at t=2
# M3 processing part at t=2
# M1 processing part at t=3
# M3 processing part at t=3
# M1 putting part at t=4
# M3 putting part at t=4
# M3 getting part at t=4
# M1 getting part at t=4
# M1 processing part at t=4
# M3 processing part at t=4
# M1 processing part at t=5
# M3 processing part at t=5
# M1 putting part at t=6
# M3 putting part at t=6
# M3 getting part at t=6
# M1 getting part at t=6
# M1 processing part at t=6
# M3 processing part at t=6
# M1 processing part at t=7
# M3 processing part at t=7
# M1 putting part at t=8
# M3 putting part at t=8
# M1 getting part at t=8
# M3 getting part at t=8
# M1 processing part at t=8
# M3 processing part at t=8
# M1 processing part at t=9
# M3 processing part at t=9
# M1 putting part at t=10
# M3 putting part at t=10
# M3 getting part at t=10
# M1 getting part at t=10
# M1 processing part at t=10
# M3 processing part at t=10
# M1 processing part at t=11
# M3 processing part at t=11
# M1 putting part at t=12
# M3 putting part at t=12
# M2 getting part at t=12
# M1 getting part at t=12
# M1 processing part at t=12
# M2 processing part at t=12
# M1 processing part at t=13
# M2 processing part at t=13
# M1 putting part at t=14
# M2 putting part at t=14
# M3 getting part at t=14
# M1 getting part at t=14
# M1 processing part at t=14
# M3 processing part at t=14
# M1 processing part at t=15
# M3 processing part at t=15
# M1 putting part at t=16
# M3 putting part at t=16
# M3 getting part at t=16
# M1 getting part at t=16
# M1 processing part at t=16
# M3 processing part at t=16
# M1 processing part at t=17
# M3 processing part at t=17
# M1 putting part at t=18
# M3 putting part at t=18
# M3 getting part at t=18
# M1 getting part at t=18
# M1 processing part at t=18
# M3 processing part at t=18
# M1 processing part at t=19
# M3 processing part at t=19
# M1 putting part at t=20
# M3 putting part at t=20
# M1 getting part at t=20
# M3 getting part at t=20
# M1 processing part at t=20
# M3 processing part at t=20
# M1 processing part at t=21
# M3 processing part at t=21
# M1 putting part at t=22
# M3 putting part at t=22
# M1 getting part at t=22
# M3 getting part at t=22
# M1 processing part at t=22
# M3 processing part at t=22
# M1 processing part at t=23
# M3 processing part at t=23
# M1 putting part at t=24
# M3 putting part at t=24
# M1 getting part at t=24
# M3 getting part at t=24
# M1 processing part at t=24
# M3 processing part at t=24
# M1 processing part at t=25
# M3 processing part at t=25
# M1 putting part at t=26
# M3 putting part at t=26
# M3 getting part at t=26
# M1 getting part at t=26
# M1 processing part at t=26
# M3 processing part at t=26
# M1 processing part at t=27
# M3 processing part at t=27
# M1 putting part at t=28
# M3 putting part at t=28
# M2 getting part at t=28
# M1 getting part at t=28
# M1 processing part at t=28
# M2 processing part at t=28
# M1 processing part at t=29
# M2 processing part at t=29
# M1 putting part at t=30
# M2 putting part at t=30
# M3 getting part at t=30
# M1 getting part at t=30
# M1 processing part at t=30
# M3 processing part at t=30
# M1 processing part at t=31
# M3 processing part at t=31
# M1 putting part at t=32
# M3 putting part at t=32
# M1 getting part at t=32
# M2 getting part at t=32
# M1 processing part at t=32
# M2 processing part at t=32
# M1 processing part at t=33
# M2 processing part at t=33
# M1 putting part at t=34
# M2 putting part at t=34
# M3 getting part at t=34
# M1 getting part at t=34
# M1 processing part at t=34
# M3 processing part at t=34
# M1 processing part at t=35
# M3 processing part at t=35
# M1 putting part at t=36
# M3 putting part at t=36
# M3 getting part at t=36
# M1 getting part at t=36
# M1 processing part at t=36
# M3 processing part at t=36
# M1 processing part at t=37
# M3 processing part at t=37
# M1 putting part at t=38
# M3 putting part at t=38
# M2 getting part at t=38
# M1 getting part at t=38
# M1 processing part at t=38
# M2 processing part at t=38
# M1 processing part at t=39
# M2 processing part at t=39
# M1 putting part at t=40
# M2 putting part at t=40
# M1 getting part at t=40
# M2 getting part at t=40
# M1 processing part at t=40
# M2 processing part at t=40
# M1 processing part at t=41
# M2 processing part at t=41
# M1 putting part at t=42
# M2 putting part at t=42
# M1 getting part at t=42
# M2 getting part at t=42
# M1 processing part at t=42
# M2 processing part at t=42
# M1 processing part at t=43
# M2 processing part at t=43
# M1 putting part at t=44
# M2 putting part at t=44
# M2 getting part at t=44
# M1 getting part at t=44
# M1 processing part at t=44
# M2 processing part at t=44
# M1 processing part at t=45
# M2 processing part at t=45
# M1 putting part at t=46
# M2 putting part at t=46
# M3 getting part at t=46
# M1 getting part at t=46
# M1 processing part at t=46
# M3 processing part at t=46
# M1 processing part at t=47
# M3 processing part at t=47
# M1 putting part at t=48
# M3 putting part at t=48
# M2 getting part at t=48
# M1 getting part at t=48
# M1 processing part at t=48
# M2 processing part at t=48
# M1 processing part at t=49
# M2 processing part at t=49
# M1 putting part at t=50
# M2 putting part at t=50
# M1 getting part at t=50
# M2 getting part at t=50
# M1 processing part at t=50
# M2 processing part at t=50
# M1 processing part at t=51
# M2 processing part at t=51
# M1 putting part at t=52
# M2 putting part at t=52
# M1 getting part at t=52
# M2 getting part at t=52
# M1 processing part at t=52
# M2 processing part at t=52
# M1 processing part at t=53
# M2 processing part at t=53
# M1 putting part at t=54
# M2 putting part at t=54
# M2 getting part at t=54
# M1 getting part at t=54
# M1 processing part at t=54
# M2 processing part at t=54
# M1 processing part at t=55
# M2 processing part at t=55
# M1 putting part at t=56
# M2 putting part at t=56
# M1 getting part at t=56
# M2 getting part at t=56
# M1 processing part at t=56
# M2 processing part at t=56
# M1 processing part at t=57
# M2 processing part at t=57
# M1 putting part at t=58
# M2 putting part at t=58
# M3 getting part at t=58
# M1 getting part at t=58
# M1 processing part at t=58
# M3 processing part at t=58
# M1 processing part at t=59
# M3 processing part at t=59
# M1 putting part at t=60
# M3 putting part at t=60
# M2 getting part at t=60
# M1 getting part at t=60
# M1 processing part at t=60
# M2 processing part at t=60
# M1 processing part at t=61
# M2 processing part at t=61
# M1 putting part at t=62
# M2 putting part at t=62
# M3 getting part at t=62
# M1 getting part at t=62
# M1 processing part at t=62
# M3 processing part at t=62
# M1 processing part at t=63
# M3 processing part at t=63
# M1 putting part at t=64
# M3 putting part at t=64
# M1 getting part at t=64
# M2 getting part at t=64
# M1 processing part at t=64
# M2 processing part at t=64
# M1 processing part at t=65
# M2 processing part at t=65
# M1 putting part at t=66
# M2 putting part at t=66
# M2 getting part at t=66
# M1 getting part at t=66
# M1 processing part at t=66
# M2 processing part at t=66
# M1 processing part at t=67
# M2 processing part at t=67
# M1 putting part at t=68
# M2 putting part at t=68
# M3 getting part at t=68
# M1 getting part at t=68
# M1 processing part at t=68
# M3 processing part at t=68
# M1 processing part at t=69
# M3 processing part at t=69
# M1 putting part at t=70
# M3 putting part at t=70
# M2 getting part at t=70
# M1 getting part at t=70
# M1 processing part at t=70
# M2 processing part at t=70
# M1 processing part at t=71
# M2 processing part at t=71
# M1 putting part at t=72
# M2 putting part at t=72
# M1 getting part at t=72
# M3 getting part at t=72
# M1 processing part at t=72
# M3 processing part at t=72
# M1 processing part at t=73
# M3 processing part at t=73
# M1 putting part at t=74
# M3 putting part at t=74
# M2 getting part at t=74
# M1 getting part at t=74
# M1 processing part at t=74
# M2 processing part at t=74
# M1 processing part at t=75
# M2 processing part at t=75
# M1 putting part at t=76
# M2 putting part at t=76
# M1 getting part at t=76
# M2 getting part at t=76
# M1 processing part at t=76
# M2 processing part at t=76
# M1 processing part at t=77
# M2 processing part at t=77
# M1 putting part at t=78
# M2 putting part at t=78
# M3 getting part at t=78
# M1 getting part at t=78
# M1 processing part at t=78
# M3 processing part at t=78
# M1 processing part at t=79
# M3 processing part at t=79
# M1 putting part at t=80
# M3 putting part at t=80
# M3 getting part at t=80
# M1 getting part at t=80
# M1 processing part at t=80
# M3 processing part at t=80
# M1 processing part at t=81
# M3 processing part at t=81
# M1 putting part at t=82
# M3 putting part at t=82
# M2 getting part at t=82
# M1 getting part at t=82
# M1 processing part at t=82
# M2 processing part at t=82
# M1 processing part at t=83
# M2 processing part at t=83
# M1 putting part at t=84
# M2 putting part at t=84
# M1 getting part at t=84
# M3 getting part at t=84
# M1 processing part at t=84
# M3 processing part at t=84
# M1 processing part at t=85
# M3 processing part at t=85
# M1 putting part at t=86
# M3 putting part at t=86
# M2 getting part at t=86
# M1 getting part at t=86
# M1 processing part at t=86
# M2 processing part at t=86
# M1 processing part at t=87
# M2 processing part at t=87
# M1 putting part at t=88
# M2 putting part at t=88
# M1 getting part at t=88
# M3 getting part at t=88
# M1 processing part at t=88
# M3 processing part at t=88
# M1 processing part at t=89
# M3 processing part at t=89
# M1 putting part at t=90
# M3 putting part at t=90
# M1 getting part at t=90
# M2 getting part at t=90
# M1 processing part at t=90
# M2 processing part at t=90
# M1 processing part at t=91
# M2 processing part at t=91
# M1 putting part at t=92
# M2 putting part at t=92
# M3 getting part at t=92
# M1 getting part at t=92
# M1 processing part at t=92
# M3 processing part at t=92
# M1 processing part at t=93
# M3 processing part at t=93
# M1 putting part at t=94
# M3 putting part at t=94
# M1 getting part at t=94
# M2 getting part at t=94
# M1 processing part at t=94
# M2 processing part at t=94
# M1 processing part at t=95
# M2 processing part at t=95
# M1 putting part at t=96
# M2 putting part at t=96
# M2 getting part at t=96
# M1 getting part at t=96
# M1 processing part at t=96
# M2 processing part at t=96
# M1 processing part at t=97
# M2 processing part at t=97
# M1 putting part at t=98
# M2 putting part at t=98
# M2 getting part at t=98
# M1 getting part at t=98
# M1 processing part at t=98
# M2 processing part at t=98
# M1 processing part at t=99
# M2 processing part at t=99
# Simulation finished in 0.05s
# Parts made: 48
# M1 getting part at t=0
# M1 processing part at t=0
# M1 processing part at t=1
# M1 putting part at t=2
# M1 getting part at t=2
# M2 getting part at t=2
# M1 processing part at t=2
# M2 processing part at t=2
# M1 processing part at t=3
# M2 processing part at t=3
# M1 putting part at t=4
# M2 putting part at t=4
# M1 getting part at t=4
# M2 getting part at t=4
# M1 processing part at t=4
# M2 processing part at t=4
# M1 processing part at t=5
# M2 processing part at t=5
# M1 putting part at t=6
# M2 putting part at t=6
# M1 getting part at t=6
# M3 getting part at t=6
# M1 processing part at t=6
# M3 processing part at t=6
# M1 processing part at t=7
# M3 processing part at t=7
# M1 putting part at t=8
# M3 putting part at t=8
# M3 getting part at t=8
# M1 getting part at t=8
# M1 processing part at t=8
# M3 processing part at t=8
# M1 processing part at t=9
# M3 processing part at t=9
# M1 putting part at t=10
# M3 putting part at t=10
# M2 getting part at t=10
# M1 getting part at t=10
# M1 processing part at t=10
# M2 processing part at t=10
# M1 processing part at t=11
# M2 processing part at t=11
# M1 putting part at t=12
# M2 putting part at t=12
# M3 getting part at t=12
# M1 getting part at t=12
# M1 processing part at t=12
# M3 processing part at t=12
# M1 processing part at t=13
# M3 processing part at t=13
# M1 putting part at t=14
# M3 putting part at t=14
# M1 getting part at t=14
# M3 getting part at t=14
# M1 processing part at t=14
# M3 processing part at t=14
# M1 processing part at t=15
# M3 processing part at t=15
# M1 putting part at t=16
# M3 putting part at t=16
# M3 getting part at t=16
# M1 getting part at t=16
# M1 processing part at t=16
# M3 processing part at t=16
# M1 processing part at t=17
# M3 processing part at t=17
# M1 putting part at t=18
# M3 putting part at t=18
# M3 getting part at t=18
# M1 getting part at t=18
# M1 processing part at t=18
# M3 processing part at t=18
# M1 processing part at t=19
# M3 processing part at t=19
# M1 putting part at t=20
# M3 putting part at t=20
# M1 getting part at t=20
# M2 getting part at t=20
# M1 processing part at t=20
# M2 processing part at t=20
# M1 processing part at t=21
# M2 processing part at t=21
# M1 putting part at t=22
# M2 putting part at t=22
# M3 getting part at t=22
# M1 getting part at t=22
# M1 processing part at t=22
# M3 processing part at t=22
# M1 processing part at t=23
# M3 processing part at t=23
# M1 putting part at t=24
# M3 putting part at t=24
# M2 getting part at t=24
# M1 getting part at t=24
# M1 processing part at t=24
# M2 processing part at t=24
# M1 processing part at t=25
# M2 processing part at t=25
# M1 putting part at t=26
# M2 putting part at t=26
# M2 getting part at t=26
# M1 getting part at t=26
# M1 processing part at t=26
# M2 processing part at t=26
# M1 processing part at t=27
# M2 processing part at t=27
# M1 putting part at t=28
# M2 putting part at t=28
# M1 getting part at t=28
# M2 getting part at t=28
# M1 processing part at t=28
# M2 processing part at t=28
# M1 processing part at t=29
# M2 processing part at t=29
# M1 putting part at t=30
# M2 putting part at t=30
# M1 getting part at t=30
# M2 getting part at t=30
# M1 processing part at t=30
# M2 processing part at t=30
# M1 processing part at t=31
# M2 processing part at t=31
# M1 putting part at t=32
# M2 putting part at t=32
# M1 getting part at t=32
# M3 getting part at t=32
# M1 processing part at t=32
# M3 processing part at t=32
# M1 processing part at t=33
# M3 processing part at t=33
# M1 putting part at t=34
# M3 putting part at t=34
# M1 getting part at t=34
# M3 getting part at t=34
# M1 processing part at t=34
# M3 processing part at t=34
# M1 processing part at t=35
# M3 processing part at t=35
# M1 putting part at t=36
# M3 putting part at t=36
# M2 getting part at t=36
# M1 getting part at t=36
# M1 processing part at t=36
# M2 processing part at t=36
# M1 processing part at t=37
# M2 processing part at t=37
# M1 putting part at t=38
# M2 putting part at t=38
# M2 getting part at t=38
# M1 getting part at t=38
# M1 processing part at t=38
# M2 processing part at t=38
# M1 processing part at t=39
# M2 processing part at t=39
# M1 putting part at t=40
# M2 putting part at t=40
# M1 getting part at t=40
# M2 getting part at t=40
# M1 processing part at t=40
# M2 processing part at t=40
# M1 processing part at t=41
# M2 processing part at t=41
# M1 putting part at t=42
# M2 putting part at t=42
# M2 getting part at t=42
# M1 getting part at t=42
# M1 processing part at t=42
# M2 processing part at t=42
# M1 processing part at t=43
# M2 processing part at t=43
# M1 putting part at t=44
# M2 putting part at t=44
# M3 getting part at t=44
# M1 getting part at t=44
# M1 processing part at t=44
# M3 processing part at t=44
# M1 processing part at t=45
# M3 processing part at t=45
# M1 putting part at t=46
# M3 putting part at t=46
# M2 getting part at t=46
# M1 getting part at t=46
# M1 processing part at t=46
# M2 processing part at t=46
# M1 processing part at t=47
# M2 processing part at t=47
# M1 putting part at t=48
# M2 putting part at t=48
# M2 getting part at t=48
# M1 getting part at t=48
# M1 processing part at t=48
# M2 processing part at t=48
# M1 processing part at t=49
# M2 processing part at t=49
# M1 putting part at t=50
# M2 putting part at t=50
# M2 getting part at t=50
# M1 getting part at t=50
# M1 processing part at t=50
# M2 processing part at t=50
# M1 processing part at t=51
# M2 processing part at t=51
# M1 putting part at t=52
# M2 putting part at t=52
# M2 getting part at t=52
# M1 getting part at t=52
# M1 processing part at t=52
# M2 processing part at t=52
# M1 processing part at t=53
# M2 processing part at t=53
# M1 putting part at t=54
# M2 putting part at t=54
# M3 getting part at t=54
# M1 getting part at t=54
# M1 processing part at t=54
# M3 processing part at t=54
# M1 processing part at t=55
# M3 processing part at t=55
# M1 putting part at t=56
# M3 putting part at t=56
# M3 getting part at t=56
# M1 getting part at t=56
# M1 processing part at t=56
# M3 processing part at t=56
# M1 processing part at t=57
# M3 processing part at t=57
# M1 putting part at t=58
# M3 putting part at t=58
# M2 getting part at t=58
# M1 getting part at t=58
# M1 processing part at t=58
# M2 processing part at t=58
# M1 processing part at t=59
# M2 processing part at t=59
# M1 putting part at t=60
# M2 putting part at t=60
# M3 getting part at t=60
# M1 getting part at t=60
# M1 processing part at t=60
# M3 processing part at t=60
# M1 processing part at t=61
# M3 processing part at t=61
# M1 putting part at t=62
# M3 putting part at t=62
# M1 getting part at t=62
# M3 getting part at t=62
# M1 processing part at t=62
# M3 processing part at t=62
# M1 processing part at t=63
# M3 processing part at t=63
# M1 putting part at t=64
# M3 putting part at t=64
# M3 getting part at t=64
# M1 getting part at t=64
# M1 processing part at t=64
# M3 processing part at t=64
# M1 processing part at t=65
# M3 processing part at t=65
# M1 putting part at t=66
# M3 putting part at t=66
# M3 getting part at t=66
# M1 getting part at t=66
# M1 processing part at t=66
# M3 processing part at t=66
# M1 processing part at t=67
# M3 processing part at t=67
# M1 putting part at t=68
# M3 putting part at t=68
# M2 getting part at t=68
# M1 getting part at t=68
# M1 processing part at t=68
# M2 processing part at t=68
# M1 processing part at t=69
# M2 processing part at t=69
# M1 putting part at t=70
# M2 putting part at t=70
# M1 getting part at t=70
# M2 getting part at t=70
# M1 processing part at t=70
# M2 processing part at t=70
# M1 processing part at t=71
# M2 processing part at t=71
# M1 putting part at t=72
# M2 putting part at t=72
# M1 getting part at t=72
# M2 getting part at t=72
# M1 processing part at t=72
# M2 processing part at t=72
# M1 processing part at t=73
# M2 processing part at t=73
# M1 putting part at t=74
# M2 putting part at t=74
# M3 getting part at t=74
# M1 getting part at t=74
# M1 processing part at t=74
# M3 processing part at t=74
# M1 processing part at t=75
# M3 processing part at t=75
# M1 putting part at t=76
# M3 putting part at t=76
# M2 getting part at t=76
# M1 getting part at t=76
# M1 processing part at t=76
# M2 processing part at t=76
# M1 processing part at t=77
# M2 processing part at t=77
# M1 putting part at t=78
# M2 putting part at t=78
# M3 getting part at t=78
# M1 getting part at t=78
# M1 processing part at t=78
# M3 processing part at t=78
# M1 processing part at t=79
# M3 processing part at t=79
# M1 putting part at t=80
# M3 putting part at t=80
# M1 getting part at t=80
# M3 getting part at t=80
# M1 processing part at t=80
# M3 processing part at t=80
# M1 processing part at t=81
# M3 processing part at t=81
# M1 putting part at t=82
# M3 putting part at t=82
# M1 getting part at t=82
# M2 getting part at t=82
# M1 processing part at t=82
# M2 processing part at t=82
# M1 processing part at t=83
# M2 processing part at t=83
# M1 putting part at t=84
# M2 putting part at t=84
# M1 getting part at t=84
# M2 getting part at t=84
# M1 processing part at t=84
# M2 processing part at t=84
# M1 processing part at t=85
# M2 processing part at t=85
# M1 putting part at t=86
# M2 putting part at t=86
# M3 getting part at t=86
# M1 getting part at t=86
# M1 processing part at t=86
# M3 processing part at t=86
# M1 processing part at t=87
# M3 processing part at t=87
# M1 putting part at t=88
# M3 putting part at t=88
# M3 getting part at t=88
# M1 getting part at t=88
# M1 processing part at t=88
# M3 processing part at t=88
# M1 processing part at t=89
# M3 processing part at t=89
# M1 putting part at t=90
# M3 putting part at t=90
# M1 getting part at t=90
# M3 getting part at t=90
# M1 processing part at t=90
# M3 processing part at t=90
# M1 processing part at t=91
# M3 processing part at t=91
# M1 putting part at t=92
# M3 putting part at t=92
# M1 getting part at t=92
# M2 getting part at t=92
# M1 processing part at t=92
# M2 processing part at t=92
# M1 processing part at t=93
# M2 processing part at t=93
# M1 putting part at t=94
# M2 putting part at t=94
# M3 getting part at t=94
# M1 getting part at t=94
# M1 processing part at t=94
# M3 processing part at t=94
# M1 processing part at t=95
# M3 processing part at t=95
# M1 putting part at t=96
# M3 putting part at t=96
# M3 getting part at t=96
# M1 getting part at t=96
# M1 processing part at t=96
# M3 processing part at t=96
# M1 processing part at t=97
# M3 processing part at t=97
# M1 putting part at t=98
# M3 putting part at t=98
# M1 getting part at t=98
# M2 getting part at t=98
# M1 processing part at t=98
# M2 processing part at t=98
# M1 processing part at t=99
# M2 processing part at t=99
# Simulation finished in 0.06s
# Parts made: 48
# M1 getting part at t=0
# M1 processing part at t=0
# M1 processing part at t=1
# M1 putting part at t=2
# M1 getting part at t=2
# M2 getting part at t=2
# M1 processing part at t=2
# M2 processing part at t=2
# M1 processing part at t=3
# M2 processing part at t=3
# M1 putting part at t=4
# M2 putting part at t=4
# M2 getting part at t=4
# M1 getting part at t=4
# M1 processing part at t=4
# M2 processing part at t=4
# M1 processing part at t=5
# M2 processing part at t=5
# M1 putting part at t=6
# M2 putting part at t=6
# M1 getting part at t=6
# M3 getting part at t=6
# M1 processing part at t=6
# M3 processing part at t=6
# M1 processing part at t=7
# M3 processing part at t=7
# M1 putting part at t=8
# M3 putting part at t=8
# M3 getting part at t=8
# M1 getting part at t=8
# M1 processing part at t=8
# M3 processing part at t=8
# M1 processing part at t=9
# M3 processing part at t=9
# M1 putting part at t=10
# M3 putting part at t=10
# M3 getting part at t=10
# M1 getting part at t=10
# M1 processing part at t=10
# M3 processing part at t=10
# M1 processing part at t=11
# M3 processing part at t=11
# M1 putting part at t=12
# M3 putting part at t=12
# M1 getting part at t=12
# M2 getting part at t=12
# M1 processing part at t=12
# M2 processing part at t=12
# M1 processing part at t=13
# M2 processing part at t=13
# M1 putting part at t=14
# M2 putting part at t=14
# M1 getting part at t=14
# M2 getting part at t=14
# M1 processing part at t=14
# M2 processing part at t=14
# M1 processing part at t=15
# M2 processing part at t=15
# M1 putting part at t=16
# M2 putting part at t=16
# M1 getting part at t=16
# M3 getting part at t=16
# M1 processing part at t=16
# M3 processing part at t=16
# M1 processing part at t=17
# M3 processing part at t=17
# M1 putting part at t=18
# M3 putting part at t=18
# M3 getting part at t=18
# M1 getting part at t=18
# M1 processing part at t=18
# M3 processing part at t=18
# M1 processing part at t=19
# M3 processing part at t=19
# M1 putting part at t=20
# M3 putting part at t=20
# M1 getting part at t=20
# M3 getting part at t=20
# M1 processing part at t=20
# M3 processing part at t=20
# M1 processing part at t=21
# M3 processing part at t=21
# M1 putting part at t=22
# M3 putting part at t=22
# M1 getting part at t=22
# M3 getting part at t=22
# M1 processing part at t=22
# M3 processing part at t=22
# M1 processing part at t=23
# M3 processing part at t=23
# M1 putting part at t=24
# M3 putting part at t=24
# M1 getting part at t=24
# M2 getting part at t=24
# M1 processing part at t=24
# M2 processing part at t=24
# M1 processing part at t=25
# M2 processing part at t=25
# M1 putting part at t=26
# M2 putting part at t=26
# M2 getting part at t=26
# M1 getting part at t=26
# M1 processing part at t=26
# M2 processing part at t=26
# M1 processing part at t=27
# M2 processing part at t=27
# M1 putting part at t=28
# M2 putting part at t=28
# M1 getting part at t=28
# M2 getting part at t=28
# M1 processing part at t=28
# M2 processing part at t=28
# M1 processing part at t=29
# M2 processing part at t=29
# M1 putting part at t=30
# M2 putting part at t=30
# M1 getting part at t=30
# M2 getting part at t=30
# M1 processing part at t=30
# M2 processing part at t=30
# M1 processing part at t=31
# M2 processing part at t=31
# M1 putting part at t=32
# M2 putting part at t=32
# M2 getting part at t=32
# M1 getting part at t=32
# M1 processing part at t=32
# M2 processing part at t=32
# M1 processing part at t=33
# M2 processing part at t=33
# M1 putting part at t=34
# M2 putting part at t=34
# M3 getting part at t=34
# M1 getting part at t=34
# M1 processing part at t=34
# M3 processing part at t=34
# M1 processing part at t=35
# M3 processing part at t=35
# M1 putting part at t=36
# M3 putting part at t=36
# M3 getting part at t=36
# M1 getting part at t=36
# M1 processing part at t=36
# M3 processing part at t=36
# M1 processing part at t=37
# M3 processing part at t=37
# M1 putting part at t=38
# M3 putting part at t=38
# M3 getting part at t=38
# M1 getting part at t=38
# M1 processing part at t=38
# M3 processing part at t=38
# M1 processing part at t=39
# M3 processing part at t=39
# M1 putting part at t=40
# M3 putting part at t=40
# M1 getting part at t=40
# M3 getting part at t=40
# M1 processing part at t=40
# M3 processing part at t=40
# M1 processing part at t=41
# M3 processing part at t=41
# M1 putting part at t=42
# M3 putting part at t=42
# M3 getting part at t=42
# M1 getting part at t=42
# M1 processing part at t=42
# M3 processing part at t=42
# M1 processing part at t=43
# M3 processing part at t=43
# M1 putting part at t=44
# M3 putting part at t=44
# M2 getting part at t=44
# M1 getting part at t=44
# M1 processing part at t=44
# M2 processing part at t=44
# M1 processing part at t=45
# M2 processing part at t=45
# M1 putting part at t=46
# M2 putting part at t=46
# M3 getting part at t=46
# M1 getting part at t=46
# M1 processing part at t=46
# M3 processing part at t=46
# M1 processing part at t=47
# M3 processing part at t=47
# M1 putting part at t=48
# M3 putting part at t=48
# M2 getting part at t=48
# M1 getting part at t=48
# M1 processing part at t=48
# M2 processing part at t=48
# M1 processing part at t=49
# M2 processing part at t=49
# M1 putting part at t=50
# M2 putting part at t=50
# M1 getting part at t=50
# M2 getting part at t=50
# M1 processing part at t=50
# M2 processing part at t=50
# M1 processing part at t=51
# M2 processing part at t=51
# M1 putting part at t=52
# M2 putting part at t=52
# M2 getting part at t=52
# M1 getting part at t=52
# M1 processing part at t=52
# M2 processing part at t=52
# M1 processing part at t=53
# M2 processing part at t=53
# M1 putting part at t=54
# M2 putting part at t=54
# M3 getting part at t=54
# M1 getting part at t=54
# M1 processing part at t=54
# M3 processing part at t=54
# M1 processing part at t=55
# M3 processing part at t=55
# M1 putting part at t=56
# M3 putting part at t=56
# M1 getting part at t=56
# M3 getting part at t=56
# M1 processing part at t=56
# M3 processing part at t=56
# M1 processing part at t=57
# M3 processing part at t=57
# M1 putting part at t=58
# M3 putting part at t=58
# M3 getting part at t=58
# M1 getting part at t=58
# M1 processing part at t=58
# M3 processing part at t=58
# M1 processing part at t=59
# M3 processing part at t=59
# M1 putting part at t=60
# M3 putting part at t=60
# M3 getting part at t=60
# M1 getting part at t=60
# M1 processing part at t=60
# M3 processing part at t=60
# M1 processing part at t=61
# M3 processing part at t=61
# M1 putting part at t=62
# M3 putting part at t=62
# M2 getting part at t=62
# M1 getting part at t=62
# M1 processing part at t=62
# M2 processing part at t=62
# M1 processing part at t=63
# M2 processing part at t=63
# M1 putting part at t=64
# M2 putting part at t=64
# M2 getting part at t=64
# M1 getting part at t=64
# M1 processing part at t=64
# M2 processing part at t=64
# M1 processing part at t=65
# M2 processing part at t=65
# M1 putting part at t=66
# M2 putting part at t=66
# M2 getting part at t=66
# M1 getting part at t=66
# M1 processing part at t=66
# M2 processing part at t=66
# M1 processing part at t=67
# M2 processing part at t=67
# M1 putting part at t=68
# M2 putting part at t=68
# M3 getting part at t=68
# M1 getting part at t=68
# M1 processing part at t=68
# M3 processing part at t=68
# M1 processing part at t=69
# M3 processing part at t=69
# M1 putting part at t=70
# M3 putting part at t=70
# M2 getting part at t=70
# M1 getting part at t=70
# M1 processing part at t=70
# M2 processing part at t=70
# M1 processing part at t=71
# M2 processing part at t=71
# M1 putting part at t=72
# M2 putting part at t=72
# M3 getting part at t=72
# M1 getting part at t=72
# M1 processing part at t=72
# M3 processing part at t=72
# M1 processing part at t=73
# M3 processing part at t=73
# M1 putting part at t=74
# M3 putting part at t=74
# M3 getting part at t=74
# M1 getting part at t=74
# M1 processing part at t=74
# M3 processing part at t=74
# M1 processing part at t=75
# M3 processing part at t=75
# M1 putting part at t=76
# M3 putting part at t=76
# M1 getting part at t=76
# M2 getting part at t=76
# M1 processing part at t=76
# M2 processing part at t=76
# M1 processing part at t=77
# ...
# M1 processing part at t=42
# M3 processing part at t=42
# M1 processing part at t=43
# M3 processing part at t=43
# M1 putting part at t=44
# M3 putting part at t=44
# M3 getting part at t=44
# M1 getting part at t=44
# M1 processing part at t=44
# M3 processing part at t=44
# M1 processing part at t=45
# M3 processing part at t=45
# M1 putting part at t=46
# M3 putting part at t=46
# M3 getting part at t=46
# M1 getting part at t=46
# M1 processing part at t=46
# M3 processing part at t=46
# M1 processing part at t=47
# M3 processing part at t=47
# M1 putting part at t=48
# M3 putting part at t=48
# M3 getting part at t=48
# M1 getting part at t=48
# M1 processing part at t=48
# M3 processing part at t=48
# M1 processing part at t=49
# M3 processing part at t=49
# M1 putting part at t=50
# M3 putting part at t=50
# M2 getting part at t=50
# M1 getting part at t=50
# M1 processing part at t=50
# M2 processing part at t=50
# M1 processing part at t=51
# M2 processing part at t=51
# M1 putting part at t=52
# M2 putting part at t=52
# M1 getting part at t=52
# M2 getting part at t=52
# M1 processing part at t=52
# M2 processing part at t=52
# M1 processing part at t=53
# M2 processing part at t=53
# M1 putting part at t=54
# M2 putting part at t=54
# M1 getting part at t=54
# M3 getting part at t=54
# M1 processing part at t=54
# M3 processing part at t=54
# M1 processing part at t=55
# M3 processing part at t=55
# M1 putting part at t=56
# M3 putting part at t=56
# M1 getting part at t=56
# M3 getting part at t=56
# M1 processing part at t=56
# M3 processing part at t=56
# M1 processing part at t=57
# M3 processing part at t=57
# M1 putting part at t=58
# M3 putting part at t=58
# M2 getting part at t=58
# M1 getting part at t=58
# M1 processing part at t=58
# M2 processing part at t=58
# M1 processing part at t=59
# M2 processing part at t=59
# M1 putting part at t=60
# M2 putting part at t=60
# M3 getting part at t=60
# M1 getting part at t=60
# M1 processing part at t=60
# M3 processing part at t=60
# M1 processing part at t=61
# M3 processing part at t=61
# M1 putting part at t=62
# M3 putting part at t=62
# M1 getting part at t=62
# M3 getting part at t=62
# M1 processing part at t=62
# M3 processing part at t=62
# M1 processing part at t=63
# M3 processing part at t=63
# M1 putting part at t=64
# M3 putting part at t=64
# M3 getting part at t=64
# M1 getting part at t=64
# M1 processing part at t=64
# M3 processing part at t=64
# M1 processing part at t=65
# M3 processing part at t=65
# M1 putting part at t=66
# M3 putting part at t=66
# M3 getting part at t=66
# M1 getting part at t=66
# M1 processing part at t=66
# M3 processing part at t=66
# M1 processing part at t=67
# M3 processing part at t=67
# M1 putting part at t=68
# M3 putting part at t=68
# M3 getting part at t=68
# M1 getting part at t=68
# M1 processing part at t=68
# M3 processing part at t=68
# M1 processing part at t=69
# M3 processing part at t=69
# M1 putting part at t=70
# M3 putting part at t=70
# M2 getting part at t=70
# M1 getting part at t=70
# M1 processing part at t=70
# M2 processing part at t=70
# M1 processing part at t=71
# M2 processing part at t=71
# M1 putting part at t=72
# M2 putting part at t=72
# M3 getting part at t=72
# M1 getting part at t=72
# M1 processing part at t=72
# M3 processing part at t=72
# M1 processing part at t=73
# M3 processing part at t=73
# M1 putting part at t=74
# M3 putting part at t=74
# M1 getting part at t=74
# M2 getting part at t=74
# M1 processing part at t=74
# M2 processing part at t=74
# M1 processing part at t=75
# M2 processing part at t=75
# M1 putting part at t=76
# M2 putting part at t=76
# M3 getting part at t=76
# M1 getting part at t=76
# M1 processing part at t=76
# M3 processing part at t=76
# M1 processing part at t=77
# M3 processing part at t=77
# M1 putting part at t=78
# M3 putting part at t=78
# M3 getting part at t=78
# M1 getting part at t=78
# M1 processing part at t=78
# M3 processing part at t=78
# M1 processing part at t=79
# M3 processing part at t=79
# M1 putting part at t=80
# M3 putting part at t=80
# M3 getting part at t=80
# M1 getting part at t=80
# M1 processing part at t=80
# M3 processing part at t=80
# M1 processing part at t=81
# M3 processing part at t=81
# M1 putting part at t=82
# M3 putting part at t=82
# M1 getting part at t=82
# M3 getting part at t=82
# M1 processing part at t=82
# M3 processing part at t=82
# M1 processing part at t=83
# M3 processing part at t=83
# M1 putting part at t=84
# M3 putting part at t=84
# M3 getting part at t=84
# M1 getting part at t=84
# M1 processing part at t=84
# M3 processing part at t=84
# M1 processing part at t=85
# M3 processing part at t=85
# M1 putting part at t=86
# M3 putting part at t=86
# M2 getting part at t=86
# M1 getting part at t=86
# M1 processing part at t=86
# M2 processing part at t=86
# M1 processing part at t=87
# M2 processing part at t=87
# M1 putting part at t=88
# M2 putting part at t=88
# M3 getting part at t=88
# M1 getting part at t=88
# M1 processing part at t=88
# M3 processing part at t=88
# M1 processing part at t=89
# M3 processing part at t=89
# M1 putting part at t=90
# M3 putting part at t=90
# M1 getting part at t=90
# M3 getting part at t=90
# M1 processing part at t=90
# M3 processing part at t=90
# M1 processing part at t=91
# M3 processing part at t=91
# M1 putting part at t=92
# M3 putting part at t=92
# M3 getting part at t=92
# M1 getting part at t=92
# M1 processing part at t=92
# M3 processing part at t=92
# M1 processing part at t=93
# M3 processing part at t=93
# M1 putting part at t=94
# M3 putting part at t=94
# M3 getting part at t=94
# M1 getting part at t=94
# M1 processing part at t=94
# M3 processing part at t=94
# M1 processing part at t=95
# M3 processing part at t=95
# M1 putting part at t=96
# M3 putting part at t=96
# M3 getting part at t=96
# M1 getting part at t=96
# M1 processing part at t=96
# M3 processing part at t=96
# M1 processing part at t=97
# M3 processing part at t=97
# M1 putting part at t=98
# M3 putting part at t=98
# M2 getting part at t=98
# M1 getting part at t=98
# M1 processing part at t=98
# M2 processing part at t=98
# M1 processing part at t=99
# M2 processing part at t=99
# Simulation finished in 0.06s
# Parts made: 48
# M1 getting part at t=0
# M1 processing part at t=0
# M1 processing part at t=1
# M1 putting part at t=2
# M2 getting part at t=2
# M1 getting part at t=2
# M1 processing part at t=2
# M2 processing part at t=2
# M1 processing part at t=3
# M2 processing part at t=3
# M1 putting part at t=4
# M2 putting part at t=4
# M1 getting part at t=4
# M3 getting part at t=4
# M1 processing part at t=4
# M3 processing part at t=4
# M1 processing part at t=5
# M3 processing part at t=5
# M1 putting part at t=6
# M3 putting part at t=6
# M3 getting part at t=6
# M1 getting part at t=6
# M1 processing part at t=6
# M3 processing part at t=6
# M1 processing part at t=7
# M3 processing part at t=7
# M1 putting part at t=8
# M3 putting part at t=8
# M2 getting part at t=8
# M1 getting part at t=8
# M1 processing part at t=8
# M2 processing part at t=8
# M1 processing part at t=9
# M2 processing part at t=9
# M1 putting part at t=10
# M2 putting part at t=10
# M3 getting part at t=10
# M1 getting part at t=10
# M1 processing part at t=10
# M3 processing part at t=10
# M1 processing part at t=11
# M3 processing part at t=11
# M1 putting part at t=12
# M3 putting part at t=12
# M3 getting part at t=12
# M1 getting part at t=12
# M1 processing part at t=12
# M3 processing part at t=12
# M1 processing part at t=13
# M3 processing part at t=13
# M1 putting part at t=14
# M3 putting part at t=14
# M1 getting part at t=14
# M3 getting part at t=14
# M1 processing part at t=14
# M3 processing part at t=14
# M1 processing part at t=15
# M3 processing part at t=15
# M1 putting part at t=16
# M3 putting part at t=16
# M3 getting part at t=16
# M1 getting part at t=16
# M1 processing part at t=16
# M3 processing part at t=16
# M1 processing part at t=17
# M3 processing part at t=17
# M1 putting part at t=18
# M3 putting part at t=18
# M1 getting part at t=18
# M2 getting part at t=18
# M1 processing part at t=18
# M2 processing part at t=18
# M1 processing part at t=19
# M2 processing part at t=19
# M1 putting part at t=20
# M2 putting part at t=20
# M2 getting part at t=20
# M1 getting part at t=20
# M1 processing part at t=20
# M2 processing part at t=20
# M1 processing part at t=21
# M2 processing part at t=21
# M1 putting part at t=22
# M2 putting part at t=22
# M1 getting part at t=22
# M3 getting part at t=22
# M1 processing part at t=22
# M3 processing part at t=22
# M1 processing part at t=23
# M3 processing part at t=23
# M1 putting part at t=24
# M3 putting part at t=24
# M2 getting part at t=24
# M1 getting part at t=24
# M1 processing part at t=24
# M2 processing part at t=24
# M1 processing part at t=25
# M2 processing part at t=25
# M1 putting part at t=26
# M2 putting part at t=26
# M2 getting part at t=26
# M1 getting part at t=26
# M1 processing part at t=26
# M2 processing part at t=26
# M1 processing part at t=27
# M2 processing part at t=27
# M1 putting part at t=28
# M2 putting part at t=28
# M2 getting part at t=28
# M1 getting part at t=28
# M1 processing part at t=28
# M2 processing part at t=28
# M1 processing part at t=29
# M2 processing part at t=29
# M1 putting part at t=30
# M2 putting part at t=30
# M3 getting part at t=30
# M1 getting part at t=30
# M1 processing part at t=30
# M3 processing part at t=30
# M1 processing part at t=31
# M3 processing part at t=31
# M1 putting part at t=32
# M3 putting part at t=32
# M3 getting part at t=32
# M1 getting part at t=32
# M1 processing part at t=32
# M3 processing part at t=32
# M1 processing part at t=33
# M3 processing part at t=33
# M1 putting part at t=34
# M3 putting part at t=34
# M2 getting part at t=34
# M1 getting part at t=34
# M1 processing part at t=34
# M2 processing part at t=34
# M1 processing part at t=35
# M2 processing part at t=35
# M1 putting part at t=36
# M2 putting part at t=36
# M1 getting part at t=36
# M2 getting part at t=36
# M1 processing part at t=36
# M2 processing part at t=36
# M1 processing part at t=37
# M2 processing part at t=37
# M1 putting part at t=38
# M2 putting part at t=38
# M1 getting part at t=38
# M3 getting part at t=38
# M1 processing part at t=38
# M3 processing part at t=38
# M1 processing part at t=39
# M3 processing part at t=39
# M1 putting part at t=40
# M3 putting part at t=40
# M2 getting part at t=40
# M1 getting part at t=40
# M1 processing part at t=40
# M2 processing part at t=40
# M1 processing part at t=41
# M2 processing part at t=41
# M1 putting part at t=42
# M2 putting part at t=42
# M1 getting part at t=42
# M3 getting part at t=42
# M1 processing part at t=42
# M3 processing part at t=42
# M1 processing part at t=43
# M3 processing part at t=43
# M1 putting part at t=44
# M3 putting part at t=44
# M2 getting part at t=44
# M1 getting part at t=44
# M1 processing part at t=44
# M2 processing part at t=44
# M1 processing part at t=45
# M2 processing part at t=45
# M1 putting part at t=46
# M2 putting part at t=46
# M1 getting part at t=46
# M2 getting part at t=46
# M1 processing part at t=46
# M2 processing part at t=46
# M1 processing part at t=47
# M2 processing part at t=47
# M1 putting part at t=48
# M2 putting part at t=48
# M3 getting part at t=48
# M1 getting part at t=48
# M1 processing part at t=48
# M3 processing part at t=48
# M1 processing part at t=49
# M3 processing part at t=49
# M1 putting part at t=50
# M3 putting part at t=50
# M3 getting part at t=50
# M1 getting part at t=50
# M1 processing part at t=50
# M3 processing part at t=50
# M1 processing part at t=51
# M3 processing part at t=51
# M1 putting part at t=52
# M3 putting part at t=52
# M3 getting part at t=52
# M1 getting part at t=52
# M1 processing part at t=52
# M3 processing part at t=52
# M1 processing part at t=53
# M3 processing part at t=53
# M1 putting part at t=54
# M3 putting part at t=54
# M2 getting part at t=54
# M1 getting part at t=54
# M1 processing part at t=54
# M2 processing part at t=54
# M1 processing part at t=55
# M2 processing part at t=55
# M1 putting part at t=56
# M2 putting part at t=56
# M1 getting part at t=56
# M2 getting part at t=56
# M1 processing part at t=56
# M2 processing part at t=56
# M1 processing part at t=57
# M2 processing part at t=57
# M1 putting part at t=58
# M2 putting part at t=58
# M2 getting part at t=58
# M1 getting part at t=58
# M1 processing part at t=58
# M2 processing part at t=58
# M1 processing part at t=59
# M2 processing part at t=59
# M1 putting part at t=60
# M2 putting part at t=60
# M2 getting part at t=60
# M1 getting part at t=60
# M1 processing part at t=60
# M2 processing part at t=60
# M1 processing part at t=61
# M2 processing part at t=61
# M1 putting part at t=62
# M2 putting part at t=62
# M2 getting part at t=62
# M1 getting part at t=62
# M1 processing part at t=62
# M2 processing part at t=62
# M1 processing part at t=63
# M2 processing part at t=63
# M1 putting part at t=64
# M2 putting part at t=64
# M2 getting part at t=64
# M1 getting part at t=64
# M1 processing part at t=64
# M2 processing part at t=64
# M1 processing part at t=65
# M2 processing part at t=65
# M1 putting part at t=66
# M2 putting part at t=66
# M2 getting part at t=66
# M1 getting part at t=66
# M1 processing part at t=66
# M2 processing part at t=66
# M1 processing part at t=67
# M2 processing part at t=67
# M1 putting part at t=68
# M2 putting part at t=68
# M1 getting part at t=68
# M2 getting part at t=68
# M1 processing part at t=68
# M2 processing part at t=68
# M1 processing part at t=69
# M2 processing part at t=69
# M1 putting part at t=70
# M2 putting part at t=70
# M1 getting part at t=70
# M2 getting part at t=70
# M1 processing part at t=70
# M2 processing part at t=70
# M1 processing part at t=71
# M2 processing part at t=71
# M1 putting part at t=72
# M2 putting part at t=72
# M2 getting part at t=72
# M1 getting part at t=72
# M1 processing part at t=72
# M2 processing part at t=72
# M1 processing part at t=73
# M2 processing part at t=73
# M1 putting part at t=74
# M2 putting part at t=74
# M3 getting part at t=74
# M1 getting part at t=74
# M1 processing part at t=74
# M3 processing part at t=74
# M1 processing part at t=75
# M3 processing part at t=75
# M1 putting part at t=76
# M3 putting part at t=76
# M2 getting part at t=76
# M1 getting part at t=76
# M1 processing part at t=76
# M2 processing part at t=76
# M1 processing part at t=77
# M2 processing part at t=77
# M1 putting part at t=78
# M2 putting part at t=78
# M3 getting part at t=78
# M1 getting part at t=78
# M1 processing part at t=78
# M3 processing part at t=78
# M1 processing part at t=79
# M3 processing part at t=79
# M1 putting part at t=80
# M3 putting part at t=80
# M2 getting part at t=80
# M1 getting part at t=80
# M1 processing part at t=80
# M2 processing part at t=80
# M1 processing part at t=81
# M2 processing part at t=81
# M1 putting part at t=82
# M2 putting part at t=82
# M1 getting part at t=82
# M3 getting part at t=82
# M1 processing part at t=82
# M3 processing part at t=82
# M1 processing part at t=83
# M3 processing part at t=83
# M1 putting part at t=84
# M3 putting part at t=84
# M2 getting part at t=84
# M1 getting part at t=84
# M1 processing part at t=84
# M2 processing part at t=84
# M1 processing part at t=85
# M2 processing part at t=85
# M1 putting part at t=86
# M2 putting part at t=86
# M2 getting part at t=86
# M1 getting part at t=86
# M1 processing part at t=86
# M2 processing part at t=86
# M1 processing part at t=87
# M2 processing part at t=87
# M1 putting part at t=88
# M2 putting part at t=88
# M1 getting part at t=88
# M3 getting part at t=88
# M1 processing part at t=88
# M3 processing part at t=88
# M1 processing part at t=89
# M3 processing part at t=89
# M1 putting part at t=90
# M3 putting part at t=90
# M1 getting part at t=90
# M2 getting part at t=90
# M1 processing part at t=90
# M2 processing part at t=90
# M1 processing part at t=91
# M2 processing part at t=91
# M1 putting part at t=92
# M2 putting part at t=92
# M3 getting part at t=92
# M1 getting part at t=92
# M1 processing part at t=92
# M3 processing part at t=92
# M1 processing part at t=93
# M3 processing part at t=93
# M1 putting part at t=94
# M3 putting part at t=94
# M3 getting part at t=94
# M1 getting part at t=94
# M1 processing part at t=94
# M3 processing part at t=94
# M1 processing part at t=95
# M3 processing part at t=95
# M1 putting part at t=96
# M3 putting part at t=96
# M3 getting part at t=96
# M1 getting part at t=96
# M1 processing part at t=96
# M3 processing part at t=96
# M1 processing part at t=97
# M3 processing part at t=97
# M1 putting part at t=98
# M3 putting part at t=98
# M1 getting part at t=98
# M2 getting part at t=98
# M1 processing part at t=98
# M2 processing part at t=98
# M1 processing part at t=99
# M2 processing part at t=99
# Simulation finished in 0.06s
# Parts made: 48
# M2 average parts made: 23.44
# M3 average parts made: 24.56
